# %%
import pandas as pd
import numpy as np
data=pd.read_excel("Copy of 500_MT_BERT_Preds _ Accuracy Analysis.xlsx",sheet_name="Tech_String_match")

# %%
data.head()
# Out:
#                             id  \
# 0  -1zMVjZsVTSaqEUPGqaTqA_0000
# 1  0BEpuKXd00LyMNQDgcqUZw_0000
# 2  0f9VnfZFwZiyd30xGBK9Ig_0000
# 3  0GTKKIK9kj-FVYLEkrqqcA_0000
# 4  0iMM991ETr11zJf6ABimew_0000
#
#                                            summaries  \
# 0  i have a masters degree in computational finan...
# 1  i am a strategic hr leader with single and mul...
# 2  multitalented creative marketing and design pr...
# 3  it professional with an overall 16 years of te...
# 4  an innovative resultdriven leader with a prove...
#
#   exact_matched_patt_contextual string_match_prediction   Tech_Label   TP  \
# 0                      ['java']           ['accenture']           []  0.0
# 1                   ['courion']             ['courion']  ['courion']  1.0
# 2                     ['adobe']     ['adobe photoshop']           []  0.0
# 3                     ['wipro']               ['wipro']    ['wipro']  1.0
# 4                    ['paypal']              ['paypal']   ['paypal']  1.0
#
# ...

# %%
data=data[['id','summaries','exact_matched_patt_contextual','string_match_prediction','Tech_Label','TP_entries_TECH','FP_entries_TECH','FN_entries_TECH','FP corrected']]

data=data.loc[:499]

# %%
data.head()
# Out:
#                             id  \
# 0  -1zMVjZsVTSaqEUPGqaTqA_0000
# 1  0BEpuKXd00LyMNQDgcqUZw_0000
# 2  0f9VnfZFwZiyd30xGBK9Ig_0000
# 3  0GTKKIK9kj-FVYLEkrqqcA_0000
# 4  0iMM991ETr11zJf6ABimew_0000
#
#                                            summaries  \
# 0  i have a masters degree in computational finan...
# 1  i am a strategic hr leader with single and mul...
# 2  multitalented creative marketing and design pr...
# 3  it professional with an overall 16 years of te...
# 4  an innovative resultdriven leader with a prove...
#
#   exact_matched_patt_contextual string_match_prediction   Tech_Label  \
# 0                      ['java']           ['accenture']           []
# 1                   ['courion']             ['courion']  ['courion']
# 2                     ['adobe']     ['adobe photoshop']           []
# 3                     ['wipro']               ['wipro']    ['wipro']
# 4                    ['paypal']              ['paypal']   ['paypal']
#
# ...

# %%
# for i, l in enumerate(data['FP_entries_eng'] ):
#     print("list",i,"is",type(l))

# %%
data['FP corrected'] = data['FP corrected'].fillna('[]')
data['FP_entries_TECH'] = data['FP_entries_TECH'].fillna('[]')
data['FP corrected'] = data['FP corrected'].apply(eval) 
data['TP_entries_TECH']= data['TP_entries_TECH'].apply(eval)
data['FP_entries_TECH']= data['FP_entries_TECH'].apply(eval)
data['FN_entries_TECH']= data['FN_entries_TECH'].apply(eval)
data['exact_matched_patt_contextual'] =data['exact_matched_patt_contextual'] .apply(eval)

# %%
data['TP_entries_TECH'].str.len().sum()
# Out:
# 209

# %%
data['FP_entries_TECH'].str.len().sum()
# Out:
# 78

# %%
#corrected fp will move in tp entry
def combine(lis1, lis2):
    return list(set(lis1 + lis2))

data['exact_matched_patt_contextual'] = data.apply(
    lambda x: combine(x['exact_matched_patt_contextual'], x["FP corrected"]), 
    axis = 1)
data['TP_entries_TECH'] = data.apply(
    lambda x: combine(x['TP_entries_TECH'], x["FP corrected"]), 
    axis = 1)

# %%
data['TP']=data['TP_entries_TECH'].str.len()
data['FP']=data['FP_entries_TECH'].str.len()
data['FN']=data['FN_entries_TECH'].str.len()

# %%
data['FP corrected'].str.len().sum()
# Out:
# 15

# %%
data['TP_entries_TECH'].str.len().sum()
# Out:
# 219

# %%
data['FP_entries_TECH'].str.len().sum()
# Out:
# 78

# %%
data.drop(columns=['FP corrected'])
# Out:
#                               id  \
# 0    -1zMVjZsVTSaqEUPGqaTqA_0000
# 1    0BEpuKXd00LyMNQDgcqUZw_0000
# 2    0f9VnfZFwZiyd30xGBK9Ig_0000
# 3    0GTKKIK9kj-FVYLEkrqqcA_0000
# 4    0iMM991ETr11zJf6ABimew_0000
# ..                           ...
# 495  zun1u5pEP6XGEgB8NnH5Cw_0000
# 496  zYOI4JmmTDiT023cU9g7XA_0000
# 497  ZzIyes8qbSx2AXxe4cSPlA_0000
# 498                          NaN
# 499                          NaN
#
#                                              summaries  \
# 0    i have a masters degree in computational finan...
# 1    i am a strategic hr leader with single and mul...
# 2    multitalented creative marketing and design pr...
# 3    it professional with an overall 16 years of te...
# 4    an innovative resultdriven leader with a prove...
# ..                                                 ...
# 495  after teaching at hogeschool rotterdam i found...
# 496  having spent 8 months in 2011 working with dan...
# 497  after 15 years of successful sales and recruit...
# ...

# %%
def get_precision(tp,fp):
    
    if tp+fp ==0:
        precision = 0
    else:
        precision = tp/(tp+fp)
    
    return precision

def get_recall(tp,fn):
    
    if tp+fn ==0:
        recall = 0
    else:
        recall = tp/(tp+fn)
    
    return recall

def get_f_score(precision, recall):
    if precision+recall == 0:
        f_score = 0
    else:
        f_score = 2*(precision*recall)/(precision+recall)
        
    return f_score

data['Precision'] = data.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

data["Recall"] = data.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

data["f_score"] = data.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

# %%
data
# Out:
#                               id  \
# 0    -1zMVjZsVTSaqEUPGqaTqA_0000
# 1    0BEpuKXd00LyMNQDgcqUZw_0000
# 2    0f9VnfZFwZiyd30xGBK9Ig_0000
# 3    0GTKKIK9kj-FVYLEkrqqcA_0000
# 4    0iMM991ETr11zJf6ABimew_0000
# ..                           ...
# 495  zun1u5pEP6XGEgB8NnH5Cw_0000
# 496  zYOI4JmmTDiT023cU9g7XA_0000
# 497  ZzIyes8qbSx2AXxe4cSPlA_0000
# 498                          NaN
# 499                          NaN
#
#                                              summaries  \
# 0    i have a masters degree in computational finan...
# 1    i am a strategic hr leader with single and mul...
# 2    multitalented creative marketing and design pr...
# 3    it professional with an overall 16 years of te...
# 4    an innovative resultdriven leader with a prove...
# ..                                                 ...
# 495  after teaching at hogeschool rotterdam i found...
# 496  having spent 8 months in 2011 working with dan...
# 497  after 15 years of successful sales and recruit...
# ...

# %%
data.to_csv("BERT_TECH_500.csv")
