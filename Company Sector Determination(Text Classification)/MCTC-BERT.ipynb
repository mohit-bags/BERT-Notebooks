# %%
# Link- https://towardsdatascience.com/multi-class-text-classification-with-deep-learning-using-bert-b59ca2f5c613
# Here I have classified Company Industry Domain(147) from its Description from Crunchbase data
import pandas as pd
import numpy as np
import nltk
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.stem.porter import PorterStemmer

from sklearn.model_selection import cross_val_score
import re
import codecs
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

import torch
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

# %%
df = pd.read_csv('../data/50k_data_crunchbase.csv')
df=df[['company_description','company_industry']]
df.head()
# Out:
#                                  company_description  \
# 0  Founded in 2005 by Art Howe, CIU Networks INC ...
# 1  Pulling your hair out over mindless call after...
# 2  Creative Facility Design can recommend alterna...
# 3  PVM Innvensys Pvt Ltd is an information techno...
# 4  Eleview International Inc is an information te...
#
#                       company_industry
# 0  Information Technology and Services
# 1  Information Technology and Services
# 2  Information Technology and Services
# 3  Information Technology and Services
# 4  Information Technology and Services

# %%
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))  
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return df

data_clean = clean_text(df, 'company_description', 'text_clean')
data_clean['company_description'] = data_clean['text_clean']
df = data_clean[['company_description','company_industry']]

# %%
possible_labels = df.company_industry.unique()

label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index
label_dict
# Out:
# {'Information Technology and Services': 0,
#  'E-Learning': 1,
#  'Electrical/Electronic Manufacturing': 2,
#  'Information Services': 3,
#  'Food & Beverages': 4,
#  'Internet': 5,
#  'Education Management': 6,
#  'Public Relations and Communications': 7,
#  'Marketing and Advertising': 8,
#  'Higher Education': 9,
#  'Supermarkets': 10,
#  'Professional Training & Coaching': 11,
#  'Hospital & Health Care': 12,
#  'Sporting Goods': 13,
#  'Hospitality': 14,
#  'Investment Banking': 15,
#  'Staffing and Recruiting': 16,
#  'Insurance': 17,
#  'Research': 18,
#  'Biotechnology': 19,
#  'Computer Software': 20,
#  'Public Policy': 21,
#  'Leisure Travel & Tourism': 22,
#  'Health Wellness and Fitness': 23,
#  'Computer Games': 24,
#  'Entertainment': 25,
#  'Apparel & Fashion': 26,
#  'Medical Devices': 27,
#  'Consumer Services': 28,
#  'Venture Capital & Private Equity': 29,
#  'Online Media': 30,
#  'Business Supplies and Equipment': 31,
#  'Retail': 32,
#  'Real Estate': 33,
#  'Government Administration': 34,
#  'Building Materials': 35,
#  'Investment Management': 36,
#  'Defense & Space': 37,
#  'Wireless': 38,
#  'Computer Hardware': 39,
#  'Music': 40,
#  'Media Production': 41,
#  'Renewables & Environment': 42,
#  'Capital Markets': 43,
#  'Broadcast Media': 44,
#  'International Trade and Development': 45,
#  'Automotive': 46,
#  'Fund-Raising': 47,
#  'Maritime': 48,
#  'Alternative Medicine': 49,
#  'Financial Services': 50,
#  'Sports': 51,
#  'Outsourcing/Offshoring': 52,
#  'Construction': 53,
#  'Banking': 54,
#  'Packaging and Containers': 55,
#  'Food Production': 56,
#  'Pharmaceuticals': 57,
#  'Wholesale': 58,
#  'Telecommunications': 59,
#  'Farming': 60,
#  'Oil & Energy': 61,
#  'Wine and Spirits': 62,
#  'Cosmetics': 63,
#  'Chemicals': 64,
#  'Logistics and Supply Chain': 65,
#  'Environmental Services': 66,
#  'Consumer Goods': 67,
#  'Government Relations': 68,
#  'Events Services': 69,
#  'Mechanical or Industrial Engineering': 70,
#  'Law Enforcement': 71,
#  'Management Consulting': 72,
#  'Luxury Goods & Jewelry': 73,
#  'Airlines/Aviation': 74,
#  'Human Resources': 75,
#  'Law Practice': 76,
#  'Facilities Services': 77,
#  'Mining & Metals': 78,
#  'Furniture': 79,
#  'Paper & Forest Products': 80,
#  'Legal Services': 81,
#  'Commercial Real Estate': 82,
#  'Security and Investigations': 83,
#  'Aviation & Aerospace': 84,
#  'Transportation/Trucking/Railroad': 85,
#  'Semiconductors': 86,
#  'Design': 87,
#  'Tobacco': 88,
#  'Industrial Automation': 89,
#  'Accounting': 90,
#  'Translation and Localization': 91,
#  'Executive Office': 92,
#  'Civic & Social Organization': 93,
#  'Textiles': 94,
#  'Publishing': 95,
#  'Public Safety': 96,
#  'Nonprofit Organization Management': 97,
#  'Restaurants': 98,
#  'Computer Networking': 99,
#  'Newspapers': 100,
#  'Architecture & Planning': 101,
#  'Gambling & Casinos': 102,
#  'Package/Freight Delivery': 103,
#  'Civil Engineering': 104,
#  'Machinery': 105,
#  'Consumer Electronics': 106,
#  'International Affairs': 107,
#  'Utilities': 108,
#  'Computer & Network Security': 109,
#  'Veterinary': 110,
#  'Warehousing': 111,
#  'Political Organization': 112,
#  'Performing Arts': 113,
#  'Motion Pictures and Film': 114,
#  'Medical Practice': 115,
#  'Photography': 116,
#  'Printing': 117,
#  'Animation': 118,
#  'Individual & Family Services': 119,
#  'Recreational Facilities and Services': 120,
#  'Market Research': 121,
#  'Writing and Editing': 122,
#  'Primary/Secondary Education': 123,
#  'Mental Health Care': 124,
#  'Dairy': 125,
#  'Arts and Crafts': 126,
#  'Philanthropy': 127,
#  'Graphic Design': 128,
#  'Think Tanks': 129,
#  'Glass Ceramics & Concrete': 130,
#  'Military': 131,
#  'Religious Institutions': 132,
#  'Plastics': 133,
#  'Import and Export': 134,
#  'Museums and Institutions': 135,
#  'Ranching': 136,
#  'Fishery': 137,
#  'Libraries': 138,
#  'Program Development': 139,
#  'Fine Art': 140,
#  'Nanotechnology': 141,
#  'Railroad Manufacture': 142,
#  'Shipbuilding': 143,
#  'Alternative Dispute Resolution': 144,
#  'Legislative Office': 145,
#  'Judiciary': 146}

# %%
df['label'] = df.company_industry.replace(label_dict)

# %%
df
# Out:
#                                      company_description  \
# 0      founded in  by art howe ciu networks inc is th...
# 1      pulling your hair out over mindless call after...
# 2      creative facility design can recommend alterna...
# 3      pvm innvensys pvt ltd is an information techno...
# 4      eleview international inc is an information te...
# ...                                                  ...
# 50069  office of rep james p mcgovern is a representa...
# 50070  the joint economic committee jec was created w...
# 50071  the international court of justice icj is the ...
# 50072  middle district of florida web site provides i...
# 50073  the southern district comprises the counties o...
#
#                           company_industry  label
# 0      Information Technology and Services      0
# 1      Information Technology and Services      0
# 2      Information Technology and Services      0
# 3      Information Technology and Services      0
# 4      Information Technology and Services      0
# ...                                    ...    ...
# 50069                   Legislative Office    145
# 50070                   Legislative Office    145
# 50071                            Judiciary    146
# 50072                            Judiciary    146
# 50073                            Judiciary    146
#
# [50074 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df.index.values, 
                                                  df.label.values, 
                                                  test_size=0.15, 
                                                  random_state=42, 
                                                  stratify=df.label.values)

df['data_type'] = ['not_set']*df.shape[0]

df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

df.groupby(['company_industry', 'label', 'data_type']).count()
# Out:
#                                                 company_description
# company_industry               label data_type
# Accounting                     90    train                      261
#                                      val                         46
# Airlines/Aviation              74    train                      122
#                                      val                         22
# Alternative Dispute Resolution 144   train                        4
# ...                                                             ...
# Wine and Spirits               62    val                         12
# Wireless                       38    train                      106
#                                      val                         19
# Writing and Editing            122   train                       56
#                                      val                         10
#
# [292 rows x 1 columns]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', 
                                          do_lower_case=True)
                                          
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].company_description.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].company_description.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/slintel/bert/lib/python3.6/site-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

batch_size = 16

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

optimizer = AdamW(model.parameters(),
                  lr=1e-4, 
                  eps=1e-8)
                  
epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
from sklearn.metrics import f1_score

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
device
# Out:
# device(type='cuda')

# %%
import random

seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals
    
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'../data/finetuned_BERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='Epoch 1', max=2661.0, style=ProgressStyle(description_wid…
# Epoch 1
# Training loss: 2.3239291766360934
# Validation loss: 1.8044585245720883
# F1 Score (Weighted): 0.49523712577689033
# HBox(children=(FloatProgress(value=0.0, description='Epoch 2', max=2661.0, style=ProgressStyle(description_wid…
# Epoch 2
# Training loss: 1.5222494926321826
# Validation loss: 1.6755151549235303
# F1 Score (Weighted): 0.5276699886389506
# HBox(children=(FloatProgress(value=0.0, description='Epoch 3', max=2661.0, style=ProgressStyle(description_wid…
# Epoch 3
# Training loss: 1.0323462704212671
# Validation loss: 1.6833917353698549
# F1 Score (Weighted): 0.5409804527303835

# %%
torch.cuda.empty_cache()

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('../data/finetuned_BERT_epoch_3.model', map_location=torch.device('cpu')))

_, predictions, true_vals = evaluate(dataloader_validation)
accuracy_per_class(predictions, true_vals)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Class: Information Technology and Services
# Accuracy: 524/915
#
# Class: E-Learning
# Accuracy: 44/64
#
# Class: Electrical/Electronic Manufacturing
# Accuracy: 47/94
#
# Class: Information Services
# Accuracy: 3/35
#
# Class: Food & Beverages
# Accuracy: 50/78
#
# Class: Internet
# Accuracy: 186/474
#
# Class: Education Management
# Accuracy: 40/87
#
# Class: Public Relations and Communications
# Accuracy: 26/34
#
# Class: Marketing and Advertising
# Accuracy: 305/432
#
# Class: Higher Education
# Accuracy: 51/75
#
# Class: Supermarkets
# Accuracy: 0/2
#
# Class: Professional Training & Coaching
# Accuracy: 11/33
#
# Class: Hospital & Health Care
# Accuracy: 77/134
#
# Class: Sporting Goods
# Accuracy: 12/15
#
# Class: Hospitality
# Accuracy: 26/49
#
# Class: Investment Banking
# Accuracy: 12/25
#
# Class: Staffing and Recruiting
# Accuracy: 51/70
#
# Class: Insurance
# Accuracy: 69/81
#
# Class: Research
# Accuracy: 18/51
#
# Class: Biotechnology
# Accuracy: 72/101
#
# Class: Computer Software
# Accuracy: 311/622
#
# Class: Public Policy
# Accuracy: 0/7
#
# Class: Leisure Travel & Tourism
# Accuracy: 37/59
#
# Class: Health Wellness and Fitness
# Accuracy: 55/113
#
# Class: Computer Games
# Accuracy: 40/49
#
# Class: Entertainment
# Accuracy: 30/74
#
# Class: Apparel & Fashion
# Accuracy: 35/59
#
# Class: Medical Devices
# Accuracy: 60/87
#
# Class: Consumer Services
# Accuracy: 15/55
#
# Class: Venture Capital & Private Equity
# Accuracy: 75/114
#
# Class: Online Media
# Accuracy: 17/51
#
# Class: Business Supplies and Equipment
# Accuracy: 5/23
#
# Class: Retail
# Accuracy: 40/106
#
# Class: Real Estate
# Accuracy: 109/139
#
# Class: Government Administration
# Accuracy: 12/18
#
# Class: Building Materials
# Accuracy: 11/29
#
# Class: Investment Management
# Accuracy: 34/71
#
# Class: Defense & Space
# Accuracy: 8/22
#
# Class: Wireless
# Accuracy: 1/19
#
# Class: Computer Hardware
# Accuracy: 3/22
#
# Class: Music
# Accuracy: 20/28
#
# Class: Media Production
# Accuracy: 27/52
#
# Class: Renewables & Environment
# Accuracy: 42/64
#
# Class: Capital Markets
# Accuracy: 0/9
#
# Class: Broadcast Media
# Accuracy: 17/30
#
# Class: International Trade and Development
# Accuracy: 5/16
#
# Class: Automotive
# Accuracy: 59/84
#
# Class: Fund-Raising
# Accuracy: 1/9
#
# Class: Maritime
# Accuracy: 8/13
#
# Class: Alternative Medicine
# Accuracy: 0/3
#
# Class: Financial Services
# Accuracy: 193/291
#
# Class: Sports
# Accuracy: 32/39
#
# Class: Outsourcing/Offshoring
# Accuracy: 3/17
#
# Class: Construction
# Accuracy: 85/116
#
# Class: Banking
# Accuracy: 44/54
#
# Class: Packaging and Containers
# Accuracy: 13/16
#
# Class: Food Production
# Accuracy: 19/32
#
# Class: Pharmaceuticals
# Accuracy: 35/55
#
# Class: Wholesale
# Accuracy: 8/27
#
# Class: Telecommunications
# Accuracy: 77/111
#
# Class: Farming
# Accuracy: 10/15
#
# Class: Oil & Energy
# Accuracy: 51/76
#
# Class: Wine and Spirits
# Accuracy: 8/12
#
# Class: Cosmetics
# Accuracy: 9/14
#
# Class: Chemicals
# Accuracy: 18/29
#
# Class: Logistics and Supply Chain
# Accuracy: 22/45
#
# Class: Environmental Services
# Accuracy: 18/41
#
# Class: Consumer Goods
# Accuracy: 16/69
#
# Class: Government Relations
# Accuracy: 1/6
#
# Class: Events Services
# Accuracy: 19/41
#
# Class: Mechanical or Industrial Engineering
# Accuracy: 27/61
#
# Class: Law Enforcement
# Accuracy: 2/3
#
# Class: Management Consulting
# Accuracy: 62/118
#
# Class: Luxury Goods & Jewelry
# Accuracy: 10/14
#
# Class: Airlines/Aviation
# Accuracy: 14/22
#
# Class: Human Resources
# Accuracy: 16/45
#
# Class: Law Practice
# Accuracy: 40/49
#
# Class: Facilities Services
# Accuracy: 8/21
#
# Class: Mining & Metals
# Accuracy: 27/37
#
# Class: Furniture
# Accuracy: 10/17
#
# Class: Paper & Forest Products
# Accuracy: 1/6
#
# Class: Legal Services
# Accuracy: 23/39
#
# Class: Commercial Real Estate
# Accuracy: 5/17
#
# Class: Security and Investigations
# Accuracy: 14/22
#
# Class: Aviation & Aerospace
# Accuracy: 21/32
#
# Class: Transportation/Trucking/Railroad
# Accuracy: 27/45
#
# Class: Semiconductors
# Accuracy: 17/22
#
# Class: Design
# Accuracy: 37/87
#
# Class: Tobacco
# Accuracy: 0/1
#
# Class: Industrial Automation
# Accuracy: 12/35
#
# Class: Accounting
# Accuracy: 33/46
#
# Class: Translation and Localization
# Accuracy: 12/12
#
# Class: Executive Office
# Accuracy: 1/8
#
# Class: Civic & Social Organization
# Accuracy: 1/20
#
# Class: Textiles
# Accuracy: 5/11
#
# Class: Publishing
# Accuracy: 30/48
#
# Class: Public Safety
# Accuracy: 0/7
#
# Class: Nonprofit Organization Management
# Accuracy: 39/76
#
# Class: Restaurants
# Accuracy: 13/20
#
# Class: Computer Networking
# Accuracy: 0/18
#
# Class: Newspapers
# Accuracy: 10/14
#
# Class: Architecture & Planning
# Accuracy: 25/32
#
# Class: Gambling & Casinos
# Accuracy: 6/9
#
# Class: Package/Freight Delivery
# Accuracy: 0/4
#
# Class: Civil Engineering
# Accuracy: 16/23
#
# Class: Machinery
# Accuracy: 13/41
#
# Class: Consumer Electronics
# Accuracy: 18/48
#
# Class: International Affairs
# Accuracy: 0/5
#
# Class: Utilities
# Accuracy: 15/23
#
# Class: Computer & Network Security
# Accuracy: 22/45
#
# Class: Veterinary
# Accuracy: 5/7
#
# Class: Warehousing
# Accuracy: 0/4
#
# Class: Political Organization
# Accuracy: 1/3
#
# Class: Performing Arts
# Accuracy: 3/5
#
# Class: Motion Pictures and Film
# Accuracy: 6/13
#
# Class: Medical Practice
# Accuracy: 15/28
#
# Class: Photography
# Accuracy: 9/14
#
# Class: Printing
# Accuracy: 15/28
#
# Class: Animation
# Accuracy: 1/7
#
# Class: Individual & Family Services
# Accuracy: 6/15
#
# Class: Recreational Facilities and Services
# Accuracy: 0/6
#
# Class: Market Research
# Accuracy: 12/24
#
# Class: Writing and Editing
# Accuracy: 5/10
#
# Class: Primary/Secondary Education
# Accuracy: 0/9
#
# Class: Mental Health Care
# Accuracy: 4/12
#
# Class: Dairy
# Accuracy: 0/2
#
# Class: Arts and Crafts
# Accuracy: 3/8
#
# Class: Philanthropy
# Accuracy: 4/13
#
# Class: Graphic Design
# Accuracy: 4/20
#
# Class: Think Tanks
# Accuracy: 0/9
#
# Class: Glass Ceramics & Concrete
# Accuracy: 1/3
#
# Class: Military
# Accuracy: 0/2
#
# Class: Religious Institutions
# Accuracy: 2/4
#
# Class: Plastics
# Accuracy: 7/17
#
# Class: Import and Export
# Accuracy: 0/6
#
# Class: Museums and Institutions
# Accuracy: 7/7
#
# Class: Ranching
# Accuracy: 0/1
#
# Class: Fishery
# Accuracy: 0/1
#
# Class: Libraries
# Accuracy: 0/2
#
# Class: Program Development
# Accuracy: 0/9
#
# Class: Fine Art
# Accuracy: 2/6
#
# Class: Nanotechnology
# Accuracy: 4/8
#
# Class: Railroad Manufacture
# Accuracy: 0/1
#
# Class: Shipbuilding
# Accuracy: 0/2
#
# Class: Alternative Dispute Resolution
# Accuracy: 0/1
