# %%
import pandas as pd
import numpy as np
import ast
import nltk
import re
from bs4 import BeautifulSoup

def remove_space(string_list):
    
    k = [" ".join(i.split()) for i in string_list]
    print(k)
    return k


def clean_text(text):
    """
        text: a string
        return: modified initial string
    """
#     text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')

#     text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
#     text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    return text

def to_list(inp):
    return "['"+inp+"']"
# Pass the matched technology column that we got
def convert_data_format(df,column_name):
    
    for i in range(0, len(df)):
        
        if df[column_name][i][0] == '[':
            res = ast.literal_eval(df[column_name][i])
            df[column_name][i] = res
            
        else:
            x = []
            x.insert(0, df[column_name][i])
            df[column_name][i] = x
            
    return df

def get_TP(df,manual_tagged_string,op_string):
    
    for ind in df.index:
        TP = FP = 0
        
        for i in range(0, len(df[op_string][ind])):
            
            if df[op_string][ind][i] in df[manual_tagged_string][ind]:
                TP = TP + 1
                
            else:
                pass
                
        tp.append(TP)

    return tp

def get_FP(df,manual_tagged_string, op_string):
    
    for ind in df.index:
        main_list = np.setdiff1d(df[op_string][ind],df[manual_tagged_string][ind])
        fp.append(len(main_list))
        fp_entry.append(main_list)
        
        
    return fp, fp_entry

def get_FN(df,manual_tagged_string, op_string):
    
    for ind in df.index:
        
        main_list = np.setdiff1d(df[manual_tagged_string][ind], df[op_string][ind])
        if df[manual_tagged_string][ind]=='[]':
            fn.append(0)
        else:
            fn.append(len(main_list))
        
    return fn

def get_tech_tagged_data(manually_tagged, tech_list):
    keep=[]
    for word in manually_tagged:
        if word in tech_list:
            keep.append(word)
    return keep
def combine(lis1, lis2):
    return list(set(lis1 + lis2))

def get_precision(tp,fp):
    
    if tp+fp ==0:
        precision = 0
    else:
        precision = tp/(tp+fp)
    return precision

def get_recall(tp,fn):
    if tp+fn ==0:
        recall = 0
    else:
        recall = tp/(tp+fn)
    return recall

def get_f_score(precision, recall):
    if precision+recall == 0:
        f_score = 0
    else:
        f_score = 2*(precision*recall)/(precision+recall)
    return f_score

def Diff(li1, li2): #FP entries
    return list(set(li2)-set(li1))

def Same(lis1,lis2): #TP entries
    return list(set(lis1).intersection(lis2))

def Common(lis1,lis2):
    return list(set(lis1)-(set(lis2)))

# %% [markdown]
# ### ENG

# %%
##############################################################################################
data_path = "BERT_prod_tags_v2_mergedkeys.csv" #ENTER DATA PATH
ID = 'lead_id'# ID column name
summaries = 'summaries'#summaries column name
manually_tagged = 'prod_tag' #manual tag column name
bert_tags = 'BERT_Tags'#column name
##############################################################################################

data=pd.read_csv(data_path)
# data=data[[ID,summaries,manually_tagged,bert_tags]]
data[manually_tagged]=data[manually_tagged].apply(clean_text)

data[manually_tagged]=data[manually_tagged].apply(eval)
data[bert_tags] = data[bert_tags].apply(eval)
data[bert_tags] = data[bert_tags].apply(remove_space)


tech_data = pd.read_csv("Tech_pydictionary_final.csv")
tech_data["Tech_word"]=tech_data["Tech_word"].apply(clean_text)
tech_list = list(set(tech_data["Tech_word"]))
eng_data = pd.read_csv("Eng_pydictionary_final.csv")
eng_data["English_word"]=eng_data["English_word"].apply(clean_text)
eng_list= list(set(eng_data["English_word"]))


# (all entries which are in eng dictionary)
eng_bert_tags=[]
removed=0
kept=0
for i in range(0,len(data)):
    eng_bert_1sen=[]
    tags= data[bert_tags][i]
    for j in tags:
        if j in eng_list:
            kept+=1
            eng_bert_1sen.append(j)
        else:
            removed+=1
    eng_bert_tags.append(eng_bert_1sen)
data[bert_tags+"_ENG"]=eng_bert_tags

##############################################################################################
data.to_csv("BERT_preds_JOB_id_ENG_ONLY2july.csv",index=False)
'''SAME FILE WRITE AND READ'''
summary = pd.read_csv("BERT_preds_JOB_id_ENG_ONLY2july.csv")
##############################################################################################
# summary = summary[[ID,summaries,manually_tagged,bert_tags]]
summary = summary.sort_values(by=[ID], ascending=False)
summary.reset_index(inplace = True, drop = True)
col_name_op = "BERT_Tags_ENG"

df_cm = summary
df_cm = convert_data_format(df_cm, col_name_op)
df_cm = convert_data_format(df_cm, manually_tagged)

count_context_technologies = []

for i in range(0, len(df_cm)):
    count_context_technologies.extend(df_cm[manually_tagged][i])
d = list(set(count_context_technologies))

tp = []
tn = []
fp = []
fn = []
TP = TN = FP = FN = 0
df_cm[manually_tagged] = df_cm[manually_tagged].fillna('[]')

df_cm['Eng_Label']=df_cm[manually_tagged].copy()

tech_tag_list = []

df_cm['Eng_Label'] = df_cm.apply(
    lambda x: get_tech_tagged_data(x["Eng_Label"], eng_list),
    axis = 1)
list_tech_dataset = []

# fill with 
for i in range(0, len(df_cm)):
    list_tech_dataset.extend(df_cm["Eng_Label"][i])

set_tech = set(list_tech_dataset)

for i in range(0, len(df_cm)):
    l = df_cm[col_name_op][i]
    df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

for i in range(0, len(df_cm)):
  words = df_cm[col_name_op][i]
  stopwords = [0]
  for word in list(words):
    if word in stopwords:
      words.remove(word)

# list of technologies which are not in extracted list but are in tagged list i.e. FN entries
df_cm['FP_entries_eng'] = df_cm.apply(lambda x: Diff(x["Eng_Label"], x[col_name_op]), axis = 1)

# list of technologies which are in extracted list and are in tagged list i.e. TP entries
df_cm['TP_entries_eng'] = df_cm.apply(lambda x: Same(x["Eng_Label"], x[col_name_op]), axis = 1)

# list of technologies which are NOT extracted list and are in tagged list i.e. FN entries
df_cm['FN_entries_eng'] = df_cm.apply(lambda x: Common(x["Eng_Label"], x[col_name_op]), axis = 1)

fp_entry =[]
tp = get_TP(df_cm, "Eng_Label", col_name_op)
fp, fp_entry_names = get_FP(df_cm, "Eng_Label", col_name_op)
fn = get_FN(df_cm, "Eng_Label", col_name_op)
# print(len(tp), len(fp), len(fn))
dict_fp = {}

for i in range(0, len(fp_entry_names)):
    fp_entry_names[i] = fp_entry_names[i].tolist()
    dict_fp[i] = fp_entry_names[i]

# creating a dataframe
df_matrix = pd.DataFrame(list(zip(tp, fp, fn)), 
               columns =['TP', 'FP', "FN"])
df_matrix['Precision'] = df_matrix.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

df_matrix["Recall"] = df_matrix.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

df_matrix["f_score"] = df_matrix.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

final_data = df_cm.join(df_matrix)
final_data.to_csv("ACC-BERT_preds_JOB_id_ENG_ONLY2july.csv",index=False) ##########GIVE ENG ACC NAME############
# Out:
# ['vmware', 'citrix', 'xenapp']
# ['vmware', 'solarwinds']
# ['airwatch’s', 'vmware']
# ['docker', 'vmware', 'intel']
# ['vmware', 'linux.', 'linux']
# ['adobe', 'adobe illustrator']
# ['synechron.', 'vmware', 'linux']
# ['adobe', 'word;', 'adobe illustrator']
# ['support']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['microsoft', 'adobe', 'adobe illustrator', 'microsoft office']
# ['java/j2ee', 'vmware', 'citrix)']
# ['vmware']
# ['citrix', 'vmware', 'java', 'ios', 'bomgar']
# ['vmware']
# ['vmware']
# ['citrix', 'microsoft', 'vmware']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['adobe', 'adobe illustrator', 'sharepoint']
# ['vmware', 'camtasia.']
# ['microsoft', 'microsoft outlook', 'adobe', 'adobe illustrator', 'office']
# ['vmware']
# ['vmware']
# ['citrix', 'vmware', 'ibm']
# ['azure', 'vmware', 'okta', 'quantum']
# ['connectpro', 'adobe', 'camtasia', 'adobe illustrator']
# ['paypal', 'vmware', 'google', 'oculus', 'ebay']
# ['snagit', 'blackberry', 'adobe', 'adobe illustrator']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['vmware']
# ['vmware']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# ['vmware', 'vmw)']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'pivotal.']
# ['nunit', 'vmware', 'the']
# ['vmware']
# ['citrix', 'vmware']
# ['jquery', 'sharepoint', 'adobe', 'adobe illustrator', 'javascript']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['microsoft office', 'html', 'adobe', 'google analytics', 'adobe illustrator']
# ['xen', 'vmware', 'drp']
# ['vmware', 'vblock', 'intel.', 'silicon', 'turnkey']
# ['vmware']
# ['eclipse', 'vmware', 'java', 'workbench', 'springone', 'vmworld']
# ['vmware', 'commvault']
# ['vmware']
# ['vmware']
# ['vmware']
# ['xp', 'dell', 'vmware']
# ['java', 'vms']
# ['vmware', 'zabbix', 'linux']
# ['netapp', 'vmware']
# ['dell', 'vmware', 'ibm.']
# ['netapp', 'vmware', 'runbook']
# ['vmware', 'microsoft']
# ['vmware', 'otus.']
# ['angularjs', 'android', 'heroku', 'mongodb']
# ['dell', 'citrix', 'vmware', 'ios', 'blackberry']
# ['vmware', 'java', 'powershell', 'salesforce.com', 'perl', 'packettrap']
# ['windows', 'netmeeting.']
# ['citrix', 'vmware']
# ['citrix', 'vmware']
# ['citrix', 'vmware']
# ['adobe', 'adobe illustrator']
# ['dell', 'microsoft', 'vmware', 'ibm']
# ['adobe', 'adobe illustrator']
# ['kofax', 'microsoft', 'citrix', 'vmware', 'fortinet']
# ['vmware']
# ['vmware']
# ['linux', 'vmware', 'java', 'zenoss.', 'nimbula', 'centos']
# []
# ['vmware']
# ['vmware']
# ['dell', 'vmware']
# ['google', 'adobe', 'adobe illustrator']
# ['rails', 'spring', 'java', 'scala', 'rails.', 'mongodb', 'rabbitmq']
# ['ruby rails', 'html', 'sphinx', 'mysql', 'javascript']
# ['vmware']
# ['vmware']
# ['netapp', 'vmware']
# ['vmware', 'hitachi', 'ibm']
# []
# ['vmware']
# ['vmware', 'optimus', 'ibm']
# ['citrix', 'vmware', 'linux']
# ['cloudfront', 'adobe', 'zendesk', 'adobe illustrator']
# ['vmware', 'eclipse']
# ['netapp.', 'vmware']
# ['quark', 'adobe', 'adobe illustrator']
# ['netapp', 'vmware', 'sharepoint', 'xendesktop', 'microsoft dynamics.', 'dell']
# ['vmware', 'vmw)']
# ['python', 'django', 'javascript', 'mongodb', 'rabbitmq']
# ['vmware']
# ['vmware', 'microsoft']
# ['vmware']
# ['vmware', 'windows']
# ['vmware']
# ['vmware', 'cisco']
# ['vmware']
# ['python', 'docker', 'rabbitmq']
# ['vmware', 'oracle', 'cacti', 'postfix']
# ['openstack.']
# ['vmware', 'vmware:']
# ['citrix', 'appsense', 'vmware']
# ['xenserver', 'microsoft', 'linux', 'citrix', 'vmware', 'centos', 'access']
# ['vmware', 'google', 'vm', 'xen.', 'ibm']
# ['linux', 'vmware', 'java', 'mysql', 'jboss']
# ['adobe', 'adobe illustrator']
# ['fusion', 'vmware']
# ['vmware']
# ['vmware']
# ['citrix', 'vmware', 'xenapp']
# ['vmware']
# ['vmware']
# []
# ['vmware']
# ['citrix', 'juniper', 'vmware', 'linux']
# ['citrix', 'juniper', 'vmware', 'linux']
# ['microsoft', 'netware', 'vmware', 'aruba', 'veeam']
# ['microsoft office', 'html', 'drupal', 'google', 'php', 'wordpress.', 'adobe', 'adobe illustrator', 'javascript']
# ['vmware', 'the']
# ['vmware']
# ['excel', 'microsoft', 'vmware', 'sharepoint', 'quickbooks']
# ['altiris', 'vmware', 'linux']
# ['vmware']
# ['react-native', 'javascript)', 'ethereum', 'scala)', 'docker', 'redux']
# ['vmware', 'microsoft', 'sharepoint']
# ['vmware']
# ['citrix', 'microsoft', 'vmware']
# ['vmware']
# ['adobe', 'html', 'adobe illustrator']
# ['vmware', 'microsoft']
# ['vmware']
# ['php', 'mysql', 'jquery', 'ios']
# ['linux', 'netapp', 'vmware', 'xen', 'ibm']
# ['citrix', 'microsoft', 'vmware']
# ['vmware', 'spring']
# ['vmware', 'windows xp']
# ['netapp', 'vmware']
# ['vmware']
# ['dell', 'vmware']
# ['netapp', 'citrix', 'vmware']
# ['vmware']
# ['adobe', 'camtasia', 'adobe illustrator']
# ['vmware', 'dynamics']
# ['ios/exchange/good', 'casper', 'vmware', 'xecs', 'ios']
# ['vmware', 'drobopro', 'linux']
# ['microsoft', 'android', 'vmware', 'ios', 'adobe', 'mysql', 'adobe illustrator', 'apache']
# ['drobo', 'vmware', 'linux', 'casper']
# ['vmware', 'microsoft']
# ['channelwave', 'qwest', 'logitech', 'channelwave.', 'covad']
# []
# ['vmware', 'altiris']
# ['vmware', 'php', 'java', 'linux']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'gemstone']
# ['vmware', 'gemstone']
# ['microsoft', 'server', 'netapp', 'citrix', 'vmware', 'microsoft.', 'ibm']
# ['symfony', 'vagrant', 'elasticache']
# ['linux', 'vmware', 'java', 'dbms', 'debian']
# ['microsoft', 'dell.', 'eventus', 'citrix', 'vmware']
# ['google', 'ruby', 'rails']
# ['vmware', 'cisco']
# ['vmware']
# ['javascript']
# ['java']
# ['citrix', 'microsoft', 'vmware']
# ['linux aix', 'microsoft', 'vmware', 'ibm']
# ['redis', 'sphinx', 'ruby', 'mysql', 'node.js', 'rabbitmq']
# ['vmware', 'vmware’s']
# ['vmware', 'windows']
# ['a daily', 'in']
# ['vmware', 'intel']
# ['office']
# ['vmware', 'linux']
# ['vmware']
# ['citrix', 'vmware']
# ['safari', 'microsoft', 'shoretel', 'vmware']
# ['vmware']
# ['vmware']
# ['java']
# ['vmware', 'ios’s']
# ['vmware', 'microsoft']
# ['linux']
# ['vmware', 'navel']
# ['dell', 'vmware', 'nutanix']
# ['vmware', 'microsoft']
# ['mysql)', 'haproxy', 'mysql', 'zend']
# ['bootstrap', 'jquery', 'html', 'mysql', 'zend']
# ['openstack', 'xen', 'vmware', 'playscreen', 'ios', 'ubuntu', 'mysql', 'vm’s', 'apache']
# ['adobe', 'adobe illustrator']
# ['jenkins/jobdsl', 'postgresql', 'scalatests', 'redis', 'spring', 'java', 'spock', 'scala', 'angularjs', 'docker', 'ansible', 'react', 'rabbitmq']
# ['jenkins/jobdsl', 'redis', 'java', 'elasticsearch', 'docker', 'ansible', 'mongodb', 'rabbitmq']
# ['adobe', 'adobe illustrator']
# ['kvm', 'appliances', 'deploy', 'and']
# ['vmware', 'microsoft']
# ['adobe', 'adobe illustrator']
# ['solarwinds.', 'vmware']
# ['vmware', 'activision']
# ['vmware']
# ['word', 'adobe', 'filemaker', 'adobe illustrator', 'powerpoint']
# ['microsoft', 'sharepoint']
# ['citrix', 'vmware', 'ibm']
# ['netapp', 'citrix', 'vmware']
# ['linux', 'nginx', 'redis', 'jenkins.', 'ansible-pull', 'jenkins', 'elasticsearch', 'mysql', 'playbooks', 'php', 'ansible', 'mongodb', 'node.js', 'rabbitmq']
# ['xen', 'citrix', 'vmware', 'ibm']
# ['vmware']
# ['dell', 'amulet', 'vmware']
# ['vmware']
# ['perl', 'dell', 'vmware']
# ['netapp', 'vmware', 'perl', 'chroot', 'ibm']
# ['xen', 'vmware', 'linux']
# ['vmware', 'linux']
# ['vmware', 'microsoft']
# ['vmware']
# ['angularjs', 'spring', 'vmware', 'postgres']
# ['nodejs', 'splunk', 'rabbitmq']
# ['postgresql', 'java', 'ruby', 'erlang', 'rabbitmq']
# ['vmware', 'adobe', 'adobe illustrator', 'intel']
# ['vmware']
# ['vmware']
# ['vmware', 'intel', 'opus']
# ['vmware', 'barilla', 'sharepoint']
# ['vmware', 'jboss', 'linux']
# ['microsoft', 'microsoft exchange', 'vmware', 'windows', 'mysql', 'dell', 'postgresql.']
# ['vmware', 'uitgevers']
# ['vmware', 'ibm']
# ['vmware']
# ['vmware', 'avamar']
# ['vmware']
# ['vmware', 'functie']
# ['vmware']
# ['vmware', 'ibm']
# ['vmware', 'selenium']
# ['html\\\\css', 'microsoft', 'rabbitmq']
# ['vmware', 'linux', 'netware']
# ['vmware', 'vmware.']
# ['vmware', 'skypoint']
# ['vmware', 'linux']
# ['illumina', 'clients']
# ['vmware', 'microsoft server', 'microsoft exchange']
# ['vmware', 'adobe', 'adobe illustrator', 'microsoft']
# ['citrix', 'vmware', 'linux']
# ['microsoft', 'netapp', 'vmware', 'servicenow', 'ibm']
# ['microsoft', 'linux', 'vmware', 'google', 'azure']
# ['vmware', 'celerra', 'linux']
# ['vmware', 'microsoft']
# ['vmware']
# ['java', 'junit']
# ['vmware', 'servicenow', 'linux', 'docker)']
# ['vmware', 'linux']
# ['vmware']
# ['vmware']
# ['citrix', 'vmware', 'microsoft share', 'xp']
# ['citrix', 'vmware', 'ironport']
# ['vmware', 'ical']
# ['vmware', 'cloudvolumes.']
# ['xerox)', 'sharepoint']
# ['linux', 'listserv', 'vmware', 'dynamics', 'nols.', 'mysql', 'centos.', 'apache']
# ['tintri', 'microsoft', 'netapp', 'vmware', 'commvault']
# ['openstack.with', 'rackspace']
# ['gnu/linux', 'vmware']
# ['vmware']
# ['vmware', 'vms']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['microsoft dynamics', 'microsoft', 'exchange', 'vmware', 'office']
# ['linux', 'vmware', 'mysql', 'perl', 'php', 'apache']
# ['citrix', 'mysql', 'vmware', 'linux']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['ruby', 'rails', 'linux', 'rabbitmq']
# ['vmware']
# ['microsoft', 'radius', 'vmware', 'powershell', 'azure.', 'azure']
# ['spring', 'java', 'ios', 'rabbitmq']
# ['vmware', 'microsoft']
# ['vmware', 'microsoft']
# ['vmware', 'microsoft', 'quest', 'microsoft exchange']
# ['utm', 'vmware']
# ['vmware', 'microsoft', 'altiris', 'windows xp']
# ['vmware', 'vmware.']
# ['vmware', 'azure).']
# ['rabbitmq', 'spring', 'apache', 'kronos']
# ['rabbitmq', 'spring', 'apache', 'kronos']
# ['hive', 'python', 'kubernetes', 'celery', 'spark', 'rabbitmq']
# ['nginx', 'cache', 'mysql', 'elastic']
# ['nodejs', 'nginx', 'terraform', 'mysql', 'docker', 'ansible']
# ['nodejs', 'nginx', 'elasticsearch', 'mysql', 'elastic', 'docker']
# ['rails', 'linux', 'redis', 'vmware', 'ruby', 'mysql', 'xtradb', 'rails.', 'apache', 'postfix']
# ['vmware']
# ['mysql', 'elastic']
# ['vmware']
# ['vmware', 'microsoft', 'microsoft exchange']
# ['jenkins.', 'the', 'cloudwatch)', 'verizon']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware', 'mysql']
# ['netapp', 'vmware', 'sharepoint', 'azure', 'dell']
# ['azure', 'vmware', 'netapp', 'sharepoint']
# ['netapp', 'vmware', 'playbook']
# ['vmware', 'microsoft']
# ['vmware']
# ['html', 'adobe', 'mysql', 'javascript', 'adobe illustrator', 'php']
# ['vmware']
# ['vmware', 'mailbox']
# ['microsoft', 'express', 'vmware', 'symantec', 'mailbox']
# ['vmware', 'juniper', 'veeam']
# ['microsoft', 'vmware', 'adobe', 'adobe illustrator', 'ibm']
# ['vmware', 'teradata', 'linux']
# ['xen', 'vmware', 'java', 'linux']
# ['vmware']
# ['citrix', 'microsoft', 'veeam', 'vmware']
# ['microsoft', 'citrix', 'vmware', 'zimbra', 'veeam']
# ['windows xp/7', 'windows', 'vmware']
# ['vmware']
# ['linux', 'netbackup', 'vmware', 'netapp/emc', 'dell/netapp/emc/cray']
# ['vmware']
# ['vmware']
# ['selenium', 'vmware', 'java', 'db2', 'java.']
# ['sonicwall', 'shoretel', 'veeam', 'vmware']
# ['vmware', 'windows', 'veeam']
# ['vmware', 'java/ejb/jms', 'postgresql']
# ['vmware']
# ['dell', 'vmware']
# ['vmware']
# ['vmware', 'airwatch']
# ['microsoft', 'openstack', 'linux', 'vmware', 'gitlab', 'linux-based', 'samba']
# ['vmware', 'udp', 'the']
# ['vmware', 'udp', 'microsoft exchange.', 'directory']
# ['android)', 'selenium', 'xp', 'vmware', 'ubuntu', 'openqa', 'firefox']
# ['vmware']
# ['vmware', 'bladecenter', 'ibm']
# ['meteor', 'vmware', 'meteor.']
# ['vmware', 'airwatch']
# ['dell', 'vmware']
# ['vmware']
# ['vmware']
# ['adobe', 'microsoft word excel powerpoint outlook', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'worksite', 'microsoft office']
# ['sonicwall', 'microsoft', 'splunk', 'vmware', 'linux-centos', 'vmax', 'solarwinds']
# ['vmware', 'fedora', 'ubuntu', 'ibm']
# ['vmware']
# ['vmware', 'microsoft', 'veeam', 'fortinet']
# ['vmware']
# ['linux)', 'vmware', 'hudson', 'jenkins', 'sprint']
# ['vmware', 'ibm']
# ['cisco', 'kepner', 'vmware', 'cognos', 'tregoe', 'xp/2000/vista/win7.', 'togaf', 'blackberry']
# ['python', 'java', 'heroku', 'scala', 'ruby', 'kubernetes', 'rabbitmq']
# ['vmware', 'veeam']
# ['vmware']
# ['blackberry', 'arconis', 'vmware']
# ['dell', 'vmware']
# ['presidio’s', 'ironport', 'netapp', 'vmware', 'fortinet']
# ['citrix', 'vmware', 'xendesktop']
# ['vmware']
# ['vmware']
# []
# ['netapp.', 'vmware', 'ibm']
# ['citrix', 'powershell)', 'vmware', 'xendesktop', 'dell']
# ['share', 'microsoft', 'vmware', 'microsoft office']
# ['adobe', 'microsoft office: excel powerpoint word', 'adobe illustrator']
# ['vmware', 'bladecenter', 'cisco', 'ibm']
# ['netapp', 'vmware', 'ontap']
# ['microsoft', 'microsoft office', 'vmware', 'office', 'dell']
# ['cloudwatch', 'docker', 'terraform']
# ['citrix', 'tam', 'vmware', 'intel', 'microsoft.', 'intel’s']
# ['citrix', 'vmware']
# ['kotlin.', 'spring', 'java', 'elasticsearch', 'mockito', 'mysql', 'kotlin', 'docker', 'javascript', 'junit']
# ['angular', 'python', 'bootstrap.', 'kubernetes', 'docker', 'javascript']
# ['postgresql', 'redis', 'java', 'angularjs', 'docker', 'mongodb', 'rabbitmq']
# ['linux', 'citrix', 'vmware', 'java', 'javascript']
# ['quickbooks', 'azure.', 'macbooks', 'microsoft office']
# ['vmware', 'android']
# ['vmware', 'altiris', 'kronos']
# ['snapdeal', 'flipkart', 'scala', 'google', 'magento', 'azure']
# ['vmware', 'microsoft server', 'java/tomcat', 'server']
# ['zendesk', 'trello.', 'vmware', 'dropbox', 'browserstack', 'wrike']
# ['sonicwall', 'wordpress', 'vmware', 'php', 'veeam', 'connectwise']
# ['windows xp', 'vmware', 'adobe', 'windows', 'adobe illustrator', 'office']
# ['microsoft', 'android', 'microsoft exchange', 'xp', 'citrix', 'vmware', 'blackberry', 'xenapp']
# ['php', 'laravel-based']
# ['microsoft', 'vmware', 'sharepoint', 'dell', 'fortinet']
# ['citrix', 'vmware']
# ['citrix', 'vmware']
# ['vmware', 'vm']
# ['vmware', 'directory', 'microsoft sql server', 'microsoft exchange']
# ['vmware']
# ['vmware', 'microsoft', 'linux']
# ['mitel', 'sonicwall', 'vmware']
# ['vmware', 'windows']
# ['cloudera', 'java-', 'nginx', 'vmware', 'java', 'scala', 'jenkins', 'python-', 'mongodb', 'apache', 'rabbitmq']
# ['netapp', 'vmware', 'vms.']
# ['vmware']
# ['xp', 'vmware', 'db2']
# ['linux']
# ['vmware']
# ['vmware']
# ['messagepack', 'docker.', 'postgresql', 'rails', 'redis', 'peek', 'ruby', 'google.', 'sidekiq', 'mongodb', 'rabbitmq']
# ['rails', 'openid', 'redis', 'zeromq', 'ruby', 'sidekiq', 'linden', 'mongodb', 'rabbitmq']
# ['microsoft', 'architeure', 'vmware', 'wonderware', 'kepware']
# ['redis', 'php', 'javascript', 'react', 'node.js', 'rabbitmq']
# ['asterisk', 'vmware']
# ['vmware']
# ['vmware', 'microsoft cloud']
# ['vmware', 'windows', 'windows xp']
# ['sonicwall', 'vmware', 'adobe', 'adobe illustrator', 'dell']
# ['microsoft', 'microsoft exchange', 'ironport', 'netapp', 'vmware', 'mailmeter', 'sharepoint', 'dell']
# ['android)', 'microsoft', 'microsoft exchange', 'vmware', 'access']
# ['citrix', 'microsoft', 'vmware']
# []
# ['vmware']
# ['vmware', 'informix', 'oracle']
# ['shoretel', 'microsoft', 'vmware', 'xenapp']
# ['vmware', 'microsoft', 'exchange']
# ['vmware', 'snapfish']
# ['vmware', 'windows']
# ['vmware', 'microsoft server sql.']
# ['janusgraph', 'redis', 'java', 'mongodb', 'elasticsearch.', 'elasticsearch', 'cassandra', 'dyno', 'apache']
# ['dell', 'vmware', 'dells']
# ['vmware', 'sharepoint']
# ['microsoft', 'netbackup', 'vmware', 'tanner', 'veeam']
# ['vmware']
# ['sonicwall', 'vmware']
# ['vmware', 'microsoft']
# [')', 'vmware']
# ['vmware']
# ['splunk', 'netapp', 'vmware', 'commvault', 'sophos']
# ['vmware']
# ['vmware', 'xenapp']
# ['teradici', 'android)', 'linux', 'vmware', 'ios', 'dell']
# []
# ['adobe', 'adobe illustrator']
# ['microsoft exchange', 'vmware', 'kronos', 'office', 'thinclient', 'blackberry']
# []
# ['vmware', 'microsoft']
# ['adobe', 'adobe illustrator']
# ['vmware', 'android']
# ['azure', 'guavus.', 'vmware', 'xen']
# ['vmware', 'linux', 'vm']
# ['vmware']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['netapp', 'vmware', 'vmware.', 'vm']
# ['vmware']
# ['dell', 'vmware', 'outlook']
# ['vmware']
# ['redis', 'spring', 'java', 'elasticsearch', 'mysql', 'javascript', 'mongodb', 'rabbitmq']
# ['vmware']
# ['vodafone', 'mastercard', 'litmus.', 'dropbox']
# ['vmware', 'linux']
# ['citrix', 'blackberry', 'vmware']
# ['postman', 'postgresql', 'python', 'nginx', 'redis', 'java', 'acl', 'django', 'rabbitmq']
# []
# ['dell', 'vmware', 'ibm']
# ['vmware', 'citrix', 'xenapp', 'acronis']
# ['dell', 'commvault', 'vmware']
# ['linux', 'xp', 'vmware', 'zenworks', 'ios', 'windows']
# []
# ['adobe', 'adobe illustrator']
# ['postgres.', 'redis', 'vmware', 'java', 'elasticsearch.', 'cassandra', 'node.js']
# ['vmware']
# ['sonicwall', 'asterisk', 'vmware', 'zabbix.', 'radware', 'netskope', 'sophos', 'dell', 'veeam']
# ['hp', 'node', 'linux', 'vmware', 'netvault']
# ['node', 'linux', 'xp', 'vmware', 'serviceguard']
# ['asterisk', 'vmware', 'linux']
# ['netapp', 'microsoft', 'sharepoint']
# ['db2', 'ibm']
# ['vmware', 'microsoft', 'android', 'dmz']
# ['xen', 'vmware', 'linux/unix', 'freebsd']
# ['cisco', 'vmware', 'java', 'ios', 'centos', 'ibm']
# ['hive', 'kerberos.', 'hadoop', 'zookeeper', 'java']
# ['adobe', 'html', 'adobe illustrator']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['mongo', 'db', 'oracle', 'rabbitmq']
# ['vmware', 'hp']
# ['vmware', 'centoos', 'microsoft', 'debian']
# ['postgresql', 'xen', 'wireshark', 'citrix', 'vmware', 'snort', 'ubuntu', 'zabbix.', 'mysql', 'debian', 'apache']
# ['sonicwall', 'vmware']
# ['microsoft office', 'html', 'joomla', 'adobe', 'adobe illustrator']
# ['clojure', 'postgresql', 'python', 'scikit', 'scala', 'docker', 'droidcon']
# ['netapp', 'vmware', 'codeignitor', 'javascript).']
# ['vmware', 'linux/windows/solaris.', 'linux']
# ['vmware', 'alcatel', 'juniper']
# ['vmware', 'microsoft', 'ibm']
# ['dell', 'microsoft', 'appspace', 'office']
# ['snapshot', 'citrix', 'vmware', 'juniper', 'ibm']
# ['vmware', 'windows', 'microsoft']
# ['vmware', 'vms']
# ['linux', 'bugzilla', 'vmware', 'apache']
# ['vmware', 'powershell']
# ['vmware', 'microsoft']
# ['vmware']
# ['aruba', 'juniper', 'vmware', 'fortinet)']
# ['linux', 'postgresql', 'vmware', 'ubuntu)', 'mysql', 'centos', 'apache']
# ['vmware', 'dell', 'solarwinds', 'xenapp']
# ['citrix', 'vmware', 'xenapp', 'dell', 'solarwinds']
# ['citrix', 'dell', 'vmware']
# ['vmware', 'sharepoint']
# ['vmware']
# ['vmware']
# ['10g', 'spring', 'swift)', 'java', 'perl', 'azure', 'mongodb', 'apache']
# ['vmware', 'linux']
# ['meraki', 'vmware']
# ['sonicwall', 'mysap', 'juniper', 'vmware']
# ['vmware']
# ['splunk', 'jboss.', 'postgresql', 'cloudwatch', 'jenkins.', 'github', 'ios', 'heroku', 'bitbucket', 'mysql', 'dbs.', 'docker']
# ['vmware', 'mailbox']
# ['vmware', 'bladelogic', 'vm’s']
# ['vmware']
# ['hp', 'bladelogic.', 'vmware', 'bladelogic', 'vm’s']
# ['vmware', 'github', 'puppet']
# ['vmware', 'ibm']
# ['dynamics']
# ['vmware']
# ['adobe', 'adobe illustrator', 'microsoft office']
# ['adobe', 'adobe illustrator', 'microsoft office']
# ['outlook', 'microsoft word excel', 'adobe', 'adobe illustrator']
# ['citrix’', 'vmware', 'microsoft', 'vmware)']
# ['vmware']
# ['vmware', 'fedora', 'debian', 'ubuntu']
# ['the', 'adobe', 'adobe illustrator', 'autodesk', 'wheelhouse:']
# ['xen', 'vmware', 'microsoft']
# ['elasticache)', 'docker', 'java', 'springboot']
# ['netapp', 'vmware']
# ['vmware', 'windows', 'microsoft exchange']
# ['vmware', 'sonicwall', 'veeam', 'dell']
# ['vmware', 'microsoft', 'ibm']
# ['xp', 'microsoft', 'symantec', 'microsoft exchange']
# ['vmware']
# ['vmware']
# ['netapp']
# ['vmware', 'ibm’s', 'analytics', 'ibm']
# ['redis', 'redux-observable', 'mongodb', 'jenkins', 'elasticsearch', 'node.js', 'mongoose', 'docker', 'redux', 'react', 'codebuild']
# ['netapp', 'vmware', 'microsoft server']
# ['jenkins', 'mysql', 'erlang', 'riak', 'rabbitmq']
# ['jenkins', 'erlang', 'riak', 'azure', 'rabbitmq']
# ['jenkins', 'erlang', 'riak', 'azure', 'rabbitmq']
# ['vmware']
# ['microsoft', 'windows']
# ['vmware']
# ['packer', 'cloudwatch', 'elasticsearch', 'ansible', 'mongodb']
# ['vmware', 'microsoft', 'java', 'adsl']
# ['splunk', 'linux', 'vmware', 'vms', 'mysql']
# ['vmware']
# ['microsoft', 'windows xp', 'microsoft office', 'vmware', 'sharepoint', 'dell']
# []
# ['vmware']
# []
# ['citrix', 'vmware', 'nutanix']
# ['vmware', 'microsoft']
# []
# ['onyx', 'vmware']
# ['python', 'ruby', 'ruby).', 'java']
# ['mysql', 'rabbitmq']
# ['python', 'vmware', 'perl', 'angular.js', 'node.js']
# ['vmware', 'bugzilla', 'mysql']
# ['vmware', 'microsoft', 'zabbix']
# ['vmware', 'redis', 'gitlab.', 'jenkins', 'nagios.', 'mongodb']
# ['vmware', 'microsoft', 'gitlab', 'zabbix']
# ['microsoft', 'xp', 'vmware', 'powershell', 'office', 'mailmarshall']
# ['vmware', 'linux']
# ['vmware', 'nagios', 'apache']
# ['vmware', 'linux']
# ['citrix', 'vmware']
# ['vmware', 'sage']
# ['citrix', 'vmware']
# ['azure', 'docker', 'omnichannel']
# ['vmware', 'ios', 'mysql', 'php', 'apache']
# ['vmware', 'microsoft', 'linux']
# ['google', 'vmware', 'node']
# ['grafana', 'rundeck', 'jenkins', 'elasticsearch', 'sprint', 'graphite']
# ['vmware', 'vms']
# ['10g', 'cognos', 'vmware']
# ['vmware', 'mysql']
# ['linux', 'microsoft', 'vmware', 'drp']
# ['netapp', 'vmware', 'solarwinds']
# ['netapp', 'vmware']
# []
# ['vmware', 'drp']
# ['vmware']
# ['vmware', 'sharepoint']
# ['netapp', 'vmware', 'sharepoint', 'windows xp']
# ['tupy', 'citrix', 'vmware', 'sharepoint', 'ibm']
# ['vmware']
# ['vmware']
# ['microsoft', 'vmware', 'powershell', 'windows', 'office', 'veeam']
# ['vmware']
# ['microsoft', 'vmware', 'powershell', 'windows', 'office', 'veeam']
# ['powershell', 'vmware', 'windows', 'veeam']
# ['vmware', 'emulex']
# ['revenue']
# ['webapi', 'gitlab', 'elasticsearch', 'couchbase', 'rabbitmq']
# ['vmware', 'ibm']
# ['vmware', 'microsoft']
# ['citrix', 'vmware', 'linux']
# ['vmware', 'linux']
# ['vmware']
# ['netapp', 'vmware', 'mysql', 'linux']
# ['vmware']
# ['vmware', 'microsoft exchange', 'office']
# ['vmware', 'microsoft', 'intel']
# ['bitbucket', 'scala', 'jenkins', 'angularjs', 'symfony', 'php', 'rabbitmq']
# ['vmware']
# ['vmware', 'sas.', 'linux.', 'linux']
# ['dell', 'vmware']
# ['microsoft sql.', 'nodejs', 'rabbitmq']
# ['vmware', 'vm']
# ['citrix', 'vmware', 'xenapp']
# ['moodle)', 'asterisk', 'microsoft', 'linux', 'qemu/kvm', 'vmware', 'wordpress)', 'drupal', 'joomla', 'papercut', 'sentora', 'cacti', 'fortinet', 'clonezilla']
# ['perl', 'vmware', 'ibm']
# ['vmware']
# []
# ['vmware', 'ibm']
# ['vmware']
# ['vmware', 'ibm']
# ['microsoft', 'microsoft exchange', 'linux', 'windows xp', 'vmware']
# ['react/flux', 'heroku.', 'node.js', 'rabbitmq']
# ['vmware', 'airwatch']
# ['dell', 'vmware', 'linux']
# ['using', 'isa/tmg', 'portals', 'to']
# ['contegix', 'vmware', 'kickstart']
# ['quark', 'adobe', 'adobe illustrator']
# ['vmware', 'commvault']
# ['microsoft', 'microsoft exchange', 'citrix', 'vmware', 'xenapp']
# ['splunk', 'jquery', 'paypal', 'rabbitmq']
# ['linux', 'python', 'redis', 'spring', 'mysql', 'java/j2ee', 'rabbitmq']
# ['vmware']
# []
# ['asterisk', 'netsuite', 'vmware', 'quickbooks', 'freepbx']
# ['citrix', 'vmware', 'xendesktop']
# ['microsoft', 'citrix', 'vmware', 'xendesktop', 'xenapp']
# ['citrix', 'microsoft', 'vmware']
# ['vmware', 'microsoft', 'vmotion', 'vm']
# ['vmware']
# ['microsoft', 'netapp', 'citrix', 'vmware', 'adobe', 'adobe illustrator', 'fortinet']
# ['vmware', 'linux']
# ['vmware']
# ['spring', 'java', 'scala', 'jenkins', 'mysql', 'docker', 'rabbitmq']
# ['microsoft', 'linux', 'database', 'vmware', 'microsoft sql server', 'ibm']
# ['ruby rails', 'android', 'rails', 'vmware', 'swift', 'ios']
# ['vmware', 'sharepoint']
# ['citrix', 'vmware', 'linux']
# ['vmware', 'vm']
# ['netapp', 'vmware']
# ['microsoft', 'netbackup', 'vmware', 'cacti', 'symantec', 'ibm']
# ['microsoft exchange', 'xp', 'citrix', 'vmware', 'mychart']
# ['vmware', 'linux', 'ibm']
# ['python', 'terraform', 'ansible', 'vmware']
# ['vmware', 'netscaler']
# ['adobe', 'adobe illustrator']
# ['vmware', 'java', 'microsoft exchange']
# ['vmware']
# ['python', 'java', 'cloudwatch)', 'elastic', 'athena', 'javascript', 'react']
# ['siteminder', 'vmware']
# ['microsoft', 'netware', 'vmware', 'html', 'db2']
# ['vmware', 'veeam', 'vm']
# ['adobe', 'adobe illustrator']
# ['vmware', 'thinapp']
# ['vmware']
# ['vmware']
# ['mongodb', 'rabbitmq']
# ['vmware', 'microsoft']
# ['adobe', 'adobe illustrator']
# ['vmware', 'risc', 'aruba', 'juniper', 'radware.']
# ['dell', 'microsoft', 'vmware']
# ['vmware']
# ['dell', 'microsoft', 'vmware', 'directory']
# ['solution', 'including', 'access']
# ['\\uf0a7']
# []
# ['vmware', 'windows', 'server']
# ['vmware']
# ['vmware', 'sharepoint']
# ['vmware']
# ['sophos', 'vmware', 'microsoft azure.', 'veeam']
# ['vmware', 'microsoft exchange']
# ['vmware']
# ['vmware', 'powershell', 'veeam', 'nutanix']
# ['vmware', 'veeam']
# ['vmware']
# ['citrix', 'vmware']
# ['citrix', 'dell', 'vmware']
# ['citrix', 'vmware', 'xenapp', 'ibm']
# ['vmware']
# ['azure', 'vmware']
# ['environment', 'in']
# ['rails', 'nginx', 'ruby', 'kubernetes', 'mysql/aurora', 'react']
# ['vmware', 'microsoft', 'linux', 'ibm']
# ['cloudwatch', 'nginx', 'redis', 'cloudfront', 'magento', 'php']
# ['vmware']
# ['citrix', 'vmware']
# ['zoomdata', 'lucidchart', 'linux', 'python', 'snowball', 'mysql', 'redshift', 'dbs']
# ['vmware', 'radius', 'vm']
# ['vmware', 'server)', 'dynamics']
# ['citrix', 'intelex', 'vmware']
# ['microsoft', 'linux', 'vmware', 'ios', 'acceleration']
# ['xp', 'vmware', 'zenworks']
# ['vmware', 'opuscapita', 'ibm']
# ['vmware', 'netware']
# ['vmware', 'microsoft exchange']
# ['autodesk', 'windows', 'vmware']
# ['vmware']
# ['vmware']
# ['linux', 'nginx', 'vmware', 'mysql', 'php', 'apache']
# ['saltstack', 'citrix', 'gitlab)', 'vmware']
# ['vmware', 'linux']
# ['dell', 'microsoft', 'vmware', 'office']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['microsoft', 'splunk', 'vmware', 'powershell', 'solarwinds']
# ['vmware']
# ['vmware']
# ['10g', 'vmware']
# ['citrix', 'dbas', 'vmware', 'linux']
# ['linux', 'hudson', 'vmware', '10g/11g', 'j2ee', 'apache)']
# ['microsoft', 'microsoft office 365', 'linux', 'netapp', 'vmware', 'juniper']
# ['vmware']
# ['vmware', 'microsoft', 'office']
# ['debian.', 'cloudwatch', 'fedora', 'ubuntu', 'centos', 'ibm']
# ['vmware', 'microsoft server']
# ['vmware', 'turnkey', 'papillon', 'xyka']
# ['spotify', 'rabbitmq']
# ['microsoft', 'xp', 'vmware', 'vxrail', 'dell']
# ['html', 'adobe', 'adobe illustrator', 'hootsuite', 'php']
# ['vmware', 'microsoft']
# ['citrix', 'dell', 'vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'mysql']
# ['vmware-accenture', 'vmware', 'vmware-ibm', 'accenture-vmware', 'ibm-vmware']
# ['vmware']
# ['vmware', 'linux.']
# ['vmware', 'wireshark', 'linux']
# ['vmware', 'commvault', 'blount’s']
# ['redhat/centos', 'selenium', 'vmware', 'jenkins', 'mysql', 'apache']
# ['android', 'java', 'ios', 'jenkins', 'mysql', 'apache', 'rabbitmq']
# ['windows xp', 'vmware', 'equitrac', 'windows', 'papercut']
# ['zabbix', 'jenkins', 'symfony', 'mysql', 'elastic', 'codeception', 'php', 'codebase', 'rabbitmq']
# ['postgresql', 'redis', 'grunt', 'angularjs', 'laravel', 'rabbitmq']
# ['vmware', 'domino']
# ['ios.', 'vmware', 'android', 'linux']
# ['vmware']
# ['vmware', 'vms.', 'solarwinds']
# ['citrix', 'vmware']
# ['citrix', 'microsoft', 'vmware']
# ['vmware', 'linux']
# ['vmware']
# ['periscope', 'java', 'snowflake', 'kubernetes', 'docker', 'react', 'rabbitmq']
# ['vmware']
# ['asterisk', 'vmware', 'freepbx']
# ['xp', 'dell', 'vmware', 'mailbox']
# ['xp', 'vmware', 'googlemail', 'dell', 'mailbox']
# ['vmware', 'microsoft', 'servicenow']
# ['zabbix', 'linux', 'netware', 'vmware', 'alcatel', 'dell']
# ['angular', 'spring', 'java', 'jenkins', 'rabbitmq']
# ['vmware']
# ['xerox', 'linux', 'vmware', 'docuprint']
# ['citrix', 'filemaker', 'vmware']
# ['vmware', 'sharepoint']
# ['microsoft', 'citrix', 'vmware', 'xendesktop', 'xenapp']
# ['citrix', 'vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'udp', 'elastic']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'microsoft outlook', 'microsoft exchange', 'office']
# ['selenium', 'vmware', 'java', 'jenkins', 'pagespeed']
# ['vmware', 'sage', 'sharepoint', 'windows xp']
# ['citrix', 'vmware', 'fortis']
# ['vmware']
# ['citrix', 'vmware', 'linux']
# ['microsoft office', 'vmware', 'spiceworks', 'solarwinds', 'ibm']
# ['vmware', 'intel']
# ['vmware', 'powershell', 'wixsharp']
# ['vmware', 'windows xp']
# ['vmware']
# ['dell', 'vmware', 'linux', 'whitebox']
# ['citrix', 'vmware', 'sharepoint']
# ['vmware']
# ['vmware']
# ['microsoft', 'microsoft exchange', 'citrix', 'vmware', 'windows xp/7', 'xenapp']
# ['vmware', 'linux']
# ['microsoft', 'netapp', 'vmware', 'avamar', 'ibm']
# ['microsoft.', 'vmware']
# ['vmware']
# ['vmware', 'microsoft']
# ['linux', 'netapp', 'vmware', 'google', 'mysql', 'verint']
# ['vmware']
# ['vmware', 'windows']
# ['vmware', 'ubuntu)', 'linux']
# ['adobe', 'adobe illustrator']
# ['python', 'puppet', 'java', 'mongodb']
# ['vmware', 'powershell', 'sharepoint']
# ['vmware', 'vms', 'sharepoint']
# ['wordpress', 'postgresql', 'python', 'mongo', 'cloudfront', 'django', 'docker', 'postgresql.']
# ['docker', 'terraform', 'rabbitmq', 'jenkins']
# ['postgresql', 'python', 'react.js', 'kubernetes', 'docker', 'rabbitmq']
# ['linux', 'xen', 'vmware', 'mysql', 'apache', 'postfix']
# ['vmware']
# ['vmware', 'veeam']
# ['sonicwall', 'microsoft', 'xen', 'vmware', 'office', 'azure', 'veeam']
# ['vmware', 'cisco']
# ['vmware']
# ['vmware', 'zimbra']
# ['sophos', 'vmware', 'veeam']
# ['netapp', 'vmware', 'drp']
# ['vmware', 'linux']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# []
# ['vmware']
# ['vmware']
# ['dell', 'bladecenter', 'vmware']
# ['citrix', 'windows', 'vmware', 'ibm']
# ['vmware', 'microsoft']
# ['java', 'kubernetes', 'elastic', 'angular/angularjs', 'docker', 'redux', 'springboot', 'mongodb', 'rabbitmq']
# ['vmware', 'windows']
# ['vmware', 'windows']
# ['rabbitmq']
# ['elasticcache.', 'nginx', 'phpunit', 'jenkins', 'symfony', 'php', 'mongodb', 'silex']
# ['vmware', 'microsoft', 'access.']
# ['vmware', 'microsoft exchange']
# ['vmware']
# ['vmware']
# ['vmware', 'windows']
# ['perl', 'vmware']
# ['vmware']
# ['vmware', 'service', 'avamar']
# ['vmware', 'windows', 'fortinet']
# ['python', 'tensorflow']
# ['scala', 'rabbitmq']
# ['vmware', 'symmetrix', 'microsoft exchange']
# ['vmware', 'microsoft exchange', 'linux']
# ['vmware']
# ['vmware']
# ['citrix', 'vmware', 'microsoft exchange.']
# ['fileservers', 'vmware', 'poe', 'veritas', 'netcool']
# ['elastic', 'node.js']
# ['vmware', 'db2', 'symantec', 'ibm']
# ['vmware', 'genesys']
# ['vmware']
# ['vmware', 'fortinet']
# ['sharepoint', 'carshare', 'dynamics)', 'codebase']
# ['vmware', 'microsoft']
# ['vmware', 'java']
# ['adobe', 'javascript', 'html', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'bugzilla', 'python-based']
# ['siemens', 'outlook', 'vmware', 'sharepoint']
# ['vmware']
# ['xero', 'nunit', 'splunk', 'selenium', 'codebase.', 'terraform)']
# ['microsoft', 'dell.', 'vmware', 'citrix', 'sharepoint', 'dell']
# ['vmware', 'openstack', 'openstack)']
# ['vmware', 'openstack', 'openstack)']
# ['vmware', 'openstack']
# ['vmware', 'sharepoint)', 'sharepoint', 'selenium']
# ['android', 'redis', 'google', 'mysql', 'mongodb']
# ['hudson', 'vmware', 'hudson’s']
# ['citrix', 'vmware']
# ['citrix', 'vmware']
# ['vmware']
# ['engineyard', 'html', 'ruby', 'mysql', 'on rails']
# ['citrix', 'vmware']
# ['windows', 'for']
# ['vmware', 'linux']
# ['microsoft', '.', 'vmware', 'powershell', 'sharepoint', 'office']
# ['vmware', 'linux(redhat)', 'cacti']
# ['vmware']
# ['vmware', 'ibm']
# ['vmware', 'docker', 'elastic', 'linux']
# ['postgresql', 'python', 'redis', 'elasticsearch', 'django', 'mongodb', 'hbase']
# ['citrix', 'vmware', 'microsoft', 'xenapp']
# ['vmware']
# ['javascript']
# ['vmware', 'dynamics']
# ['blackberry', 'veeam', 'vmware', 'dynamics']
# ['vmware', 'microsoft', 'altiris']
# ['hive', 'postgresql', 'python', 'spring', 'java', 'google', 'mysql', 'java/j2ee', 'mongodb', 'apache']
# ['dell', 'powershell', 'vmware', 'linux']
# ['vmware', 'microsoft']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'dell.', 'microsoft exchange', 'server', 'vmware', 'directory', 'dell', 'backup', 'ibm']
# ['vmware', 'microsoft', 'ibm']
# ['vmware']
# ['java', 'cloudwatch', 'android', 'ios']
# ['vmware']
# ['vmware']
# ['collaborator', 'for', 'code']
# ['vmware', 'mysql', 'linux/suse']
# ['eclipse', 'java', 'jquery', 'angularjs', 'java.', 'rabbitmq']
# ['hitachi', 'netapp).', 'vmware', 'veritas', 'ibm']
# ['linux', 'ubuntu).', 'xp', 'java', 'jenkins', 'mysql']
# ['netbackup', 'vmware', 'microsoft', 'netapp']
# ['xen', 'citrix', 'vmware', 'vm']
# ['sonicwall', 'microsoft', 'dell', 'linux', 'vmware', 'ubuntu', 'outlook', 'symix', 'microsoft’s', 'centos', 'access']
# ['dell', 'microsoft', 'vmware']
# ['vmware']
# ['vmware', 'ibm']
# ['netbackup', 'vmware', 'avamar', 'symmetrix', 'timefinder)', 'symantec']
# ['vmware']
# ['vmware']
# ['vmware', 'sonicwall', 'sonicpoint']
# ['vmware']
# ['azure', 'vmware', 'microsoft', 'powerapps']
# ['vmware']
# ['hudson', 'spring', 'vmware', 'linux']
# ['ruby)', 'rabbitmq']
# ['vmware']
# ['vmware']
# ['vmware', 'droid']
# ['vmware', 'microsoft']
# ['linux', 'vmware', 'boto3', 'jenkins', 'ansible']
# ['portima.', 'adobe', 'adobe illustrator', 'office']
# ['vmware']
# ['python', 'python)']
# ['xenserver', 'citrix', 'vmware', 'alcatel-lucent', 'omniswitch']
# ['angular', 'microsoft', 'salesforce', 'vmware', 'elasticsearch', 'skype', 'javascript']
# ['regression', 'directory', 'resources']
# ['resources']
# ['directory', 'resources']
# ['windows xp', 'vmware', 'sharepoint', 'xerox', 'azure', 'sophos']
# ['mailboxes', 'microsoft exchange', 'vmware', 'windows', 'skype', 'servicenow', 'access']
# ['java', 'rabbitmq.', 'apache', 'rabbitmq']
# ['elasticsearch', 'matplotlib)']
# ['sidekiq.', 'ruby', 'rails', 'rabbitmq']
# ['vmware']
# ['vmware']
# ['vmware']
# ['netapp', 'vmware']
# ['vmware']
# ['python', 'celery', 'rabbitmq']
# ['vmware']
# ['vmware', 'dell', 'access', 'microsoft exchange']
# ['bugzilla', 'debian.', 'microsoft', 'linux', 'vmware', 'sharepoint', 'ubuntu', 'mysql', 'veeam', 'apache']
# ['microsoft', 'linux)', 'linux', 'vmware', 'sharepoint', 'sun', 'ubuntu', 'office', 'debian', 'ibm']
# ['apache+tomcat', 'vmware', 'mysql', 'linux']
# ['vmware', 'php', 'wordpress', 'linux']
# ['vmware', 'vmware).']
# ['vmware']
# ['linux', 'python', 'vmware', 'html', 'javascript']
# ['vmware']
# ['microsoft', 'vmware', 'xp/2000/2003/vista/2008/7', 'terrasoft', 'firebird', 'vm']
# ['citrix', 'vmware']
# ['microsoft office', 'netapp', 'citrix', 'vmware', 'okta', 'veeam', 'xenapp']
# ['vmware', 'altiris']
# ['fogbugz.', 'vmware']
# ['vmware']
# ['microsoft', 'microsoft exchange', 'netbackup', 'vmware', 'netapp']
# ['android', 'xp', 'jquery', 'html', 'adobe', 'mysql', 'adobe illustrator', 'javascript', 'apache']
# ['vmware']
# ['vmware', 'javascript', 'jquery', 'sharepoint']
# ['vmware', 'javascript', 'jquery']
# ['vmware', 'puppet', 'jenkins']
# ['vmware']
# ['vmware', 'netiq', 'node', 'nastel.']
# ['vmware']
# ['microsoft', 'exchange', 'ironport', 'vmware', 'dynamics']
# ['microsoft', 'vmware', 'dynamics', 'skype', 'office']
# ['xen', 'citrix', 'coillte', 'vmware']
# ['dell', 'xp.', 'vmware']
# ['vmware']
# ['xenserver', 'citrix', 'vmware', 'python.']
# ['vmware', 'onshift', 'veeam', 'kronos']
# ['kofaxcapture', 'cloudflare', 'google', 'cloudfront']
# ['vmware', 'linux/windows']
# ['citrix', 'vmware']
# ['vmware']
# ['citrix', 'vmware', 'sharepoint']
# ['citrix', 'vmware']
# ['vmware']
# ['vmware', 'microsoft']
# ['vmware', 'onda.']
# ['ruby', 'on rails/mysql/solr']
# ['vmware']
# ['vmware', 'linux']
# ['microsoft', 'microsoft office', 'shortel', 'gotomeeting', 'windows xp', 'vmware', 'teamviewer', 'windows', 'office', 'shoretel', 'servicenow']
# ['vmware']
# ['citrix', 'vmware', 'office']
# ['vmware', 'bitbucket.']
# ['microsoft', 'vmware', 'mysql', 'juniper', 'office', 'dell']
# ['citrix', 'netscaler', '5.5/7.6', 'windows', '\\uf0b7', 'xenapp']
# ['vmware', 'the', 'linux']
# ['postgresql', 'python', 'vmware', 'perl', 'ubuntu', 'adobe', 'mysql', 'adobe illustrator', 'centos/redhat', 'php', 'apache']
# ['vmware']
# ['vmware']
# ['vmware', 'linux', 'postfix']
# ['adobe', 'adobe illustrator']
# ['vmware', 'citrix', 'xenapp', 'microsoft exchange']
# ['netapp', 'vmware', 'vm']
# ['microsoft', 'netapp', 'citrix', 'vmware', 'xenapp/app-v', 'xendesktop', 'xenapp']
# []
# ['wordpress', 'microsoft office', 'html', 'jquery', 'php', 'adobe', 'adobe illustrator', 'javascript']
# ['dell', 'orkstation', 'vmware', 'microsoft']
# ['vmware']
# ['vmware', 'sprints']
# ['vmware', 'vmware.']
# ['vmware', 'vmworld']
# ['vmware']
# ['vmware', 'teradata']
# ['support', 'l2(rim)']
# ['vmware']
# ['vmware', 'microsoft']
# ['vmware', 'vmworld']
# ['citrix', 'netscalers', 'vmware', 'xenapp']
# ['vmware', 'hitachi', 'netapp)']
# ['cloudwatch', 'linux-based', 'cloudtrail']
# ['vmware', 'openstack', 'nokia']
# ['citrix', 'vmware', 'xenapp']
# ['vmware']
# ['vmware', 'vblock', 'intel.', 'cisco']
# ['sonicwall', 'microsoft', 'vmware']
# ['spring', 'java', 'rabbitmq']
# ['linux', 'nginx', 'zabbix.', 'mysql', 'cloudways', 'apache', 'postfix']
# ['vmware', 'flybe.com']
# ['citrix', 'xp/7/2003/2008', 'vmware']
# ['adobe', 'adobe illustrator']
# ['angular', 'redis', 'bootstrap', 'spring', 'java', 'jenkins', 'mysql', 'docker', 'jboss', 'rabbitmq']
# ['vmware', 'linux/unix', 'wireshark']
# ['tensorflow', 'hive', 'mongdb', 'java', 'scala', 'jenkins', 'graphite', 'ansible', 'tinkerpop']
# ['vmware']
# ['vmware', 'windows']
# ['vmware', 'windows']
# ['sonicwall', 'vmware', 'xp/vista/7', 'html', 'dell', 'javascript']
# ['onicwall', 'linux', 'centrion', 'citrix', 'vmware', 'xp/vista/7/8/10', 'html', 'ios', 'dell/hp', 'docker', 'javascript', 'rabbitmq']
# ['linux', 'python', 'vmware', 'selinux', 'gnu/linux', 'cacti', 'perl', 'dell', 'jboss', 'apache']
# ['openbsd', 'python', 'gnu/linux', 'vmware', 'ubuntu', 'perl', 'debian', 'postfix']
# ['microsoft', 'lexel', 'citrix', 'vmware', 'ibm']
# ['ensure', '\\uf09f', 'from', 'costs']
# ['vmware']
# ['vmware', 'okta', 'cisco']
# ['docker', 'java']
# ['vmware', 'linux']
# ['citrix', 'vmware']
# ['rabbitmq', 'hbase']
# ['10g', 'vmstat', 'sitescope', 'iostat', 'citrix', 'vmware', 'informatica', 'heap', 'ibm']
# []
# ['vmware', 'vasco', 'microsoft', 'vm']
# ['vmware', 'vasco', 'microsoft', 'vm']
# ['citrix', 'vmware', 'xenapp']
# ['netapp', 'citrix', 'vmware']
# ['windows', 'microsoft visual', 'vmware']
# ['vmware']
# ['citrix', 'xendesktop/pvs', 'netscaler', 'vmware']
# ['xenserver', 'microsoft', 'vmware', 'netscaler', 'windows']
# ['vmware', 'powershell']
# ['vmware', 'acros']
# ['socket', 'vmware', 'html', 'mysql', 'perl', 'jboss']
# ['tempest', 'vmware', 'veeam', 'ios']
# ['microsoft', 'vmware', 'ios', 'windows', 'sophos']
# ['microsoft', 'vmware', 'windows', 'azure', 'veeam']
# ['microsoft', 'html', 'sharepoint', 'google', 'adobe', 'adobe illustrator', 'javascript']
# ['html', 'jquery', 'wordpress.', 'adobe', 'javascript', 'adobe illustrator', 'php']
# ['postgresql', 'selenium', 'python', 'hudson', 'eclipse', 'java', 'html', 'selenium2/rspec/capybara', 'ruby', 'mysql', 'vmware fusion-server-workstation-gsx']
# ['vmware', 'sharepoint.', 'sharepoint..', 'windows xp']
# ['citrix', 'vmware']
# ['vmware']
# ['netapp', 'vmware']
# ['sonicwall', 'chromebook', 'vmware']
# ['google', 'sonicwall', 'vmware']
# ['xp', 'vmware']
# ['vmware', 'cisco']
# ['vmware', 'linux']
# ['vmware', 'netiq']
# ['vmware', 'zephyr', 'mercurial']
# ['vmware']
# ['vmware']
# ['microsoft', 'microsoft visual basic.net', 'framework', 'microsoft sql server']
# ['vmware']
# ['quark', 'adobe', 'adobe illustrator']
# ['android', 'ios', 'adobe', 'skype', 'adobe illustrator']
# ['adobe illustrator', 'adobe', 'android', 'ios']
# []
# ['zabbix', 'cisco', 'netflow', 'redis', 'elasticsearch', 'ruby', 'mysql', 'perl', 'rabbitmq']
# ['vmware', 'splunk', 'jboss', 'ibm']
# ['vmware', 'manger']
# ['postgresql.', 'sonicwall', 'linux', 'postfix', 'vmware', 'fortinet.', 'mysql', 'jboss', 'debian', 'apache', 'vm']
# ['microsoft', 'linux', 'citrix', 'vmware', 'cisco.', 'mysql', 'jboss', 'debian', 'apache']
# ['vmware']
# ['vmware']
# ['vmware', 'sharepoint']
# ['vmware']
# ['vmware']
# ['python', 'vmware', 'java', 'rootkit', 'ruby.']
# ['vmware', 'microsoft']
# ['webdriver', 'selenium', 'vmware', 'java', 'j2ee']
# ['vmware']
# ['citrix', 'vmware', 'xenapp']
# ['vmware']
# ['citrix', 'dell', 'vmware']
# ['vmware', 'node']
# ['microsoft', 'vmware', 'java', 'html', 'j2ee', 'google', 'joomla', 'comerica', 'javascript', 'ibm']
# ['vmware']
# ['docker', 'elasticache', 'aurora']
# ['windows', 'mantis', 'vmware']
# ['vmware', 'filenet', 'oracle', 'jboss']
# ['safari)', 'rails', 'selenium', 'monit.', 'jquery', 'ios', 'ruby', 'mysql', 'javascript']
# ['vmware']
# ['vmware']
# ['vmware', 'vms', 'linux.', 'linux']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['citrix', 'microsoft', 'vmware']
# ['vmware']
# ['citrix', 'microsoft', 'vmware']
# ['vmware']
# ['vmware']
# ['netapp', 'sonicwall', 'iconect', 'vmware']
# ['vmware', 'java']
# ['python', 'vmware', 'spring', 'java', 'j2ee', 'mysql']
# ['vmware', 'microsoft', 'sharepoint', 'ibm']
# ['redis', 'django.', 'airbnb']
# ['mysql.', 'hive', 'jenkins.', 'html/jquery/bootstrap/jinjia.', 'redis.']
# ['vmware']
# ['citrix', 'vmware']
# ['python', 'vmware', 'powershell']
# ['dell', 'microsoft', 'vmware', 'office']
# ['citrix', 'accenture)', 'vmware']
# ['vmware', 'vmworld']
# ['vmware', 'vmware’s']
# ['microsoft', 'vmware', 'citrix', 'netscaler', 'xenapp']
# ['vmware']
# ['vmware']
# ['netapp', 'vmware']
# ['vmware', 'citrix', 'netscaler', 'xendesktop', 'xenapp']
# ['dell', 'juniper', 'vmware', 'linux']
# ['netapp', 'vmware', 'linux', 'ibm']
# ['cloudsearch']
# ['vmware', 'microsoft', 'sharepoint', 'office']
# ['vmware']
# ['vmware', 'ios', 'android.']
# ['vmware', 'ios', 'android.']
# ['hootsuite', 'adobe', 'adobe illustrator']
# ['vmware']
# ['vmware', 'ios']
# ['vmware', 'microsoft', 'microsoft exchange']
# ['vmware', 'microsoft', 'symantec']
# ['dell', 'microsoft', 'vmware', 'webroot']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'linux']
# ['vmware']
# ['vmware']
# ['vmware']
# ['dell', 'vmware']
# ['linux', 'citrix', 'vmware', 'datebase', 'anitvirus', 'scala']
# ['citrix', 'vmware', 'windows xp']
# ['netapp', 'vmware', 'ibm']
# ['vmware']
# ['vmware', 'alcatel', 'microsoft', 'microsoft exchange']
# ['vmware']
# ['sonicwall', 'microsoft', 'vmware']
# ['citrix', 'vmware']
# ['vmware', 'fortran', 'intel']
# ['vmware']
# ['microsoft', 'dell', 'microsoft exchange', 'microsoft office', 'vmware', 'spiceworks']
# ['vmware']
# ['dell', 'vmware']
# ['vmware']
# ['citrix', 'xangati', 'zen', 'vmware']
# ['fusion', 'vmware']
# ['vmware', 'storeall).', 'swift', 'openstack']
# ['vmware']
# ['vmware']
# ['vagrant)', 'vmware', 'jenkins', 'azure.', 'azure']
# ['microsoft', 'vmware', 'linux.', 'sharepoint/moss', 'ibm']
# ['microsoft', 'dell', 'linux', 'vmware', 'linux.', 'sharepoint', 'centos', 'luxcloud']
# ['vmware', 'fortinet', 'powershell.']
# ['vmware']
# ['vmware', 'intel']
# ['citrix', 'microsoft', 'vmware', 'intel']
# ['adobe', 'microsoft office.', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'linux/unix', 'linux']
# ['vmware']
# ['microsoft', 'vmware', 'sharepoint', 'microsoft office365', 'veeam']
# ['vmware:']
# ['vmware']
# ['citrix', 'splunk', 'vmware']
# ['vmware', 'veeam']
# ['vmware', 'sharepoint', 'intel']
# ['vmware']
# ['vmware']
# ['vmware', 'linux']
# ['microsoft', 'citrix', 'sap', 'vmware', 'codestone', 'microsoft.', 'turnkey']
# ['sass', 'cucumber.js', 'spring', 'angulardart', 'docker']
# ['microsoft', 'server', 'vmware', 'microsoft exchange server', 'ibm aix', 'backup', 'ibm']
# ['selenium', 'python', 'vmware', 'testrail', 'junit']
# ['vmware', 'radius', 'vm']
# ['vmware', 'radia']
# ['vmware', 'juniper']
# ['vmware']
# ['vmware', 'microsoft', 'microsoft exchange']
# ['vmware']
# ['vmware', 'citrix.', 'qualys', 'ibm']
# ['dell', 'microsoft', 'vmware', 'webroot']
# ['sonicwall.', 'citrix', 'vmware', 'xen']
# ['redis.io.', 'microsoft sql server', 'rabbitmq']
# ['vmware']
# ['designed', '\\x95', 'dmz']
# ['citrix', 'vmware']
# ['netbackup', 'vmware', 'microsoft']
# ['vmware', 'linux']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['sonicwall', 'veeam', 'vmware']
# ['citrix', 'vmware']
# ['microsoft.', 'vmware', 'microsoft']
# ['vmware']
# ['vmware']
# ['vmware', 'vmwares']
# ['vmware']
# ['microsoft sql', 'microsoft', 'vmware']
# ['vmware', 'linux', 'netware']
# ['vmware']
# ['citrix', 'vmware', 'celerra', 'xenapp']
# ['vmware', 'ios', 'linux']
# ['vmware', 'sharepoint']
# []
# ['vmware']
# ['vmware', 'equifax']
# ['shoretel', 'citrix', 'vmware', 'sonicwall)', 'dell', 'xenapp']
# ['docker', 'vmware', 'php', 'j2ee']
# ['vmware', 'dynamics']
# ['postresql)', 'vmware']
# ['vmware', 'ibm']
# ['vmware', 'radius', 'veeam.', 'ibm']
# ['vmware', 'jboss', 'linux']
# ['vmware', 'linux', 'windows xp']
# ['vmware', 'linux']
# ['citrix', 'vmware']
# ['vmware']
# ['xenserver', 'vmware', 'netscaler', 'xendesktop', 'xenapp']
# ['equinix', 'citrix', 'vmware', 'ibm']
# ['vmware', 'xenapp', 'microsoft exchange']
# ['sonicwall', 'microsoft', 'microsoft exchange', 'vmware', 'microsoft sql server']
# ['netapp', 'vmware', 'windows', 'microsoft']
# ['vmware', 'bugzilla', 'java', 'jenkins']
# ['imagespace', 'mysql']
# ['database.', 'vmware', 'oracle', 'san', 'systems).']
# ['vmware', 'zenworks', 'arcgis']
# ['microsoft', 'citrix', 'vmware', 'powershell', 'netscaler', 'microsoft server', 'windows', 'xenapp/xendesktop']
# ['microsoft office', 'word excel', 'adobe', 'adobe illustrator', 'powerpoint', 'access']
# ['javascript.', 'microsoft office', 'html', 'access.', 'word excel', 'adobe', 'adobe illustrator', 'powerpoint']
# ['citrix', 'microsoft', 'vmware']
# ['dell', 'vmware']
# ['citrix', 'vmware', 'xenapp']
# ['vmware']
# ['vmware']
# ['10g', 'exchange', 'three', 'cisco']
# ['adobe', 'adobe illustrator']
# ['db2.', 'microsoft sql', 'microsoft', 'vmware', 'cognos', 'manger', 'ibm']
# ['vmware', 'linux']
# ['netapp', 'vmware']
# ['puppet', 'php', 'mysql', 'zend']
# ['vmware', 'linux']
# ['vmware']
# ['angular', 'xamarin', 'firebase', 'jenkins', 'elasticsearch', 'angularjs', 'ios/swift', 'android/java', 'mongodb']
# ['nginx', 'mysql', 'sprint', 'php', 'laravel', 'rabbitmq']
# ['perl', 'bluearc', 'hitachi', 'vmware']
# ['vmware', 'microsoft']
# ['vmware', 'zen', 'sharepoint']
# ['vmware', 'debian', 'apache', 'linux']
# ['vmware', 'debian', 'apache', 'linux']
# ['vmware', 'microsoft', 'postman', 'jenkins']
# ['vmware', 'juniper']
# ['vmware']
# ['vmware', 'linux']
# ['vmware', 'microsoft exchange']
# ['php', 'html', 'linux']
# ['vmware']
# ['linux', 'vmware', 'drp']
# ['vmware', 'windows', 'wiki', 'drac', 'vm']
# ['vmware', 'alcatel']
# ['netapp', 'vmware', 'dell)']
# ['linux', 'microsoft office', 'vmware', 'filemaker', 'dell']
# ['vmware']
# ['netapp', 'citrix', 'vmware', 'netware']
# ['vmware']
# ['microsoft', 'office.', 'vmware', 'iosafe', 'poe', 'office', 'dell', 'veeam']
# ['netapp', 'dell', 'vmware']
# ['linux', 'vmware', 'mysql', 'jboss', 'centos', 'apache', 'postfix']
# ['vmware', 'bootcamp', 'applejack']
# ['vmware']
# ['vmware', 'bugzilla', 'sharepoint']
# ['vmware', 'kubernetes']
# ['vmware']
# ['vmware']
# ['openstack', 'selenium', 'python', 'vmware', 'docker']
# ['vmware', 'microsoft']
# ['sonicwall', 'microsoft', 'vmware']
# ['vmware']
# ['vmware', 'citrix', 'xenapp', 'microsoft exchange']
# ['cloudera', 'selenium', 'python', 'jenkins', 'mocha', 'arcadia', 'openldap', 'athena', 'docker', 'javascript']
# ['python', 'nginx', 'ubuntu', 'mysql', 'javascript']
# ['adobe', 'adobe illustrator']
# ['autodesk', 'windows', 'vmware']
# ['citrix', 'vmware']
# ['citrix', 'vmware']
# ['citrix', 'sharepoint', 'vmware', 'linux']
# ['citrix', 'xenapp', 'vmware', 'microsoft exchange']
# ['citrix', 'vmware']
# ['vmware']
# ['angularjs', 'php-based']
# ['jenkins.', 'php', 'nodejs.']
# ['microsoft', 'microsoft exchange', 'server', 'vmware', 'sharepoint']
# ['microsoft office', 'netapp', 'citrix', 'vmware office', 'servicenow']
# ['vmware', 'java', 'microsoft’s']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# ['vmware', 'microsoft', 'cisco', 'mailbox']
# ['microsoft', 'vmware', 'powershell', 'office', 'azure', 'dell', 'solarwinds']
# ['java', 'mysql']
# ['vmware', 'vmware).']
# ['windows xp/server', 'powershell', 'vmware', 'thinapp']
# ['vmware', 'netapp/storevault']
# ['vmware', 'twikis']
# ['vms.', 'vmware', 'vm']
# ['citrix', 'vmware']
# ['vmware', 'veeam']
# ['citrix', 'xenapp7.5', 'vmware', 'xenapp']
# ['vmware', 'linux']
# ['vmware']
# ['microsoft', 'altiris', 'windows xp', 'netware', 'citrix', 'cisco', 'vmware', 'zenworks', 'office', 'patchlink']
# ['vmware']
# ['qliktech', 'dell', 'vmware', 'ibm']
# ['vmware', 'xp/2003', 'windows xp/vista']
# ['vmware', 'informatici', 'veeam']
# ['sophos', 'dell', 'vmware', 'linux']
# ['vmware']
# ['vmware']
# ['hive', 'redis', 'bootstrapping', 'python.', 'apache', 'rabbitmq']
# ['axure', 'adobe', 'adobe illustrator']
# ['vmware', 'microsoft', 'exchange']
# ['google', 'vmware', 'helpdesk', 'edgewave']
# ['vmware', 'vnx']
# ['meraki', 'fortinet', 'vmware']
# ['adobe', 'html', 'adobe illustrator']
# ['vmware', 'microsoft']
# ['citrix', 'microsoft', 'veeam', 'vmware']
# ['java', 'vmware', 'spring', 'mysql']
# ['citrix', 'vmware']
# ['ruckus', 'vmware']
# ['vmware', 'sharepoint']
# ['vmware']
# ['onedrive', 'vmware']
# ['vmware', 'microsoft', 'debian/ubuntu)', 'linux']
# ['vmware']
# ['centos', 'fedora', 'vmware', 'ubuntu']
# ['android)', 'linux', 'eclipse', 'java', 'jogl', 'gpuanalyzer', 'aptana', 'xampp', 'mercurial', 'php', 'opengles']
# ['vmware', 'dell', 'microsoft', 'skype4b']
# ['dell', 'vmware']
# ['vmware']
# ['server', 'equipped', 'and']
# ['vmware', 'citrix', 'powershell', 'netscaler', 'xenapp']
# []
# ['microsoft', 'vmware', 'citrix', 'windows', 'juniper', 'xenapp', 'access']
# ['vmware', 'vmware.']
# ['10g', 'oracle', 'vmware']
# ['vmware', 'ubuntu']
# ['perl', 'vmware', 'vms']
# ...
# ['microsoft dynamics', 'microsoft', 'vmware', 'salesforce.com', 'dell', 'ibm']
# ['vodafone', 'vmware', 'freemove', 'emea']
# ['netapp', 'vmware', 'ibm']
# ['vmware', 'linux.']
# ['citrix', 'microsoft', 'vmware']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['netapp', 'vmware', 'steam']
# ['microsoft office 365', 'microsoft exchange', 'vmware', 'sharepoint', 'skype', 'backup']
# ['adobe', 'adobe illustrator']
# ['netapp', 'vmware']
# ['installation']
# ['dual', 'site', 'managed']
# ['vmware', 'openstack', 'microsoft', 'rackspace']
# ['vmware', 'microsoft', 'nant']
# ['vmware', 'ibm', 'cisco', 'ironport']
# ['outlook', 'vmware', 'sharepoint']
# ['citrix', 'vmware']
# ['linux', 'vmware', 'starteam', 'borland', 'solarwinds']
# ['google', 'vmware', 'microsoft']
# ['netapp', 'vmware', 'ibm']
# ['microsoft', 'vmware', 'citrix', 'dell', 'certus']
# ['dell', 'vmware', 'intel', 'vmware.']
# ['citrix', 'vmware']
# ['vmware']
# ['azure', 'vmware', 'openstack']
# ['vmware']
# ['vmware', 'comm', 'linux']
# ['vmware', 'sharepoint']
# ['microsoft']
# ['vmware', 'dell', 'tam', 'seibel']
# ['adobe', 'adobe illustrator', 'word']
# ['talecris', 'talecris.', 'vmware', 'google', 'documentum']
# ['html', 'adobe', 'adobe illustrator', 'microsoft powerpoint', 'claris', 'pagemill']
# ['citrix', 'microsoft', 'vmware']
# ['citrix', 'microsoft', 'vmware', 'ebay.']
# ['citrix', 'microsoft', 'vmware']
# []
# ['cumulus', 'vmware', 'linux']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'adobe', 'adobe illustrator']
# ['vmware']
# ['citrix', 'microsoft', 'vmware']
# []
# ['wattpad.', 'google', 'adobe', 'adobe illustrator', 'hootsuite']
# ['angular', 'postgresql', 'python', 'qantas', 'php', 'elasticache', 'javascript', 'teradata)']
# ['vmware', 'microsoft', 'office']
# ['vmware']
# ['vmware']
# ['vmware']
# ['myvmware', 'vmware']
# ['vmware']
# ['vmware', 'db2', 'linux', 'ibm']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# ['vmware', 'cadence']
# ['vmware']
# ['citrix', 'dell', 'dell’s', 'vmware']
# ['vmware']
# ['vmware']
# ['dell', 'vmware']
# ['citrix', 'vmware']
# ['vmware']
# ['netapp', 'citrix', 'xangati:', 'vmware', 'xangati', 'ebay', 'dell', 'vmworld']
# ['netapp', 'vmware', 'commvault']
# ['vmware', 'vmware.']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'shellshock']
# ['vmware']
# ['citrix', 'microsoft', 'vmware', 'vmware.']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'vmware', 'analytics).', 'veeam', 'guardium', 'ibm']
# ['vmware', 'avamar']
# ['vmware', 'javascript', 'jquery']
# ['migration', 'tools', 'tasks', 'e1000', 'using', 'dell', 'a']
# ['for', 'on']
# ['excel', 'vmware', 'microsoft', 'wikis']
# ['vmware', 'webos']
# ['adobe', 'adobe illustrator']
# ['citrix', 'microsoft', 'vmware']
# ['linux', 'nginx', 'cacti', 'jboss', 'apache']
# ['vmware', 'windows']
# ['vmware']
# ['xenserver', 'citrix', 'vmware', 'xendesktop', 'xenapp']
# ['vmware', 'microsoft', 'java', 'ibm']
# ['netapp', 'citrix', 'microsoft', 'vmware']
# ['vmware', 'ibm']
# ['vmware']
# ['vmware', 'microsoft', 'sharepoint']
# ['vmware', 'launchpad']
# ['netapp', 'citrix', 'vmware']
# ['wordpress', 'html', 'keynote', 'adobe', 'adobe illustrator']
# [')', 'html', 'adobe', 'mysql', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'ibm']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'quarkxpress']
# ['vmware']
# ['adobe', 'adobe illustrator', 'quarkxpress.']
# ['vmware', 'juniper', 'veeam']
# ['adobe', 'avid', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'xerox', 'hubspot']
# ['adobe', 'adobe illustrator', 'pageflex.']
# ['adobe', 'nanion', 'adobe illustrator', 'nanion’s']
# []
# ['adobe', 'adobe illustrator']
# ['quark', 'adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe illustrator', 'adobe', 'ios']
# ['adobe illustrator', 'adobe', 'android', 'ios']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'microsoft powerpoint']
# ['microsoft', 'linux', 'vmware', 'sharepoint', 'zenoss', 'dell']
# ['vmware', 'vmworld']
# ['adobe', 'macromedia', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['javascript.', 'wordpress', 'html', 'drupal', 'joomla', 'adobe', 'adobe illustrator', 'magento', 'php']
# ['vmware', 'airwatch']
# ['adobe', 'adobe illustrator', 'mailchimp.']
# ['mailchimp', 'adobe', 'shopify.', 'adobe illustrator']
# ['vmware', 'veeam', 'intel', 'casper']
# ['os', 'microsoft office', 'paytrax', 'html', 'adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'quarkxpress.']
# ['quark', 'adobe', 'adobe illustrator']
# ['html/css', 'wordpress', 'html', 'php', 'joomla', 'adobe', 'adobe illustrator', 'javascript']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['netapp', 'citrix', 'microsoft', 'solarwinds']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'mailchimp.']
# ['adobe', 'adobe illustrator']
# ['linux', 'netware', 'xen', 'vmware', 'perl']
# ['linux', 'netware', 'xen', 'vmware', 'perl']
# ['html', 'adobe', 'javascript', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['spingo', 'adobe', 'google analytics', 'adobe illustrator', 'spingo.com']
# ['salesforce', 'adobe', 'adobe illustrator', 'pardot', 'html.']
# ['javascript)', 'adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'vmware', 'intel', 'dmz', 'ibm']
# ['adobe', 'adobe illustrator', 'quarkxpress']
# ['netapp', 'vmware', 'microsoft', 'dynamics']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'archicad']
# ['adobe', 'adobe illustrator']
# ['quickbooks', 'joomla', 'adobe', 'adobe illustrator']
# ['vmware']
# ['adobe', 'the', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['dell', 'sage', 'vmware', 'intel']
# ['adobe', 'adobe illustrator']
# ['adobe', 'html', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator', 'microsoft office']
# ['adobe', 'adobe illustrator']
# ['google', 'adobe', 'adobe illustrator']
# ['microsoft', 'adobe', 'adobe illustrator', 'sharepoint']
# ['adobe', 'lotto.', 'adobe illustrator', 'lotto']
# ['adobe', 'adobe illustrator', 'lotto']
# ['adobe illustrator', 'adobe', 'wordpress', 'graphtec']
# ['adobe', 'adobe illustrator', 'quarkxpress.']
# ['logitech', 'netapp', 'vmware', 'intel', 'clickstar', 'adobe', 'adobe illustrator', 'motorola']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['wordpress', 'bootstrap', 'drupal', 'joomla', 'google analytics', 'adobe', 'adobe illustrator', 'sass.', 'cloud:', 'javascript', 'zenphoto']
# ['adobe', 'adobe illustrator']
# ['adobe', 'php', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'microsoft word', 'adobe illustrator', 'mailchimp.']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['vmware', 'vmware’s']
# ['drupal.', 'adobe', 'adobe illustrator', 'drupal-based', 'microsoft access:']
# ['adobe', 'adobe illustrator', 'microsoft office']
# ['to']
# ['adobe', 'aldus', 'adobe illustrator', 'quarkxpress']
# ['adobe', 'zynga', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['testcafe', 'keycloak', 'java', 'elasticsearch', 'angularjs', 'rabbitmq']
# ['adobe', 'adobe illustrator']
# ['adobe', 'php', 'html', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'html', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['citrix', 'dell', 'centrix', 'vmware']
# ['vmware', 'microsoft', 'windows xp']
# ['vmware']
# ['microsoft office', 'adobe', 'adobe illustrator', 'epic', 'arbortext']
# ['vmware', 'fastcloud', 'ibm']
# ['vmware']
# ['netapp', 'vmware', 'ibm express', 'vm', 'vmware.', 'ibm']
# ['vmware', 'microsoft', 'linux)', 'ibm']
# ['microsoft', 'vmware', 'adobe', 'adobe illustrator', 'ibm']
# ['microsoft', 'vmware', 'adobe', 'adobe illustrator', 'ibm']
# ['microsoft', 'vmware', 'adobe', 'adobe illustrator', 'ibm']
# ['adobe', 'pixbit', 'adobe illustrator', 'pixbit.']
# ['vmware']
# ['vmware']
# ['adobe', 'adobe illustrator', 'quarkxpress']
# []
# ['vmware']
# ['wordpress', 'drupal', 'adobe', 'adobe illustrator', 'salesforce)']
# ['vmware']
# ['vmware', 'microsoft', 'office.', 'office']
# ['vmware', 'windows']
# ['microsoft', 'vmware', 'adobe', 'adobe illustrator', 'ibm']
# ['linux', 'vmware', 'perl', 'apache', 'tregoe.']
# ['vmware', 'microsoft']
# ['microsoft', 'vmware', 'sharepoint', 'dell', 'fortinet', 'ibm']
# ['vmware', 'windows', 'x86']
# ['html', 'jquery', 'wordpress.', 'adobe', 'adobe illustrator', 'javascript']
# ['vmware', 'spring', 'springpeople', 'lightbend', 'mulesoft', 'elastic']
# ['vmware']
# ['quark', 'adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['dell', 'microsoft', 'vmware']
# ['dell', 'microsoft', 'vmware']
# ['vmware', 'linux']
# ['linux', 'vmware', 'rundeck', 'ansible.', 'jenkins']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware', 'cymphonix']
# ['netapp.', 'linux', 'xp', 'vmware', 'ubuntu', 'vmware.']
# ['wiki', 'linux.', 'node', 'debian']
# ['vmware', 'linux-based', 'ubuntu', 'drupal', 'mysql', 'apache']
# ['vmware', 'vmware’s', 'ibm']
# ['vmware', 'microsoft', 'exchange']
# ['azure).', 'vmware', 'rackspace', 'html).', 'php']
# ['netapp.', 'vmware', 'ibm']
# ['vmware', 'microsoft', 'server']
# ['splunk', 'linux', 'postgresql', 'xen', 'redis', 'rabbitmq', 'jenkins', 'centos', 'mercurial', 'mysql', 'perl', 'docker', 'php', 'ansible', 'soapui', 'jasper', 'pentaho']
# ['vmware']
# ['accenture', 'vmware']
# ['corporate', 'tracking', '\\uf0d8', 'and']
# ['citrix', 'vmware', 'xenapp']
# ['vmware', 'kovarus']
# ['vmware']
# ['autodesk', 'maya', 'adobe', 'adobe illustrator']
# ['adobe', 'html', 'adobe illustrator']
# ['the', 'netapp', 'vmware', 'avamar', 'veeam', 'vm']
# ['vmware', 'delphix']
# ['blackberry', 'vmware', 'ironport']
# []
# ['vmware', 'vmware.']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware']
# ['vmware', 'android', 'bootcamp']
# ['vmware']
# ['openstack', 'the', 'linux', 'python', 'vmware', 'java', 'powershell', 'vm-level', 'openstack.', 'vm']
# ['vmware']
# ['vmware']
# ['fedex', 'vmware', 'wordpress']
# ['citrix', 'vmware']
# ['vmware', 'linux/unix', 'x86']
# ['linux', 'xp', 'vmware', 'opensolaris', 'apache']
# ['adobe', 'adobe illustrator']
# ['google', 'vmware']
# ['google', 'vmware']
# ['vmware']
# ['vmware', 'informatici']
# ['vmware', 'linux']
# ['adobe', 'adobe illustrator']
# ['adobe', 'adobe illustrator']
# ['dell', 'microsoft', 'veeam', 'vmware']
# ['vmware']
# ['server', 'all customers']
# ['vmware']
# ['hive', 'sass', 'linux', 'python', 'jquery', 'elasticsearch', 'hbase', 'orange', 'django', 'spark', 'perl', 'docker', 'javascript', 'rabbitmq']
# ['the', 'microsoft office', 'vmware', 'sharepoint', 'adobe', 'adobe illustrator']
# ['vmware']
# ['puppet', 'node', 'radius', 'vmware', 'apache']
# ['vmware', 'sharepoint', 'ibm']
# []
# ['vmware']
# ['vmware']
# ['netapp', 'vmware', 'commvault', 'microsoft']
# ['datos', 'netapp', 'vmware', 'rubrik.', 'azure.', 'lightspeed', 'mongodb']
# ['vmware', 'microsoft']
# ['vmware', 'ibm']
# ['adobe', 'html', 'adobe illustrator', 'microsoft office']
# ['xenserver', 'microsoft', 'vmware', 'netscaler', 'xendesktop', 'office', 'xenapp', 'vmware)']
# ['vmware', 'microsoft', 'sharepoint']
# ['vmware', 'openstack']
# ['adobe', 'adobe illustrator']
# ['citrix', 'vmware', 'linux']
# ['vmware', 'linux)', 'ibm']
# ['redis', 'bootstrap', 'jquery', 'elasticsearch', 'angularjs', 'javascript', 'node.js']
# ['dell', 'vmware']
# ['vmware', 'microsoft', 'netcheck']
# ['netapp.', 'vmware']
# ['adobe', 'adobe illustrator']
# ['vmware', 'veeam)', 'veeam']
# ['hitach', 'aptare', 'netapp', 'vmware', 'ibm']
# ['vmware', 'windows', 'sharepoint']
# ['vmware', 'microsoft', 'intel']
# ['vmware']
# ['android', 'java/android', 'spring', 'java', 'java/spring', 'rabbitmq']
# ['vmware', 'microsoft', 'microsoft exchange', 'office']
# ['commvault', 'dell', 'hp', 'vmware']
# ['quark', 'adobe', 'adobe illustrator']
# ['microsoft', 'linux', 'vmware', 'windows', 'mysql']
# ['vmware', 'intel']
# ['vmware', 'selenium......etc.']
# ['vmware', 'ibm']
# ['vmware', 'microsoft', 'linux']
# ['adobe', 'adobe illustrator']
# ['microsoft', 'exchange', 'server', 'vmware', 'sql', 'share', 'dell', 'vm']
# ['microsoft', 'vmware', 'citrix', 'xendesktop', 'xendesktop/xenapp', 'xenapp']
# ['vmware']
# ['vmware']
# ['selenium', 'vmware', 'selenium.', 'sprint', 'sprint.']
# ['accenture)', 'vmware', 'cisco']
# ['vmware', 'oracle', 'avamar']
# ['adobe', 'adobe illustrator']
# ['outlook', 'vmware', 'mailbox']
# ['fiserv', 'microsoft', 'linux', 'vmware', 'wiki.']
# ['vmware']
# ['vmware']
# ['vmware']
# ['sharepoint', 'google', 'adobe', 'google analytics', 'adobe illustrator']
# ['dell', 'microsoft', 'vmware']
# ['microsoft', 'microsoft exchange', 'ironport', 'citrix', 'vmware', 'directory', 'microsoft server', 'juniper']
# ['vmware', 'microsoft', 'intel']
# ['vmware']
# ['java', 'adobe', 'mysql', 'adobe illustrator', 'php']
# ['java', 'adobe', 'mysql', 'adobe illustrator', 'php']
# ['microsoft', 'linux', 'citrix', 'vmware', 'powershell']
# ['nutanix', 'redis', 'sprint', 'php', 'mongodb', 'node.js', 'rabbitmq']
# ['vmware']
# ['vmware', 'microsoft', 'linux']
# ['vmware', 'microsoft']
# ['netapp', 'vmware', 'symatec(veritas)']
# ['vmware', 'cognos', '.', 'sharepoint']
# ['vmware', 'microsoft', 'linux']
# ['broadcom', 'emulex']
# ['vmware', 'linux']
# ['linux', 'mysql)', 'vmware', 'mysql', 'perl', 'php', 'apache']
# ['vmware', 'ios', 'android/']
# ['vmware', 'ios', 'android/']
# ['angular', 'wordpress', 'bootstrap', 'docker)', 'jquery', 'mongodb', 'drupal', 'php', 'node.js', 'python.', 'javascript', 'react', 'codecommit)']
# ['citrix', 'microsoft', 'vmware', 'sharepoint']
# ['python', 'vmware', 'mysql', 'javaee', 'apache']
# ['blucommerce', 'ubuntu', 'elasticsearch', 'cloudfront', 'blubolt’s', 'mysql', 'ruby', 'elasticache', 'blubolt', 'php']
# ['vmware', 'citrix', 'microsoft', 'myit']
# ['vmware', 'server', 'ibm']
# ['vmware']
# ['adobe', 'adobe illustrator']
# ['vmware']
# ['vmware', 'commvault.']
# ['adobe', 'artpro.', 'adobe illustrator', 'kodak']
# ['vmware', 'citrix', 'symantec']
# ['vmware', 'vmserver', 'vm']
# ['citrix', 'vblock', 'vmware']
# []
# ['gray.', 'node', 'graylog', 'new', '\\uf0fc', 'prometheus', 'micro', 'tests', 'services']
# ['vmware', 'netscaler', 'xenapp/xendesktop', 'xenmobile']
# ['vmware']
# ['dell', 'microsoft', 'vmware']
# ['microsoft sql', 'microsoft', 'the', 'mysql', 'rabbitmq']
# ['vmware']
# ['varonis', 'microsoft', 'vmware', 'dell', 'ibm']
# ['microsoft', 'vmware', 'citrix', 'dyntek', 'dell']
# ['vmware']
# ['netapp', 'vmware']
# ['microsoft word', 'adobe', 'adobe illustrator', 'office', 'powerpoint']
# ['linux', 'vmware', 'rancid', 'perl', 'php']
# ['linux', 'vmware', 'dell’s', 'juniper', 'perl', 'dell', 'php']
# <ipython-input-21-9726975dea28>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name][i] = res
# <ipython-input-22-71863bbd3bca>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

# %% [markdown]
# ### TECH Acc

# %%
summary = pd.read_csv(data_path)

# summary = summary[[ID,summaries,manually_tagged]]
summary[manually_tagged]=summary[manually_tagged].apply(clean_text)

summary = summary.sort_values(by=[ID], ascending=False)
summary.reset_index(inplace = True, drop = True)

# reading 
tech = pd.read_csv("Tech_pydictionary_final.csv")
col_name=tech.columns[-1]
tech[col_name] = tech[col_name].astype(str)
all_tech_words = list(tech[col_name].str.lower())
summary[summaries]=summary[summaries].astype(str)
all_strings = list(summary[summaries].str.lower())

i=1
tech_keys=[]
for item in all_strings:
#     print("***","TEST No,",i,"***")
    i=i+1
    tech_row=[]
    for k in all_tech_words:
        if k in item and len(k)>2:
           tech_row.append(k)
    tech_keys.append(tech_row)

summary['keywords']=tech_keys

def reg_match(txt, keyw):
    sep='|'
    temp = sep.join(['\\b' + i+'\\b' for i in keyw])
    matches = re.findall(temp,txt)
    if len(''.join(list(set(matches))))==0:
#         print(list(set(matches)))
        return []
    else:
        return list(set(matches))

summary['Tech_matched'] = summary.apply(
    lambda x: reg_match(x[summaries], x["keywords"]),
    axis = 1)

col_name_op = "Tech_matched"

df_cm = summary
df_cm = convert_data_format(df_cm, manually_tagged)
df_cm[manually_tagged] = df_cm[manually_tagged].fillna('[]')
count_context_technologies = []
for i in range(0, len(df_cm)):
    count_context_technologies.extend(df_cm[manually_tagged][i])
d = list(set(count_context_technologies))

tp = []
tn = []
fp = []
fn = []

TP = TN = FP = FN = 0

df_cm['Tech_Label'] = df_cm.apply(
    lambda x: get_tech_tagged_data(x[manually_tagged],tech_list), axis = 1)
string_match_tech_col = df_cm['Tech_Label']
list_tech_dataset = []

for i in range(0, len(df_cm)):
    list_tech_dataset.extend(df_cm["Tech_Label"][i])

set_tech = set(list_tech_dataset)

for i in range(0, len(df_cm)):
    l = df_cm[col_name_op][i]
    df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

for i in range(0, len(df_cm)):
  words = df_cm[col_name_op][i]
  stopwords = [0]
  for word in list(words):
    if word in stopwords:
      words.remove(word)
    
    
# list of technologies which are not in extracted list but are in tagged list i.e. FN entries
df_cm['FP_entries_TECH'] = df_cm.apply(lambda x: Diff(x["Tech_Label"], x[col_name_op]), axis = 1)

# list of technologies which are in extracted list and are in tagged list i.e. TP entries
df_cm['TP_entries_TECH'] = df_cm.apply(lambda x: Same(x["Tech_Label"], x[col_name_op]), axis = 1)

# list of technologies which are NOT extracted list and are in tagged list i.e. FN entries
df_cm['FN_entries_TECH'] = df_cm.apply(lambda x: Common(x["Tech_Label"], x[col_name_op]), axis = 1)
# function call
fp_entry =[]
tp = get_TP(df_cm, "Tech_Label", col_name_op)
fp, fp_entry_names = get_FP(df_cm, "Tech_Label", col_name_op)
fn = get_FN(df_cm, "Tech_Label", col_name_op)

# creating a dataframe
df_matrix = pd.DataFrame(list(zip(tp, fp, fn)), 
               columns =['TP', 'FP', "FN"])

df_matrix['Precision'] = df_matrix.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

df_matrix["Recall"] = df_matrix.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

df_matrix["f_score"] = df_matrix.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

df_cm=df_cm.drop(columns="keywords")
final_data = df_cm.join(df_matrix)
final_data.to_csv("ACC-TECH_BERT_preds_JOB_id2july.csv",index=False) ##########GIVE TECH ACC NAME############
# Out:
# <ipython-input-15-fa4e9f7308a3>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name][i] = res
# <ipython-input-17-a44b83c069d2>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

# %%
all_tech_words
# Out:
# ['visual basic.net', 'vmware', 'amazon ec2', 'symantec mail security']

# %% [markdown]
# ### ENG+TECH

# %%
data=pd.read_csv("BERT_preds_JOB_id_ENG_ONLY2july.csv")#only eng   #####READ ENG ACC SHEET GENERATED ABOVE########
bert_tags="BERT_Tags_ENG"
col_name_op="BERT_ENG+string_matched"

data[bert_tags] = data[bert_tags].apply(str)
data[bert_tags] = data[bert_tags].apply(eval)
data[bert_tags] = data[bert_tags].apply(remove_space)
tech = pd.read_csv("Tech_pydictionary_final.csv")
col_name=tech.columns[-1]
summary=data
tech[col_name] = tech[col_name].astype(str)
all_tech_words = list(tech[col_name].str.lower())
summary[summaries]=summary[summaries].astype(str)
all_strings = list(summary[summaries].str.lower())
i=1
tech_keys=[]
for item in all_strings:
#     print("***","TEST No,",i,"***")
    i=i+1
    tech_row=[]
    for k in all_tech_words:
        if k in item and len(k)>2:
           tech_row.append(k)
    tech_keys.append(tech_row)
summary['keywords']=tech_keys

summary['string_matched'] = summary.apply(lambda x: reg_match(x[summaries], x["keywords"]), axis = 1)
summary['BERT_ENG+string_matched'] = summary.apply(
    lambda x: combine(x[bert_tags], x["string_matched"]), 
    axis = 1)

data=summary

########CHANGE NAME ##################
data.to_csv("BERT_preds_JOB_id_ENG+TECH2july.csv")
###########READ SAME FILE####################
summary = pd.read_csv("BERT_preds_JOB_id_ENG+TECH2july.csv")

col_name_op ="BERT_ENG+string_matched"#column name

summary = summary.sort_values(by=[ID], ascending=False)
summary.reset_index(inplace = True, drop = True)

df_cm = summary
df_cm = convert_data_format(df_cm, col_name_op)

df_cm = convert_data_format(df_cm,manually_tagged)

count_context_technologies = []

for i in range(0, len(df_cm)):
    count_context_technologies.extend(df_cm[manually_tagged][i])
d = list(set(count_context_technologies))

tp = []
tn = []
fp = []
fn = []

TP = TN = FP = FN = 0

df_cm[manually_tagged] = df_cm[manually_tagged].fillna('[]')

for i in range(0, len(df_cm)):
    l = df_cm[col_name_op][i]
    df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

for i in range(0, len(df_cm)):
  words = df_cm[col_name_op][i]
  stopwords = [0]
  for word in list(words):
    if word in stopwords:
      words.remove(word)
    

# list of technologies which are not in extracted list but are in tagged list i.e. FN entries
df_cm['FP_entries'] = df_cm.apply(lambda x: Diff(x[manually_tagged], x[col_name_op]), axis = 1)

# list of technologies which are in extracted list and are in tagged list i.e. TP entries
df_cm['TP_entries'] = df_cm.apply(lambda x: Same(x[manually_tagged], x[col_name_op]), axis = 1)

# list of technologies which are NOT extracted list and are in tagged list i.e. FN entries
df_cm['FN_entries'] = df_cm.apply(lambda x: Common(x[manually_tagged], x[col_name_op]), axis = 1)
fp_entry =[]

tp = get_TP(df_cm, manually_tagged, col_name_op)
fp, fp_entry_names = get_FP(df_cm, manually_tagged, col_name_op)
fn = get_FN(df_cm, manually_tagged, col_name_op)

dict_fp = {}

for i in range(0, len(fp_entry_names)):
    fp_entry_names[i] = fp_entry_names[i].tolist()
    dict_fp[i] = fp_entry_names[i]

# creating a dataframe
df_matrix = pd.DataFrame(list(zip(tp, fp, fn)), 
               columns =['TP', 'FP', "FN"])

df_matrix['Precision'] = df_matrix.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

df_matrix["Recall"] = df_matrix.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

df_matrix["f_score"] = df_matrix.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

final_data = df_cm.join(df_matrix)
final_data.to_csv("ACC-ENG+TECH_BERT_preds_JOB_id2july.csv",index=False) ##########GIVE ENG+TECH ACC NAME############
# Out:
# <ipython-input-15-fa4e9f7308a3>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name][i] = res
# <ipython-input-19-8f74ca64818a>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

# %%
######        BERT-TECH    ##########
data_path = "BERT_prod_tagsv2.csv" #ENTER DATA PATH
ID = 'lead_id'# ID column name
summaries = 'summaries'#summaries column name
manually_tagged = 'prod_tag' #manual tag column name
bert_tags = 'BERT_Tags'#column name
##############################################################################################

data=pd.read_csv(data_path)
# data=data[[ID,summaries,manually_tagged,bert_tags]]
data[manually_tagged]=data[manually_tagged].apply(clean_text)

data[manually_tagged]=data[manually_tagged].apply(eval)
data[bert_tags] = data[bert_tags].apply(eval)
data[bert_tags] = data[bert_tags].apply(remove_space)


tech_data = pd.read_csv("Tech_pydictionary_final.csv")
tech_data["Tech_word"]=tech_data["Tech_word"].apply(clean_text)
tech_list = list(set(tech_data["Tech_word"]))
eng_data = pd.read_csv("Eng_pydictionary_final.csv")
eng_data["English_word"]=eng_data["English_word"].apply(clean_text)
eng_list= list(set(eng_data["English_word"]))


# (all entries which are in eng dictionary)
tech_bert_tags=[]
removed=0
kept=0
for i in range(0,len(data)):
    tech_bert_1sen=[]
    tags= data[bert_tags][i]
    for j in tags:
        if j in tech_list:
            kept+=1
            tech_bert_1sen.append(j)
        else:
            removed+=1
    tech_bert_tags.append(tech_bert_1sen)
data[bert_tags+"_TECH"]=tech_bert_tags

##############################################################################################
data.to_csv("BERT_preds_JOB_id_TECH_ONLY2july.csv",index=False)
'''SAME FILE WRITE AND READ'''
summary = pd.read_csv("BERT_preds_JOB_id_TECH_ONLY2july.csv")
##############################################################################################
# summary = summary[[ID,summaries,manually_tagged,bert_tags]]
summary = summary.sort_values(by=[ID], ascending=False)
summary.reset_index(inplace = True, drop = True)
col_name_op = "BERT_Tags_TECH"

df_cm = summary
df_cm = convert_data_format(df_cm, col_name_op)
df_cm = convert_data_format(df_cm, manually_tagged)

count_context_technologies = []

for i in range(0, len(df_cm)):
    count_context_technologies.extend(df_cm[manually_tagged][i])
d = list(set(count_context_technologies))

tp = []
tn = []
fp = []
fn = []
TP = TN = FP = FN = 0
df_cm[manually_tagged] = df_cm[manually_tagged].fillna('[]')

df_cm['tech_Label']=df_cm[manually_tagged].copy()

tech_tag_list = []

df_cm['tech_Label'] = df_cm.apply(
    lambda x: get_tech_tagged_data(x["tech_Label"], tech_list),
    axis = 1)
list_tech_dataset = []

# fill with 
for i in range(0, len(df_cm)):
    list_tech_dataset.extend(df_cm["tech_Label"][i])

set_tech = set(list_tech_dataset)

for i in range(0, len(df_cm)):
    l = df_cm[col_name_op][i]
    df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

for i in range(0, len(df_cm)):
  words = df_cm[col_name_op][i]
  stopwords = [0]
  for word in list(words):
    if word in stopwords:
      words.remove(word)

# list of technologies which are not in extracted list but are in tagged list i.e. FN entries
df_cm['FP_entries_tech'] = df_cm.apply(lambda x: Diff(x["tech_Label"], x[col_name_op]), axis = 1)

# list of technologies which are in extracted list and are in tagged list i.e. TP entries
df_cm['TP_entries_tech'] = df_cm.apply(lambda x: Same(x["tech_Label"], x[col_name_op]), axis = 1)

# list of technologies which are NOT extracted list and are in tagged list i.e. FN entries
df_cm['FN_entries_tech'] = df_cm.apply(lambda x: Common(x["tech_Label"], x[col_name_op]), axis = 1)

fp_entry =[]
tp = get_TP(df_cm, "tech_Label", col_name_op)
fp, fp_entry_names = get_FP(df_cm, "tech_Label", col_name_op)
fn = get_FN(df_cm, "tech_Label", col_name_op)
# print(len(tp), len(fp), len(fn))
dict_fp = {}

for i in range(0, len(fp_entry_names)):
    fp_entry_names[i] = fp_entry_names[i].tolist()
    dict_fp[i] = fp_entry_names[i]

# creating a dataframe
df_matrix = pd.DataFrame(list(zip(tp, fp, fn)), 
               columns =['TP', 'FP', "FN"])
df_matrix['Precision'] = df_matrix.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

df_matrix["Recall"] = df_matrix.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

df_matrix["f_score"] = df_matrix.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

final_data = df_cm.join(df_matrix)
final_data.to_csv("ACC-BERT_preds_TECH_ONLY2july.csv",index=False) ##########GIVE ENG ACC NAME############
# Out:
# <ipython-input-15-fa4e9f7308a3>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name][i] = res
# <ipython-input-20-4a713a3d915c>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]
