# %%
# Importing the libraries here

import pandas as pd
import numpy as np
import ast
import json
from operator import add 
from operator import truediv
import re
# import swifter
from tqdm import tqdm

# %%
#data for TECH Acc
# summary = pd.read_csv("BERT_Pred_189_FULL_with_eng.csv")
# summary = pd.read_csv("BERT_Pred_189_FULL_without_MASTER.csv")
summary = pd.read_csv("Bert_Preds_EXP_Summary_TECH_only.csv")
# summary = pd.read_csv("BERT_Pred_500_without_MASTER_ENG+TECH_ROW_WISE.csv")

# %%
summary.head()
# Out:
#    Unnamed: 0                           id  \
# 0           0  -4W7H0UFJneCeHmDK-b9LA_0000
# 1           1  -5KQNWRmZUAxcmAKsBVFCw_0000
# 2           2  -9vRkMCaww4q9MTuMhg16A_0000
# 3           3  -nZOV-0MncypcjMiVI38pQ_0000
# 4           4  0-6kc4T3YjlcPQYOK7Wt4g_0000
#
#                                            summaries  \
# 0   im a seasoned software consultant and manager...
# 1   committed and clientfocused technical lead wi...
# 2   professional web site design and development ...
# 3   experienced it software and infrastructure pr...
# 4   now hiring actively sourcing nfoh manager agm...
#
#                        exact_matched_patt_contextual  \
# 0                                          ['gmail']
# 1  ['oracle pl/sql', 'vb.net', 'hp quality center...
# 2                      ['html', 'php', 'javascript']
# 3  ['versionone', 'ios', 'sharepoint', 'windows 1...
# 4                                          ['gmail']
#
#                                       string_matched
# 0                                                 []
# 1                                     ['windows xp']
# 2                              ['javascript', 'php']
# 3  ['citrix xenmobile', 'sharepoint', 'versionone...
# 4                                                 []

# %%
summary = summary[['id','summaries','exact_matched_patt_contextual']]

# %%
summary = summary.sort_values(by=['id'], ascending=False)
summary.reset_index(inplace = True, drop = True)

# %%
# reading 
tech = pd.read_csv("Tech_pydictionary_2.csv")

tech.columns = ["index", "title"]
tech.drop(columns = ["index"], axis =1 , inplace = True)
tech.reset_index(inplace = True, drop = True)

# %%
tech['title'] = tech['title'].astype(str)
all_tech_words = list(tech['title'].str.lower())
summary["summaries"]=summary["summaries"].astype(str)
all_strings = list(summary["summaries"].str.lower())

# %%
i=1
tech_keys=[]
for item in all_strings:
#     print("***","TEST No,",i,"***")
    i=i+1
    tech_row=[]
    for k in all_tech_words:
        if k in item and len(k)>2:
           tech_row.append(k)
    tech_keys.append(tech_row)

# %%
summary['keywords']=tech_keys
summary.head()
# Out:
#                             id  \
# 0  zeExhAA-r0lbcTQH41BlFg_0000
# 1  zSvilx9nLA2ADlgkbh0Avw_0000
# 2  z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3  yCI14syBYDiD3pwIDKVEKQ_0000
# 4  xuMF3K3aFCBGMOElWU0WTA_0000
#
#                                            summaries  \
# 0   senior account manager at verizon enterprise ...
# 1   12 years of software development experience o...
# 2   ours excavating is a commercial excavating de...
# 3   getting things done voor iedere uitdaging de ...
# 4   12 +years of experience in development qa dev...
#
#                        exact_matched_patt_contextual  \
# 0                             ['verizon enterprise']
# 1  ['microsoft.net', 'asp.net', 'java', 'jquery',...
# 2                                          ['gmail']
# 3                                          ['gmail']
# 4                               ['java', 'selenium']
#
#                                             keywords
# 0                         [pris, verizon enterprise]
# 1  [eploy, xperience, informa, que, nex, javascri...
# 2                      [xperience, ava, digg, gmail]
# 3                           [twik, omp, plex, gmail]
# 4  [xperience, ora, sap erp, que, shopp, ava, esi...

# %%
import re
def reg_match(txt, keyw):
    sep='|'
    temp = sep.join(['\\b' + i+'\\b' for i in keyw])
    matches = re.findall(temp,txt)
    return list(set(matches))

# %%
summary['Tech_matched'] = summary.apply(lambda x: reg_match(x["summaries"], x["keywords"]), axis = 1)

# %%
summary
# Out:
#                               id  \
# 0    zeExhAA-r0lbcTQH41BlFg_0000
# 1    zSvilx9nLA2ADlgkbh0Avw_0000
# 2    z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3    yCI14syBYDiD3pwIDKVEKQ_0000
# 4    xuMF3K3aFCBGMOElWU0WTA_0000
# 5    xlZw0zgxhTJ34Zkj8qz3ow_0000
# 6    xi1WETjz2xTW4jBSE8U8DQ_0000
# 7    xfwmFMDDgwYyhZMc1MJcpg_0000
# 8    wy3R8tztPGIHWzOl1wTTOg_0000
# 9    wmiO3uJcgJcjGMruOdWykg_0000
# 10   wfeb9x1PszS-BeaAlBlS4w_0000
# 11   wTue5Ls4a6DY7MB4rxCynw_0000
# 12   wPQdim5iOSpeJnA5zh5lHA_0000
# 13   wMr2Z7wACq1tSdfGQrWP2Q_0000
# 14   wAXzF14t17vJAESEBSbWEA_0000
# 15   w7JBrnHPYOXAMYg8JfEgSA_0000
# 16   w-hPsoDEjY5ZRoWQNRv35w_0000
# 17   vtqI5sw2Q7Fj0G5MZH6EWg_0000
# 18   vYgrvPTNNbLa265V3PRmVg_0000
# 19   vXW8UmqWG8kVfU4xwMnCyA_0000
# 20   vSe8gOZBgd6rGgbUkSfwJw_0000
# 21   vRjy6aodY19BeyKo4keaPQ_0000
# 22   vLfvENwdwLwDMe25RDBPKg_0000
# 23   v5Nwdhiqr3ljLUHBnuO9Qg_0000
# 24   uz9Z4HzieWUGIqtTlUf2Zw_0000
# 25   uwDQOYrDZyRmem7R9CKJhg_0000
# 26   u1oSj10QoLMrQrxymPaKTQ_0000
# 27   ty2jU8tnLdR-sR-GrJgolQ_0000
# 28   tj2oQp7zQUNFyOTmOjIHjA_0000
# 29   tMKWEE6BEyLjEppcAlHzMw_0000
# ..                           ...
# 361  2zMB0WsDD8dnIs7l0bjqVQ_0000
# 362  2oBWrvGcQqLc8Ox60kqGIA_0000
# 363  2FJEQ4GPKPXFuN72RReGXw_0000
# 364  23i0ds45WtgDvidngtBVtg_0000
# 365  21ZRtlKSI9Hbf-It-9IhQg_0000
# 366  20ACC5Zu7Qw5ljETXM9-SQ_0000
# 367  1yK4SvaWDqtE9Cqekb4Y5A_0000
# 368  1wztIVtYwHYQHlkeRbcngg_0000
# 369  1lfE0YZm4jOGOetZjjwYtA_0000
# 370  1ZHDRD60jc9f-PcblZlJuQ_0000
# 371  1VUCEgBHgHm4iH3nV8Lbiw_0000
# 372  1JQBRBlqf8f0DIgiXa5fyA_0000
# 373  17pBi6GXDQNPBL9mda7mIQ_0000
# 374  11fAMF1Dciid6cPaoWwM-w_0000
# 375  0zbpjZpxowAXfttxPbL9pA_0000
# 376  0atiAweBnVg2uhlsm7qWkA_0000
# 377  0GBPD-n6-mPJNsQlznKKYQ_0000
# 378  0BWE1RkxLyLbumqkdHvvVw_0000
# 379  05l6kpEnLfOAFSGhR8mDAw_0000
# 380  03tu8YiZ7JKoHCrzT5Ug2g_0000
# 381  03GYW3MC-xU0rC2CLecevA_0000
# 382  0-6kc4T3YjlcPQYOK7Wt4g_0000
# 383  -nZOV-0MncypcjMiVI38pQ_0000
# 384  -9vRkMCaww4q9MTuMhg16A_0000
# 385  -5KQNWRmZUAxcmAKsBVFCw_0000
# 386  -4W7H0UFJneCeHmDK-b9LA_0000
# 387                          NaN
# 388                          NaN
# 389                          NaN
# 390                          NaN
#
#                                              summaries  \
# 0     senior account manager at verizon enterprise ...
# 1     12 years of software development experience o...
# 2     ours excavating is a commercial excavating de...
# 3     getting things done voor iedere uitdaging de ...
# 4     12 +years of experience in development qa dev...
# 5     i am an upcoming graduate from the university...
# 6     specialties advertising technology agile soft...
# 7     cpa eligible currently taking cpa exams and a...
# 8     an experienced test consultant in the field o...
# 9     an accomplished resultsoriented customer supp...
# 10    i am a selfstarter with a passion for busines...
# 11    im an extrovert with good managerial skills h...
# 12    goals involve using systems engineering and l...
# 13    i have been working in the film and tv indust...
# 14    experienced developer java bpm and mainframe ...
# 15    senior sales executive account manager and bu...
# 16    im equal parts left and rightbrain which mean...
# 17    vicky nguyen is a news reporter for keytnn vi...
# 18    experienced digital marketing manager with a ...
# 19    im also the ceo founder of melbourne fashion ...
# 20    student at mriem rohtak affliated to mduniver...
# 21    im specialized in android but have worked wit...
# 22    broadcast executive at dentsu aegis network a...
# 23    specialties operating system linux windows pr...
# 24    i am a human resource manager with over six y...
# 25    experience of schematic capture and pcb layou...
# 26    working on projects on ios and android since ...
# 27    rahul midha is a strategic professional with ...
# 28    a selfmotivated english masters graduate stud...
# 29    sap certificated abap android spring boot net...
# ..                                                 ...
# 361   i find pleasure and energy in building up rel...
# 362   specialties brand management budgeting custom...
# 363   to reach me via email laurefloriach gmailcom ...
# 364   focusing on combining understanding of financ...
# 365   ive now been working as a webdevelop for cutt...
# 366   working from last 4 years as a java developer...
# 367   permanent resident in canada n n sap certifie...
# 368   view ajith vasudevs professional profile on l...
# 369   i am specialised in functional and preventive...
# 370   experienced finance professional leading orig...
# 371   a resultoriented professional offering 4 year...
# 372   it infrastructure architect system engineer d...
# 373   hello i am team leader at innovana think lab ...
# 374   career goalnnbe responsible for the image of ...
# 375   close protection operative psd tl control ris...
# 376   1+ years of experience in the development of ...
# 377   assistant category manager corporate card and...
# 378   current creative specialist for one of the co...
# 379   i am a second year master student in business...
# 380   sr test development engineer at sandisk staff...
# 381   i have a solid background in retail analysis ...
# 382   now hiring actively sourcing nfoh manager agm...
# 383   experienced it software and infrastructure pr...
# 384   professional web site design and development ...
# 385   committed and clientfocused technical lead wi...
# 386   im a seasoned software consultant and manager...
# 387   im passionate about finding issue with the so...
# 388   senior software engineer with 6+ years in ana...
# 389   we make some cool websites and desktop applic...
# 390   multitalented creative marketing and design p...
#
#                          exact_matched_patt_contextual  \
# 0                               ['verizon enterprise']
# 1    ['microsoft.net', 'asp.net', 'java', 'jquery',...
# 2                                            ['gmail']
# 3                                            ['gmail']
# 4                                 ['java', 'selenium']
# 5                                            ['gmail']
# 6                               ['java', 'javascript']
# 7                                            ['gmail']
# 8    ['ibm rational', 'soapui', 'selenium', 'javasc...
# 9                                            ['gmail']
# 10                                ['google analytics']
# 11                                  ['adobe', 'forte']
# 12                                           ['gmail']
# 13                                           ['gmail']
# 14   ['java', 'informatica', 'spring', 'html', 'jav...
# 15                                           ['gmail']
# 16                                           ['gmail']
# 17                                           ['gmail']
# 18                                ['google analytics']
# 19                                           ['gmail']
# 20                     ['ibm global process services']
# 21              ['android', 'ios', 'ethereum', 'java']
# 22                            ['dentsu aegis network']
# 23   ['linux', 'php', 'jquery', 'android', 'javascr...
# 24                                           ['gmail']
# 25                                ['cadence', 'intel']
# 26   ['ios', 'android', 'angularjs', 'java', 'accen...
# 27                                           ['gmail']
# 28                                           ['gmail']
# 29          ['android', 'spring', 'angularjs', 'java']
# ..                                                 ...
# 361                                          ['gmail']
# 362        ['microsoft office', 'microsoft publisher']
# 363                                          ['gmail']
# 364                               ['google analytics']
# 365                              ['php', 'javascript']
# 366  ['java', 'j2ee', 'october', 'forte', 'spring',...
# 367    ['db2', 'sap netweaver', 'sap hana', 'sap crm']
# 368                                       ['salesbox']
# 369                                          ['gmail']
# 370                                          ['gmail']
# 371  ['accenture', 'google analytics', 'appnexus', ...
# 372  ['linux', 'openshift', 'kvm', 'xen', 'ovirt', ...
# 373  ['asp.net', 'jquery', 'html', 'javascript', 's...
# 374                                          ['gmail']
# 375                                          ['janus']
# 376  ['linux', 'android', 'intel', 'atomic', 'cgit'...
# 377                                       ['teletech']
# 378                                      ['totaljobs']
# 379                                          ['gmail']
# 380                     ['sandisk', 'western digital']
# 381                               ['microsoft office']
# 382                                          ['gmail']
# 383  ['versionone', 'ios', 'sharepoint', 'windows 1...
# 384                      ['html', 'php', 'javascript']
# 385  ['oracle pl/sql', 'vb.net', 'hp quality center...
# 386                                          ['gmail']
# 387                          ['selenium', 'cognizant']
# 388                              ['asp.net', 'jquery']
# 389                                 ['java', 'joomla']
# 390                                          ['adobe']
#
#                                               keywords  \
# 0                           [pris, verizon enterprise]
# 1    [eploy, xperience, informa, que, nex, javascri...
# 2                        [xperience, ava, digg, gmail]
# 3                             [twik, omp, plex, gmail]
# 4    [xperience, ora, sap erp, que, shopp, ava, esi...
# 5    [xperience, alexa, ets, verifi, que, lita, res...
# 6               [javascript, ava, ving, adverti, cien]
# 7    [ami, emplo, imal, ava, ios, ning, omp, mploy,...
# 8    [xperience, perl, ibm rational, javascript, av...
# 9    [ento, adrive, rform, chai, perf, omp, ics, ni...
# 10   [google analytics, xperience, and co, bric, em...
# 11   [xperience, esign, vendo, iri, ning, endor, st...
# 12   [xperience, ora, lita, orat, nvolv, soci, ning...
# 13          [evie, ami, obs, rsm, ning, gmail, amilia]
# 14   [xperience, informa, ora, jboss, continu, que,...
# 15   [xperience, accounts, informa, esign, hips, ni...
# 16                                [esign, ning, gmail]
# 17   [nativ, soci, ning, kcom, carto, gmail, carto,...
# 18   [google analytics, xperience, ravelin, ets, ey...
# 19         [xperience, ami, and co, esign, omp, gmail]
# 20                       [ibm global process services]
# 21   [ento, ethereum, remo, ava, ios, ning, dito, v...
# 22                        [dentsu aegis network, ning]
# 23   [codeigniter, cakephp, ora, php, nativ, que, s...
# 24   [xperience, emplo, rform, perf, ress, ning, om...
# 25   [xperience, lifecycle, esign, soci, allego, om...
# 26   [xperience, and co, indo, ava, ress, enth, ios...
# 27   [xperience, pris, vendo, combin, ning, endor, ...
# 28                           [ress, enth, ning, gmail]
# 29                                    [ava, angularjs]
# ..                                                 ...
# 361  [xperience, ets, que, riter, chai, ava, esign,...
# 362  [lita, microsoft publisher, blis, ning, materi...
# 363                           [nativ, omp, flo, gmail]
# 364  [google analytics, xperience, ets, emplo, lua,...
# 365  [xperience, evie, php, javascript, ava, esign,...
# 366             [and co, ava, soci, octo, j2ee, ibm i]
# 367  [xperience, perma, db2, ava, nvolv, soci, sap ...
# 368                                         [salesbox]
# 369  [informa, alis, and co, rform, perf, ress, nin...
# 370  [xperience, amo, informa, ora, nex, orat, ics,...
# 371  [google analytics, xperience, facebook ads, am...
# 372  [openshift, xperience, glusterfs, ami, ora, xe...
# 373  [xperience, que, javascript, indo, ava, esign,...
# 374  [ami, and co, drie, trac, ress, etrac, omp, hr...
# 375                                                 []
# 376  [xperience, ora, continu, orat, indo, ava, esi...
# 377                              [ora, teletech, orat]
# 378  [xperience, conversio, totaljobs, ora, alis, a...
# 379                                            [gmail]
# 380                                    [sandisk, staf]
# 381  [xperience, ento, microstrategy, ress, microso...
# 382  [xperience, nect, ets, jaco, staf, iri, ning, ...
# 383  [xperience, harepoint, versionone, ora, xen, c...
# 384  [php, and co, javascript, ava, esign, ning, ic...
# 385     [xperience, ora, indo, windows xp, sched, acl]
# 386   [xperience, ets, alis, and co, que, hips, gmail]
# 387                                             [soci]
# 388  [netbase, xperience, amo, ami, informa, ora, s...
# 389                         [shopp, ava, ress, joomla]
# 390  [xperience, and co, xpand, awin, que, italent,...
#
#                                           Tech_matched
# 0                                 [verizon enterprise]
# 1    [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                   []
# 3                                                   []
# 4                                      [j2ee, sap erp]
# 5                                                   []
# 6                                         [javascript]
# 7                                                   []
# 8             [soapui, perl, javascript, ibm rational]
# 9                                                   []
# 10                                                  []
# 11                                   [adobe photoshop]
# 12                                                  []
# 13                                                  []
# 14   [jboss, jquery, db2, jenkins, javascript, info...
# 15                                          [accounts]
# 16                                                  []
# 17                                                  []
# 18                                  [google analytics]
# 19                                                  []
# 20                       [ibm global process services]
# 21                                     [ios, ethereum]
# 22                              [dentsu aegis network]
# 23   [cvs, php, jquery, ios, adobe dreamweaver, cod...
# 24                                                  []
# 25                                     [intel, allego]
# 26                         [ios, accenture, angularjs]
# 27                                                  []
# 28                                                  []
# 29                                         [angularjs]
# ..                                                 ...
# 361                                                 []
# 362            [microsoft publisher, microsoft office]
# 363                                                 []
# 364                            [google analytics, moz]
# 365                                  [php, javascript]
# 366                                             [j2ee]
# 367            [sap hana, sap crm, sap netweaver, db2]
# 368                                         [salesbox]
# 369                                                 []
# 370                                                 []
# 371  [google analytics, facebook ads, accenture, ap...
# 372  [kvm, openshift, openstack, ansible, vmware, o...
# 373  [microsoft visual studio, jquery, sqlite, xama...
# 374                                                 []
# 375                                                 []
# 376                                       [intel, dsi]
# 377                                         [teletech]
# 378                                        [totaljobs]
# 379                                                 []
# 380                                          [sandisk]
# 381  [microsoft excel, microsoft office, microstrat...
# 382                                                 []
# 383    [ios, sharepoint, versionone, citrix xenmobile]
# 384                                  [php, javascript]
# 385                                       [windows xp]
# 386                                                 []
# 387                                                 []
# 388                                 [jquery, sitecore]
# 389                                           [joomla]
# 390                                  [adobe photoshop]
#
# [391 rows x 5 columns]

# %%
col_name_op = "Tech_matched"
# col_name_op = "string_matched"

# %%
# Pass the matched technology column that we got
def convert_data_format(df,column_name):
    
    for i in range(0, len(df)):
        
        if df[column_name][i][0] == '[':
            res = ast.literal_eval(df[column_name][i])
            df[column_name][i] = res
            
        else:
            x = []
            x.insert(0, df[column_name][i])
            df[column_name][i] = x
            
    return df

df_cm = summary

# %%
df_cm
# Out:
#                               id  \
# 0    zeExhAA-r0lbcTQH41BlFg_0000
# 1    zSvilx9nLA2ADlgkbh0Avw_0000
# 2    z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3    yCI14syBYDiD3pwIDKVEKQ_0000
# 4    xuMF3K3aFCBGMOElWU0WTA_0000
# 5    xlZw0zgxhTJ34Zkj8qz3ow_0000
# 6    xi1WETjz2xTW4jBSE8U8DQ_0000
# 7    xfwmFMDDgwYyhZMc1MJcpg_0000
# 8    wy3R8tztPGIHWzOl1wTTOg_0000
# 9    wmiO3uJcgJcjGMruOdWykg_0000
# 10   wfeb9x1PszS-BeaAlBlS4w_0000
# 11   wTue5Ls4a6DY7MB4rxCynw_0000
# 12   wPQdim5iOSpeJnA5zh5lHA_0000
# 13   wMr2Z7wACq1tSdfGQrWP2Q_0000
# 14   wAXzF14t17vJAESEBSbWEA_0000
# 15   w7JBrnHPYOXAMYg8JfEgSA_0000
# 16   w-hPsoDEjY5ZRoWQNRv35w_0000
# 17   vtqI5sw2Q7Fj0G5MZH6EWg_0000
# 18   vYgrvPTNNbLa265V3PRmVg_0000
# 19   vXW8UmqWG8kVfU4xwMnCyA_0000
# 20   vSe8gOZBgd6rGgbUkSfwJw_0000
# 21   vRjy6aodY19BeyKo4keaPQ_0000
# 22   vLfvENwdwLwDMe25RDBPKg_0000
# 23   v5Nwdhiqr3ljLUHBnuO9Qg_0000
# 24   uz9Z4HzieWUGIqtTlUf2Zw_0000
# 25   uwDQOYrDZyRmem7R9CKJhg_0000
# 26   u1oSj10QoLMrQrxymPaKTQ_0000
# 27   ty2jU8tnLdR-sR-GrJgolQ_0000
# 28   tj2oQp7zQUNFyOTmOjIHjA_0000
# 29   tMKWEE6BEyLjEppcAlHzMw_0000
# ..                           ...
# 361  2zMB0WsDD8dnIs7l0bjqVQ_0000
# 362  2oBWrvGcQqLc8Ox60kqGIA_0000
# 363  2FJEQ4GPKPXFuN72RReGXw_0000
# 364  23i0ds45WtgDvidngtBVtg_0000
# 365  21ZRtlKSI9Hbf-It-9IhQg_0000
# 366  20ACC5Zu7Qw5ljETXM9-SQ_0000
# 367  1yK4SvaWDqtE9Cqekb4Y5A_0000
# 368  1wztIVtYwHYQHlkeRbcngg_0000
# 369  1lfE0YZm4jOGOetZjjwYtA_0000
# 370  1ZHDRD60jc9f-PcblZlJuQ_0000
# 371  1VUCEgBHgHm4iH3nV8Lbiw_0000
# 372  1JQBRBlqf8f0DIgiXa5fyA_0000
# 373  17pBi6GXDQNPBL9mda7mIQ_0000
# 374  11fAMF1Dciid6cPaoWwM-w_0000
# 375  0zbpjZpxowAXfttxPbL9pA_0000
# 376  0atiAweBnVg2uhlsm7qWkA_0000
# 377  0GBPD-n6-mPJNsQlznKKYQ_0000
# 378  0BWE1RkxLyLbumqkdHvvVw_0000
# 379  05l6kpEnLfOAFSGhR8mDAw_0000
# 380  03tu8YiZ7JKoHCrzT5Ug2g_0000
# 381  03GYW3MC-xU0rC2CLecevA_0000
# 382  0-6kc4T3YjlcPQYOK7Wt4g_0000
# 383  -nZOV-0MncypcjMiVI38pQ_0000
# 384  -9vRkMCaww4q9MTuMhg16A_0000
# 385  -5KQNWRmZUAxcmAKsBVFCw_0000
# 386  -4W7H0UFJneCeHmDK-b9LA_0000
# 387                          NaN
# 388                          NaN
# 389                          NaN
# 390                          NaN
#
#                                              summaries  \
# 0     senior account manager at verizon enterprise ...
# 1     12 years of software development experience o...
# 2     ours excavating is a commercial excavating de...
# 3     getting things done voor iedere uitdaging de ...
# 4     12 +years of experience in development qa dev...
# 5     i am an upcoming graduate from the university...
# 6     specialties advertising technology agile soft...
# 7     cpa eligible currently taking cpa exams and a...
# 8     an experienced test consultant in the field o...
# 9     an accomplished resultsoriented customer supp...
# 10    i am a selfstarter with a passion for busines...
# 11    im an extrovert with good managerial skills h...
# 12    goals involve using systems engineering and l...
# 13    i have been working in the film and tv indust...
# 14    experienced developer java bpm and mainframe ...
# 15    senior sales executive account manager and bu...
# 16    im equal parts left and rightbrain which mean...
# 17    vicky nguyen is a news reporter for keytnn vi...
# 18    experienced digital marketing manager with a ...
# 19    im also the ceo founder of melbourne fashion ...
# 20    student at mriem rohtak affliated to mduniver...
# 21    im specialized in android but have worked wit...
# 22    broadcast executive at dentsu aegis network a...
# 23    specialties operating system linux windows pr...
# 24    i am a human resource manager with over six y...
# 25    experience of schematic capture and pcb layou...
# 26    working on projects on ios and android since ...
# 27    rahul midha is a strategic professional with ...
# 28    a selfmotivated english masters graduate stud...
# 29    sap certificated abap android spring boot net...
# ..                                                 ...
# 361   i find pleasure and energy in building up rel...
# 362   specialties brand management budgeting custom...
# 363   to reach me via email laurefloriach gmailcom ...
# 364   focusing on combining understanding of financ...
# 365   ive now been working as a webdevelop for cutt...
# 366   working from last 4 years as a java developer...
# 367   permanent resident in canada n n sap certifie...
# 368   view ajith vasudevs professional profile on l...
# 369   i am specialised in functional and preventive...
# 370   experienced finance professional leading orig...
# 371   a resultoriented professional offering 4 year...
# 372   it infrastructure architect system engineer d...
# 373   hello i am team leader at innovana think lab ...
# 374   career goalnnbe responsible for the image of ...
# 375   close protection operative psd tl control ris...
# 376   1+ years of experience in the development of ...
# 377   assistant category manager corporate card and...
# 378   current creative specialist for one of the co...
# 379   i am a second year master student in business...
# 380   sr test development engineer at sandisk staff...
# 381   i have a solid background in retail analysis ...
# 382   now hiring actively sourcing nfoh manager agm...
# 383   experienced it software and infrastructure pr...
# 384   professional web site design and development ...
# 385   committed and clientfocused technical lead wi...
# 386   im a seasoned software consultant and manager...
# 387   im passionate about finding issue with the so...
# 388   senior software engineer with 6+ years in ana...
# 389   we make some cool websites and desktop applic...
# 390   multitalented creative marketing and design p...
#
#                          exact_matched_patt_contextual  \
# 0                               ['verizon enterprise']
# 1    ['microsoft.net', 'asp.net', 'java', 'jquery',...
# 2                                            ['gmail']
# 3                                            ['gmail']
# 4                                 ['java', 'selenium']
# 5                                            ['gmail']
# 6                               ['java', 'javascript']
# 7                                            ['gmail']
# 8    ['ibm rational', 'soapui', 'selenium', 'javasc...
# 9                                            ['gmail']
# 10                                ['google analytics']
# 11                                  ['adobe', 'forte']
# 12                                           ['gmail']
# 13                                           ['gmail']
# 14   ['java', 'informatica', 'spring', 'html', 'jav...
# 15                                           ['gmail']
# 16                                           ['gmail']
# 17                                           ['gmail']
# 18                                ['google analytics']
# 19                                           ['gmail']
# 20                     ['ibm global process services']
# 21              ['android', 'ios', 'ethereum', 'java']
# 22                            ['dentsu aegis network']
# 23   ['linux', 'php', 'jquery', 'android', 'javascr...
# 24                                           ['gmail']
# 25                                ['cadence', 'intel']
# 26   ['ios', 'android', 'angularjs', 'java', 'accen...
# 27                                           ['gmail']
# 28                                           ['gmail']
# 29          ['android', 'spring', 'angularjs', 'java']
# ..                                                 ...
# 361                                          ['gmail']
# 362        ['microsoft office', 'microsoft publisher']
# 363                                          ['gmail']
# 364                               ['google analytics']
# 365                              ['php', 'javascript']
# 366  ['java', 'j2ee', 'october', 'forte', 'spring',...
# 367    ['db2', 'sap netweaver', 'sap hana', 'sap crm']
# 368                                       ['salesbox']
# 369                                          ['gmail']
# 370                                          ['gmail']
# 371  ['accenture', 'google analytics', 'appnexus', ...
# 372  ['linux', 'openshift', 'kvm', 'xen', 'ovirt', ...
# 373  ['asp.net', 'jquery', 'html', 'javascript', 's...
# 374                                          ['gmail']
# 375                                          ['janus']
# 376  ['linux', 'android', 'intel', 'atomic', 'cgit'...
# 377                                       ['teletech']
# 378                                      ['totaljobs']
# 379                                          ['gmail']
# 380                     ['sandisk', 'western digital']
# 381                               ['microsoft office']
# 382                                          ['gmail']
# 383  ['versionone', 'ios', 'sharepoint', 'windows 1...
# 384                      ['html', 'php', 'javascript']
# 385  ['oracle pl/sql', 'vb.net', 'hp quality center...
# 386                                          ['gmail']
# 387                          ['selenium', 'cognizant']
# 388                              ['asp.net', 'jquery']
# 389                                 ['java', 'joomla']
# 390                                          ['adobe']
#
#                                               keywords  \
# 0                           [pris, verizon enterprise]
# 1    [eploy, xperience, informa, que, nex, javascri...
# 2                        [xperience, ava, digg, gmail]
# 3                             [twik, omp, plex, gmail]
# 4    [xperience, ora, sap erp, que, shopp, ava, esi...
# 5    [xperience, alexa, ets, verifi, que, lita, res...
# 6               [javascript, ava, ving, adverti, cien]
# 7    [ami, emplo, imal, ava, ios, ning, omp, mploy,...
# 8    [xperience, perl, ibm rational, javascript, av...
# 9    [ento, adrive, rform, chai, perf, omp, ics, ni...
# 10   [google analytics, xperience, and co, bric, em...
# 11   [xperience, esign, vendo, iri, ning, endor, st...
# 12   [xperience, ora, lita, orat, nvolv, soci, ning...
# 13          [evie, ami, obs, rsm, ning, gmail, amilia]
# 14   [xperience, informa, ora, jboss, continu, que,...
# 15   [xperience, accounts, informa, esign, hips, ni...
# 16                                [esign, ning, gmail]
# 17   [nativ, soci, ning, kcom, carto, gmail, carto,...
# 18   [google analytics, xperience, ravelin, ets, ey...
# 19         [xperience, ami, and co, esign, omp, gmail]
# 20                       [ibm global process services]
# 21   [ento, ethereum, remo, ava, ios, ning, dito, v...
# 22                        [dentsu aegis network, ning]
# 23   [codeigniter, cakephp, ora, php, nativ, que, s...
# 24   [xperience, emplo, rform, perf, ress, ning, om...
# 25   [xperience, lifecycle, esign, soci, allego, om...
# 26   [xperience, and co, indo, ava, ress, enth, ios...
# 27   [xperience, pris, vendo, combin, ning, endor, ...
# 28                           [ress, enth, ning, gmail]
# 29                                    [ava, angularjs]
# ..                                                 ...
# 361  [xperience, ets, que, riter, chai, ava, esign,...
# 362  [lita, microsoft publisher, blis, ning, materi...
# 363                           [nativ, omp, flo, gmail]
# 364  [google analytics, xperience, ets, emplo, lua,...
# 365  [xperience, evie, php, javascript, ava, esign,...
# 366             [and co, ava, soci, octo, j2ee, ibm i]
# 367  [xperience, perma, db2, ava, nvolv, soci, sap ...
# 368                                         [salesbox]
# 369  [informa, alis, and co, rform, perf, ress, nin...
# 370  [xperience, amo, informa, ora, nex, orat, ics,...
# 371  [google analytics, xperience, facebook ads, am...
# 372  [openshift, xperience, glusterfs, ami, ora, xe...
# 373  [xperience, que, javascript, indo, ava, esign,...
# 374  [ami, and co, drie, trac, ress, etrac, omp, hr...
# 375                                                 []
# 376  [xperience, ora, continu, orat, indo, ava, esi...
# 377                              [ora, teletech, orat]
# 378  [xperience, conversio, totaljobs, ora, alis, a...
# 379                                            [gmail]
# 380                                    [sandisk, staf]
# 381  [xperience, ento, microstrategy, ress, microso...
# 382  [xperience, nect, ets, jaco, staf, iri, ning, ...
# 383  [xperience, harepoint, versionone, ora, xen, c...
# 384  [php, and co, javascript, ava, esign, ning, ic...
# 385     [xperience, ora, indo, windows xp, sched, acl]
# 386   [xperience, ets, alis, and co, que, hips, gmail]
# 387                                             [soci]
# 388  [netbase, xperience, amo, ami, informa, ora, s...
# 389                         [shopp, ava, ress, joomla]
# 390  [xperience, and co, xpand, awin, que, italent,...
#
#                                           Tech_matched
# 0                                 [verizon enterprise]
# 1    [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                   []
# 3                                                   []
# 4                                      [j2ee, sap erp]
# 5                                                   []
# 6                                         [javascript]
# 7                                                   []
# 8             [soapui, perl, javascript, ibm rational]
# 9                                                   []
# 10                                                  []
# 11                                   [adobe photoshop]
# 12                                                  []
# 13                                                  []
# 14   [jboss, jquery, db2, jenkins, javascript, info...
# 15                                          [accounts]
# 16                                                  []
# 17                                                  []
# 18                                  [google analytics]
# 19                                                  []
# 20                       [ibm global process services]
# 21                                     [ios, ethereum]
# 22                              [dentsu aegis network]
# 23   [cvs, php, jquery, ios, adobe dreamweaver, cod...
# 24                                                  []
# 25                                     [intel, allego]
# 26                         [ios, accenture, angularjs]
# 27                                                  []
# 28                                                  []
# 29                                         [angularjs]
# ..                                                 ...
# 361                                                 []
# 362            [microsoft publisher, microsoft office]
# 363                                                 []
# 364                            [google analytics, moz]
# 365                                  [php, javascript]
# 366                                             [j2ee]
# 367            [sap hana, sap crm, sap netweaver, db2]
# 368                                         [salesbox]
# 369                                                 []
# 370                                                 []
# 371  [google analytics, facebook ads, accenture, ap...
# 372  [kvm, openshift, openstack, ansible, vmware, o...
# 373  [microsoft visual studio, jquery, sqlite, xama...
# 374                                                 []
# 375                                                 []
# 376                                       [intel, dsi]
# 377                                         [teletech]
# 378                                        [totaljobs]
# 379                                                 []
# 380                                          [sandisk]
# 381  [microsoft excel, microsoft office, microstrat...
# 382                                                 []
# 383    [ios, sharepoint, versionone, citrix xenmobile]
# 384                                  [php, javascript]
# 385                                       [windows xp]
# 386                                                 []
# 387                                                 []
# 388                                 [jquery, sitecore]
# 389                                           [joomla]
# 390                                  [adobe photoshop]
#
# [391 rows x 5 columns]

# %%
df_cm = convert_data_format(df_cm, "exact_matched_patt_contextual")

# %%
df_cm["exact_matched_patt_contextual"] = df_cm["exact_matched_patt_contextual"].fillna('[]')

# %%
df_cm["exact_matched_patt_contextual"][12]
# Out:
# ['gmail']

# %%
count_context_technologies = []

for i in range(0, len(df_cm)):
    count_context_technologies.extend(df_cm["exact_matched_patt_contextual"][i])
d = list(set(count_context_technologies))
len(d)
# Out:
# 362

# %% [markdown]
# # Converting into dataformat to compare two strings

# %%
# TP: present in both sheet i==j
# TN: not in both (insignificant)
# FP: in extracted sheet but not in manual tagging     i!=j
# FN: in manual tagging and is not in extracted tagging j

# %%
tp = []
tn = []
fp = []
fn = []

# %%
TP = TN = FP = FN = 0

# TP + FP calculation
# op_string = exact_matched_patt
# , manual_tagged_string = Actual/Actual(NER)

df_cm.head()
# Out:
#                             id  \
# 0  zeExhAA-r0lbcTQH41BlFg_0000
# 1  zSvilx9nLA2ADlgkbh0Avw_0000
# 2  z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3  yCI14syBYDiD3pwIDKVEKQ_0000
# 4  xuMF3K3aFCBGMOElWU0WTA_0000
#
#                                            summaries  \
# 0   senior account manager at verizon enterprise ...
# 1   12 years of software development experience o...
# 2   ours excavating is a commercial excavating de...
# 3   getting things done voor iedere uitdaging de ...
# 4   12 +years of experience in development qa dev...
#
#                        exact_matched_patt_contextual  \
# 0                               [verizon enterprise]
# 1  [microsoft.net, asp.net, java, jquery, html, j...
# 2                                            [gmail]
# 3                                            [gmail]
# 4                                   [java, selenium]
#
#                                             keywords  \
# 0                         [pris, verizon enterprise]
# 1  [eploy, xperience, informa, que, nex, javascri...
# 2                      [xperience, ava, digg, gmail]
# 3                           [twik, omp, plex, gmail]
# 4  [xperience, ora, sap erp, que, shopp, ava, esi...
#
#                                         Tech_matched
# 0                               [verizon enterprise]
# 1  [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                 []
# 3                                                 []
# 4                                    [j2ee, sap erp]

# %%
tech.head()
# Out:
#                title
# 0        WorkflowMax
# 1           InGenius
# 2            DealHub
# 3              Ebsta
# 4  Repsly Mobile CRM

# %%
tech_list = tech["title"].tolist()
tech_list = list(set(tech_list))
len(tech_list)
# Out:
# 24028

# %%
for i in range(0, len(tech_list)):
    tech_list[i] = tech_list[i].lower()

# %%
# tech_list

# %%
# df_cm['Eng_Label']=df_cm["exact_matched_patt_contextual"].copy()

# %%
tech_tag_list = []

def get_tech_tagged_data(manually_tagged, tech_list):
    keep=[]
    for word in manually_tagged:
        if word in tech_list:
            keep.append(word)
    return keep

# %%
# get_tech_tagged_data(df_cm["exact_matched_patt_contextual"][1],tech_list)

# %%
df_cm.head(10)
# Out:
#                             id  \
# 0  zeExhAA-r0lbcTQH41BlFg_0000
# 1  zSvilx9nLA2ADlgkbh0Avw_0000
# 2  z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3  yCI14syBYDiD3pwIDKVEKQ_0000
# 4  xuMF3K3aFCBGMOElWU0WTA_0000
# 5  xlZw0zgxhTJ34Zkj8qz3ow_0000
# 6  xi1WETjz2xTW4jBSE8U8DQ_0000
# 7  xfwmFMDDgwYyhZMc1MJcpg_0000
# 8  wy3R8tztPGIHWzOl1wTTOg_0000
# 9  wmiO3uJcgJcjGMruOdWykg_0000
#
#                                            summaries  \
# 0   senior account manager at verizon enterprise ...
# 1   12 years of software development experience o...
# 2   ours excavating is a commercial excavating de...
# 3   getting things done voor iedere uitdaging de ...
# 4   12 +years of experience in development qa dev...
# 5   i am an upcoming graduate from the university...
# 6   specialties advertising technology agile soft...
# 7   cpa eligible currently taking cpa exams and a...
# 8   an experienced test consultant in the field o...
# 9   an accomplished resultsoriented customer supp...
#
#                        exact_matched_patt_contextual  \
# 0                               [verizon enterprise]
# 1  [microsoft.net, asp.net, java, jquery, html, j...
# 2                                            [gmail]
# 3                                            [gmail]
# 4                                   [java, selenium]
# 5                                            [gmail]
# 6                                 [java, javascript]
# 7                                            [gmail]
# 8  [ibm rational, soapui, selenium, javascript, j...
# 9                                            [gmail]
#
#                                             keywords  \
# 0                         [pris, verizon enterprise]
# 1  [eploy, xperience, informa, que, nex, javascri...
# 2                      [xperience, ava, digg, gmail]
# 3                           [twik, omp, plex, gmail]
# 4  [xperience, ora, sap erp, que, shopp, ava, esi...
# 5  [xperience, alexa, ets, verifi, que, lita, res...
# 6             [javascript, ava, ving, adverti, cien]
# 7  [ami, emplo, imal, ava, ios, ning, omp, mploy,...
# 8  [xperience, perl, ibm rational, javascript, av...
# 9  [ento, adrive, rform, chai, perf, omp, ics, ni...
#
#                                         Tech_matched
# 0                               [verizon enterprise]
# 1  [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                 []
# 3                                                 []
# 4                                    [j2ee, sap erp]
# 5                                                 []
# 6                                       [javascript]
# 7                                                 []
# 8           [soapui, perl, javascript, ibm rational]
# 9                                                 []

# %%
df_cm['Tech_Label'] = df_cm.apply(lambda x: get_tech_tagged_data(x["exact_matched_patt_contextual"], tech_list), axis = 1)
# df_cm['Eng_Label'] = df_cm.apply(lambda x: get_tech_tagged_data(x["exact_matched_patt_contextual"], tech_list), axis = 1)

# %%
df_cm.head(10)
# Out:
#                             id  \
# 0  zeExhAA-r0lbcTQH41BlFg_0000
# 1  zSvilx9nLA2ADlgkbh0Avw_0000
# 2  z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3  yCI14syBYDiD3pwIDKVEKQ_0000
# 4  xuMF3K3aFCBGMOElWU0WTA_0000
# 5  xlZw0zgxhTJ34Zkj8qz3ow_0000
# 6  xi1WETjz2xTW4jBSE8U8DQ_0000
# 7  xfwmFMDDgwYyhZMc1MJcpg_0000
# 8  wy3R8tztPGIHWzOl1wTTOg_0000
# 9  wmiO3uJcgJcjGMruOdWykg_0000
#
#                                            summaries  \
# 0   senior account manager at verizon enterprise ...
# 1   12 years of software development experience o...
# 2   ours excavating is a commercial excavating de...
# 3   getting things done voor iedere uitdaging de ...
# 4   12 +years of experience in development qa dev...
# 5   i am an upcoming graduate from the university...
# 6   specialties advertising technology agile soft...
# 7   cpa eligible currently taking cpa exams and a...
# 8   an experienced test consultant in the field o...
# 9   an accomplished resultsoriented customer supp...
#
#                        exact_matched_patt_contextual  \
# 0                               [verizon enterprise]
# 1  [microsoft.net, asp.net, java, jquery, html, j...
# 2                                            [gmail]
# 3                                            [gmail]
# 4                                   [java, selenium]
# 5                                            [gmail]
# 6                                 [java, javascript]
# 7                                            [gmail]
# 8  [ibm rational, soapui, selenium, javascript, j...
# 9                                            [gmail]
#
#                                             keywords  \
# 0                         [pris, verizon enterprise]
# 1  [eploy, xperience, informa, que, nex, javascri...
# 2                      [xperience, ava, digg, gmail]
# 3                           [twik, omp, plex, gmail]
# 4  [xperience, ora, sap erp, que, shopp, ava, esi...
# 5  [xperience, alexa, ets, verifi, que, lita, res...
# 6             [javascript, ava, ving, adverti, cien]
# 7  [ami, emplo, imal, ava, ios, ning, omp, mploy,...
# 8  [xperience, perl, ibm rational, javascript, av...
# 9  [ento, adrive, rform, chai, perf, omp, ics, ni...
#
#                                         Tech_matched  \
# 0                               [verizon enterprise]
# 1  [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                 []
# 3                                                 []
# 4                                    [j2ee, sap erp]
# 5                                                 []
# 6                                       [javascript]
# 7                                                 []
# 8           [soapui, perl, javascript, ibm rational]
# 9                                                 []
#
#                                           Tech_Label
# 0                               [verizon enterprise]
# 1  [microsoft.net, asp.net, jquery, javascript, a...
# 2                                            [gmail]
# 3                                            [gmail]
# 4                                                 []
# 5                                            [gmail]
# 6                                       [javascript]
# 7                                            [gmail]
# 8           [ibm rational, soapui, javascript, perl]
# 9                                            [gmail]

# %%
list_tech_dataset = []

# %%
# fill with 
for i in range(0, len(df_cm)):
    list_tech_dataset.extend(df_cm["Tech_Label"][i])

# %%
len(list_tech_dataset)
# Out:
# 740

# %%
set_tech = set(list_tech_dataset)
len(set_tech)
# Out:
# 254

# %%
for i in range(0, len(df_cm)):
    l = df_cm[col_name_op][i]
    df_cm[col_name_op][i] = [0 if element == '0' else element for element in l]

# %%
for i in range(0, len(df_cm)):
  words = df_cm[col_name_op][i]
  stopwords = [0]
  for word in list(words):
    if word in stopwords:
      words.remove(word)

# %%
def Diff(li1, li2): #FP entries
    return list(set(li2)-set(li1))

# %%
def Same(lis1,lis2): #TP entries
    return list(set(lis1).intersection(lis2))

# %%
def Common(lis1,lis2):
    return list(set(lis1)-(set(lis2)))

# %%
# list of technologies which are not in extracted list but are in tagged list i.e. FN entries
df_cm['FP_entries_TECH'] = df_cm.apply(lambda x: Diff(x["Tech_Label"], x[col_name_op]), axis = 1)

# %%
# list of technologies which are in extracted list and are in tagged list i.e. TP entries
df_cm['TP_entries_TECH'] = df_cm.apply(lambda x: Same(x["Tech_Label"], x[col_name_op]), axis = 1)

# %%
# list of technologies which are NOT extracted list and are in tagged list i.e. FN entries
df_cm['FN_entries_TECH'] = df_cm.apply(lambda x: Common(x["Tech_Label"], x[col_name_op]), axis = 1)

# %%
df_cm.head(15)
# Out:
#                              id  \
# 0   zeExhAA-r0lbcTQH41BlFg_0000
# 1   zSvilx9nLA2ADlgkbh0Avw_0000
# 2   z5Kl-V2w51Z-6uhXbNCRrQ_0000
# 3   yCI14syBYDiD3pwIDKVEKQ_0000
# 4   xuMF3K3aFCBGMOElWU0WTA_0000
# 5   xlZw0zgxhTJ34Zkj8qz3ow_0000
# 6   xi1WETjz2xTW4jBSE8U8DQ_0000
# 7   xfwmFMDDgwYyhZMc1MJcpg_0000
# 8   wy3R8tztPGIHWzOl1wTTOg_0000
# 9   wmiO3uJcgJcjGMruOdWykg_0000
# 10  wfeb9x1PszS-BeaAlBlS4w_0000
# 11  wTue5Ls4a6DY7MB4rxCynw_0000
# 12  wPQdim5iOSpeJnA5zh5lHA_0000
# 13  wMr2Z7wACq1tSdfGQrWP2Q_0000
# 14  wAXzF14t17vJAESEBSbWEA_0000
#
#                                             summaries  \
# 0    senior account manager at verizon enterprise ...
# 1    12 years of software development experience o...
# 2    ours excavating is a commercial excavating de...
# 3    getting things done voor iedere uitdaging de ...
# 4    12 +years of experience in development qa dev...
# 5    i am an upcoming graduate from the university...
# 6    specialties advertising technology agile soft...
# 7    cpa eligible currently taking cpa exams and a...
# 8    an experienced test consultant in the field o...
# 9    an accomplished resultsoriented customer supp...
# 10   i am a selfstarter with a passion for busines...
# 11   im an extrovert with good managerial skills h...
# 12   goals involve using systems engineering and l...
# 13   i have been working in the film and tv indust...
# 14   experienced developer java bpm and mainframe ...
#
#                         exact_matched_patt_contextual  \
# 0                                [verizon enterprise]
# 1   [microsoft.net, asp.net, java, jquery, html, j...
# 2                                             [gmail]
# 3                                             [gmail]
# 4                                    [java, selenium]
# 5                                             [gmail]
# 6                                  [java, javascript]
# 7                                             [gmail]
# 8   [ibm rational, soapui, selenium, javascript, j...
# 9                                             [gmail]
# 10                                 [google analytics]
# 11                                     [adobe, forte]
# 12                                            [gmail]
# 13                                            [gmail]
# 14  [java, informatica, spring, html, javascript, ...
#
#                                              keywords  \
# 0                          [pris, verizon enterprise]
# 1   [eploy, xperience, informa, que, nex, javascri...
# 2                       [xperience, ava, digg, gmail]
# 3                            [twik, omp, plex, gmail]
# 4   [xperience, ora, sap erp, que, shopp, ava, esi...
# 5   [xperience, alexa, ets, verifi, que, lita, res...
# 6              [javascript, ava, ving, adverti, cien]
# 7   [ami, emplo, imal, ava, ios, ning, omp, mploy,...
# 8   [xperience, perl, ibm rational, javascript, av...
# 9   [ento, adrive, rform, chai, perf, omp, ics, ni...
# 10  [google analytics, xperience, and co, bric, em...
# 11  [xperience, esign, vendo, iri, ning, endor, st...
# 12  [xperience, ora, lita, orat, nvolv, soci, ning...
# 13         [evie, ami, obs, rsm, ning, gmail, amilia]
# 14  [xperience, informa, ora, jboss, continu, que,...
#
#                                          Tech_matched  \
# 0                                [verizon enterprise]
# 1   [rabbitmq, jquery, angularjs, javascript, nuni...
# 2                                                  []
# 3                                                  []
# 4                                     [j2ee, sap erp]
# 5                                                  []
# 6                                        [javascript]
# 7                                                  []
# 8            [soapui, perl, javascript, ibm rational]
# 9                                                  []
# 10                                                 []
# 11                                  [adobe photoshop]
# 12                                                 []
# 13                                                 []
# 14  [jboss, jquery, db2, jenkins, javascript, info...
#
#                                            Tech_Label    FP_entries_TECH  \
# 0                                [verizon enterprise]                 []
# 1   [microsoft.net, asp.net, jquery, javascript, a...    [jquery mobile]
# 2                                             [gmail]                 []
# 3                                             [gmail]                 []
# 4                                                  []    [j2ee, sap erp]
# 5                                             [gmail]                 []
# 6                                        [javascript]                 []
# 7                                             [gmail]                 []
# 8            [ibm rational, soapui, javascript, perl]                 []
# 9                                             [gmail]                 []
# 10                                 [google analytics]                 []
# 11                                                 []  [adobe photoshop]
# 12                                            [gmail]                 []
# 13                                            [gmail]                 []
# 14  [informatica, javascript, jquery, db2, jcl, je...                 []
#
#                                       TP_entries_TECH  \
# 0                                [verizon enterprise]
# 1    [rabbitmq, jquery, angularjs, javascript, nunit]
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6                                        [javascript]
# 7                                                  []
# 8            [soapui, perl, javascript, ibm rational]
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14  [jboss, jquery, db2, jenkins, javascript, info...
#
#              FN_entries_TECH
# 0                         []
# 1   [asp.net, microsoft.net]
# 2                    [gmail]
# 3                    [gmail]
# 4                         []
# 5                    [gmail]
# 6                         []
# 7                    [gmail]
# 8                         []
# 9                    [gmail]
# 10        [google analytics]
# 11                        []
# 12                   [gmail]
# 13                   [gmail]
# 14                        []

# %%
# df_cm.to_csv("bert_eng_accuracy_M1_with_entries.csv", index = False)

# %%
def get_TP(df,manual_tagged_string,op_string):
    
    for ind in df.index:
        TP = FP = 0
        
        for i in range(0, len(df[op_string][ind])):
            
            if df[op_string][ind][i] in df[manual_tagged_string][ind]:
                TP = TP + 1
                
            else:
                pass
                
        tp.append(TP)

    return tp

# %%
fp_entry =[]
# fn_entry = []

# %%
# import numpy as np
# list_1 = ["a", "b", "c", "d", "e"]
# list_2 = ["a", "f", "c", "m"] 
# # yields the elements in `list_2` that are NOT in `list_1`
# main_list = np.setdiff1d(list_2,list_1)
# yields the elements in `list_2` that are NOT in `list_1`



def get_FP(df,manual_tagged_string, op_string):
    
    for ind in df.index:
        main_list = np.setdiff1d(df[op_string][ind],df[manual_tagged_string][ind])
        fp.append(len(main_list))
        fp_entry.append(main_list)
        
        
    return fp, fp_entry

# %%
# ORIGINAL
# def get_FN(df,manual_tagged_string, op_string):
    
#     for ind in df.index:
        
#         main_list = np.setdiff1d(df[manual_tagged_string][ind], df[op_string][ind])
#         fn.append(len(main_list))
        
#     return fn

# %%
def get_FN(df,manual_tagged_string, op_string):
    
    for ind in df.index:
        
        main_list = np.setdiff1d(df[manual_tagged_string][ind], df[op_string][ind])
        if df[manual_tagged_string][ind]=='[]':
            fn.append(0)
        else:
            fn.append(len(main_list))
        
    return fn

# %%
# entry like Empty|list of technology output

# %%
# def get_FN(df,manual_tagged_string, op_string):
    
#     for ind in df.index:
        
#         main_list = np.setdiff1d(df[manual_tagged_string][ind], df[op_string][ind])
#         if (manual_tagged_string[ind] == "[]"or manual_tagged_string[ind] == ""):
#             fn.append(0)
#         else:
#             fn.append(len(main_list))
        
#     return fn

# %%
# function call
tp = get_TP(df_cm, "Tech_Label", col_name_op)
fp, fp_entry_names = get_FP(df_cm, "Tech_Label", col_name_op)
fn = get_FN(df_cm, "Tech_Label", col_name_op)

# tp = get_TP(df_cm, "Tech_Label", col_name_op)
# fp, fp_entry_names = get_FP(df_cm, "Tech_Label", col_name_op)
# fn = get_FN(df_cm, "Tech_Label", col_name_op)


# tp = get_TP(df_cm, "Technology", col_name_op)
# fp = get_FP(df_cm, "Technology", col_name_op)
# fn = get_FN(df_cm, "Technology", col_name_op)

# %%
# tp

# %%
print(len(tp), len(fp), len(fn))
# Out:
# 391 391 391

# %%
len(fp_entry_names)
# Out:
# 391

# %%
type(fp_entry_names)
# Out:
# list

# %%
dict_fp = {}

# %%
for i in range(0, len(fp_entry_names)):
    fp_entry_names[i] = fp_entry_names[i].tolist()
    dict_fp[i] = fp_entry_names[i]

# %%
# creating a dataframe
df_matrix = pd.DataFrame(list(zip(tp, fp, fn)), 
               columns =['TP', 'FP', "FN"])
df_matrix.head(-1)
# Out:
#      TP  FP  FN
# 0     1   0   0
# 1     5   1   2
# 2     0   0   1
# 3     0   0   1
# 4     0   2   0
# 5     0   0   1
# 6     1   0   0
# 7     0   0   1
# 8     4   0   0
# 9     0   0   1
# 10    0   0   1
# 11    0   1   0
# 12    0   0   1
# 13    0   0   1
# 14    7   0   0
# 15    0   1   1
# 16    0   0   1
# 17    0   0   1
# 18    1   0   0
# 19    0   0   1
# 20    1   0   0
# 21    2   0   0
# 22    1   0   0
# 23    8   2   0
# 24    0   0   1
# 25    1   1   0
# 26    3   0   0
# 27    0   0   1
# 28    0   0   1
# 29    1   0   0
# ..   ..  ..  ..
# 360   0   1   1
# 361   0   0   1
# 362   2   0   0
# 363   0   0   1
# 364   1   1   0
# 365   2   0   0
# 366   1   0   0
# 367   4   0   0
# 368   1   0   0
# 369   0   0   1
# 370   0   0   1
# 371   4   0   0
# 372   7   2   0
# 373   5   0   1
# 374   0   0   1
# 375   0   1   0
# 376   1   1   1
# 377   1   0   0
# 378   1   0   0
# 379   0   0   1
# 380   1   0   0
# 381   1   2   0
# 382   0   0   1
# 383   3   1   0
# 384   2   0   0
# 385   1   0   2
# 386   0   0   1
# 387   0   0   0
# 388   1   1   1
# 389   1   0   0
#
# [390 rows x 3 columns]

# %%
def get_precision(tp,fp):
    
    if tp+fp ==0:
        precision = 0
    else:
        precision = tp/(tp+fp)
    
    return precision

# %%
def get_recall(tp,fn):
    
    if tp+fn ==0:
        recall = 0
    else:
        recall = tp/(tp+fn)
    
    return recall

# %%
def get_f_score(precision, recall):
    if precision+recall == 0:
        f_score = 0
    else:
        f_score = 2*(precision*recall)/(precision+recall)
        
    return f_score

# %%
df_matrix['Precision'] = df_matrix.apply(lambda x: get_precision(x["TP"], x["FP"]), axis = 1)

# %%
df_matrix["Recall"] = df_matrix.apply(lambda x: get_recall(x["TP"], x["FN"]), axis = 1)

# %%
df_matrix["f_score"] = df_matrix.apply(lambda x: get_f_score(x["Precision"], x["Recall"]), axis = 1)

# %%
df_matrix.head()
# Out:
#    TP  FP  FN  Precision    Recall   f_score
# 0   1   0   0   1.000000  1.000000  1.000000
# 1   5   1   2   0.833333  0.714286  0.769231
# 2   0   0   1   0.000000  0.000000  0.000000
# 3   0   0   1   0.000000  0.000000  0.000000
# 4   0   2   0   0.000000  0.000000  0.000000

# %%
# df_matrix.to_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/Output/Accuracy_Sheet_ner_en_large_flair_100_tagged.csv", index = False)
# df_matrix.to_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/Output/Accuracy_Sheet_spacy_adding_more_tags.csv", index = False)
# df_matrix.to_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/Output/Accuracy_Sheet_String_Match_non_context.csv", index = False)
# df_matrix.to_csv("189_BERT_tags_SPACY_TEST_DATA_M1_12_Jun_21.csv", index = False)

# df_matrix.to_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/Output/Accuracy_Sheet_lg__moreTAGS_tagged_100_more_ENTS.csv", index = False)
# df_matrix.to_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/Output/Accuracy_Sheet_lg_100_simple_spacy.csv", index = False)

# %%
df_cm=df_cm.drop(columns="keywords")
final_data = df_cm.join(df_matrix)
final_data.to_csv("ACC-TECH_BERT_pred_ENG_SUM_EXP.csv",index=False)
# final_data.to_csv("1190_spacy_pred_tech_match.csv")
