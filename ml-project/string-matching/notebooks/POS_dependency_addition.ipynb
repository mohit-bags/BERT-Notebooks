# %%
import nltk
# nltk.download()
import pandas as pd
import spacy
# from spacy import displacy
# from collections import Counter
import en_core_web_lg
nlp = en_core_web_lg.load()
import re
import truecase

# %%
import pandas as pd
import spacy
from spacy.displacy.render import EntityRenderer
from IPython.core.display import display, HTML
# %load_ext autoreload
# %autoreload 2

# %%
def custom_render(doc, df, column, options={}, page=False, minify=False, idx=0):
    """Overload the spaCy built-in rendering to allow custom part-of-speech (POS) tags.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    column -- the name of of a column of interest in the dataframe
    options -- various options to feed into the spaCy renderer, including colors
    page -- rendering markup as full HTML page (default False)
    minify -- for compact HTML (default False)
    idx -- index for specific query or doc in dataframe (default 0)
    
    """
    renderer, converter = EntityRenderer, parse_custom_ents
    renderer = renderer(options=options)
    parsed = [converter(doc, df=df, idx=idx, column=column)]
    html = renderer.render(parsed, page=page, minify=minify).strip()  
    return display(HTML(html))

def parse_custom_ents(doc, df, idx, column):
    """Parse custom entity types that aren't in the original spaCy module.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    idx -- index for specific query or doc in dataframe
    column -- the name of of a column of interest in the dataframe
    
    """
    if column in df.columns:
        entities = df[column][idx]
        ents = [{'start': ent[1], 'end': ent[2], 'label': ent[3]} 
                for ent in entities]
    else:
        ents = [{'start': ent.start_char, 'end': ent.end_char, 'label': ent.label_}
            for ent in doc.ents]
    return {'text': doc.text, 'ents': ents, 'title': None}

def render_entities(idx, df, options={}, column='named_ents'):
    """A wrapper function to get text from a dataframe and render it visually in jupyter notebooks
    
    Keyword arguments:
    idx -- index for specific query or doc in dataframe (default 0)
    df -- a pandas dataframe object
    options -- various options to feed into the spaCy renderer, including colors
    column -- the name of of a column of interest in the dataframe (default 'named_ents')
    
    """
    text = df['text'][idx]
    custom_render(nlp(text), df=df, column=column, options=options, idx=idx)

# %%
# colors for additional part of speech tags we want to visualize
options = {
    'colors': {'COMPOUND': '#FE6BFE', 'PROPN': '#18CFE6', 'NOUN': '#18CFE6', 'NP': '#1EECA6', 'ENTITY': '#FF8800'}
}

# %%
pd.set_option('display.max_rows', 10) # edit how jupyter will render our pandas dataframes
pd.options.mode.chained_assignment = None # prevent warning about working on a copy of a dataframe

# %%
tech = pd.read_csv("Dataset/Technology Summary Matching Project - technologies.csv")
# summary = pd.read_csv("a4f32761-65b8-45e8-99ed-fb8ad4a63f8d.csv")
# summary = pd.read_csv("train_data_original_untagged.csv")
summary = pd.read_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/tagged_simanchala_100.csv")

# summary = pd.read_csv("Train_Data/String_Match_non_duplicates - String_Match_non_duplicates.csv")
output = pd.read_csv("Dataset/output - output.csv")

# %%
df = summary

# %%
lower = lambda x: x.lower() # make everything lowercase

# %%
df = pd.DataFrame(df['summaries'].apply(lower))
df.columns = ['text']
display(df)
# Out:
#                                                  text
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Extract Named Entities

# %%
def extract_named_ents(text):
    """Extract named entities, and beginning, middle and end idx using spaCy's out-of-the-box model. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in nlp(text).ents]

def add_named_ents(df):
    """Create new column in data frame with named entity tuple extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_ents'] = df['text'].apply(extract_named_ents)

# %%
add_named_ents(df)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
# [100 rows x 2 columns]

# %%
type(df["named_ents"][0][0])
# Out:
# tuple

# %%
column = 'named_ents'
render_entities(0, df, options=options, column=column) # take a look at one of the abstracts
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15+ years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  within the recruiting industry combined with
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in management contribute to a well-rounded recruiting professional dedicated to finding quality candidates for my client groups. my goal is to ensure that the perfect marriage is made between the candidate and the team and that a long term relationship is forged with the perfect match. i am the consummate recruiter, i live, eat and breathe my work and am always looking for new ways to better my skills. i am always learning and love to share what i have learned with my colleagues, or anyone willing to take the time to listen. i am happy to be a resource and look forward to meeting new people. i am here to network and am a member of lion and am open to invites. specialties: recruiter, sourcing guru, mentor, innovative &amp; creative. strong networking capabilities, cost effective sourcing techniques and methodologies. specializing in finding passive candidates within the it sector. national and international recruiting abilities.,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  within the recruiting industry combined with
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in management contribute to a well-rounded recruiting professional dedicated to finding quality candidates for my client groups. my goal is to ensure that the perfect marriage is made between the candidate and the team and that a long term relationship is forged with the perfect match. i am the consummate recruiter, i live, eat and breathe my work and am always looking for new ways to better my skills. i am always learning and love to share what i have learned with my colleagues, or anyone willing to take the time to listen. i am happy to be a resource and look forward to meeting new people. i am here to network and am a member of lion and am open to invites.</br></br>specialties: recruiter, sourcing guru, mentor, innovative &amp; creative. strong networking capabilities, cost effective sourcing techniques and methodologies. specializing in finding passive candidates within the it sector. national and international recruiting abilities.,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  within the recruiting industry combined with
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in management contribute to a well-rounded recruiting professional dedicated to finding quality candidates for my client groups. my goal is to ensure that the perfect marriage is made between the candidate and the team and that a long term relationship is forged with the perfect match. i am the consummate recruiter, i live, eat and breathe my work and am always looking for new ways to better my skills. i am always learning and love to share what i have learned with my colleagues, or anyone willing to take the time to listen. i am happy to be a resource and look forward to meeting new people. i am here to network and am a member of lion and am open to invites. specialties: recruiter, sourcing guru, mentor, innovative &amp; creative. strong networking capabilities, cost effective sourcing techniques and methodologies. specializing in finding passive candidates within the it sector. national and international recruiting abilities., senior technology recruiter in seattle. any and all statements made are my own., unicorn wrangler &amp; purple squirrel collector at tune, purple squirrel hunter at hewlett packard enterprise, unicorn wrangler &amp; purple squirrel stalker for snap!, senior technical recruiter at unity technologies, purple squirrel hunter at microsoft]</div>

# %% [markdown]
# ## Extracting NOUNS

# %%
def extract_nouns(text):
    """Extract a few types of nouns, and beginning, middle and end idx using spaCy's POS (part of speech) tagger. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    keep_pos = ['PROPN', 'NOUN']
    return [(tok.text, tok.idx, tok.idx+len(tok.text), tok.pos_) for tok in nlp(text) if tok.pos_ in keep_pos]

def add_nouns(df):
    """Create new column in data frame with nouns extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['nouns'] = df['text'].apply(extract_nouns)

# %%
add_nouns(df)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents  \
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
#                                                 nouns
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
# [100 rows x 3 columns]

# %%
column = 'nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[15+
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  within the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  combined with ten
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  for my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     client
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     goal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is to ensure that the perfect
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marriage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is made between the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     candidate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and that a long
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     term
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     relationship
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is forged with the perfect
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     match
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am the consummate
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , i live, eat and breathe my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     work
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and am always looking for new
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to better my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     skills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am always learning and love to share what i have learned with my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colleagues
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , or anyone willing to take the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to listen. i am happy to be a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     resource
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and look forward to meeting new
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am here to network and am a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     member
#     <span style="fo

# %% [markdown]
# ## Combine Named Entities and Nouns

# %%
def extract_named_nouns(row_series):
    """Combine nouns and non-numerical entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    ents = set()
    idxs = set()
    # remove duplicates and merge two lists together
    for noun_tuple in row_series['nouns']:
        for named_ents_tuple in row_series['named_ents']:
            if noun_tuple[1] == named_ents_tuple[1]: 
                idxs.add(noun_tuple[1])
                ents.add(named_ents_tuple)
        if noun_tuple[1] not in idxs:
            ents.add(noun_tuple)
    
    return sorted(list(ents), key=lambda x: x[1])

def add_named_nouns(df):
    """Create new column in data frame with nouns and named ents.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_nouns'] = df.apply(extract_named_nouns, axis=1)

# %%
add_named_nouns(df)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents  \
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
#                                                 nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                           named_nouns
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
# [100 rows x 4 columns]

# %%
column = 'named_nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[15+
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  within the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  combined with ten
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  for my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     client
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     goal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is to ensure that the perfect
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marriage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is made between the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     candidate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and that a long
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     term
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     relationship
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  is forged with the perfect
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     match
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am the consummate
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , i live, eat and breathe my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     work
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and am always looking for new
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to better my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     skills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am always learning and love to share what i have learned with my
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colleagues
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# , or anyone willing to take the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  to listen. i am happy to be a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     resource
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  and look forward to meeting new
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# . i am here to network and am a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     member
#     <span style="fo

# %% [markdown]
# ## Extract Noun Phrases

# %% [markdown]
# A Chunky Pipeline
# Even mild exposure to computer science, or any of the various isoforms of engineering, will have introduced you to the idea of an abstraction, wherein low-level concepts are bundled into higher-order relationships. The noun phrase or chunk is an abstraction which consists of two or more words, and is the by-product of dependency parsing, POS tagging, and tokenization. spaCy's POS tagger is essentially a statistical model which learns to predict the tag (noun, verb, adjective, etc.) for a given word using examples of tagged-sentences.
#
# This supervised machine learning approach relies on tokens generated from splitting text into somewhat atomic units using a rule-based tokenizer (although there are some interesting unsupervised models out there as well). Dependency parsing then uncovers relationships between these tagged tokens, allowing us to finally extract noun chunks or phrases of relevance.
#
# The full pipeline goes something like this:
#
# raw text → tokenization → POS tagging → dependency parsing → noun chunk extraction
#
# Theoretically, one could swap out noun chunk extraction for named entity recognition, but that's the part of the pipeline we are attempting to modify for our own purposes, because we want n-length entities. Barring our custom intrusion, however, this is exactly how spaCy's built-in model works! If you don't believe me (which you shouldn't, since you're a scientist), scroll up to the very top of this notebook to convince yourself.

# %%
text = summary["summaries"][0]
spacy.displacy.render(nlp(text), jupyter=True) # generating raw-markup using spacy's built-in renderer
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a1f0a88e43e746c089e12bbc130c2a9d-0" class="displacy" width="94550" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">15</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">+</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">recruiting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">industry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">combined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">ten</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">contribute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">well-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">rounded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">recruiting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">professional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">dedicated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">finding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">quality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">candidates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">client</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">groups.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">my</tspan>
#     <tspan

# %%
def extract_noun_phrases(text):
    """Combine noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(chunk.text, chunk.start_char, chunk.end_char, chunk.label_) for chunk in nlp(text).noun_chunks]

def add_noun_phrases(df):
    """Create new column in data frame with noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['noun_phrases'] = df['text'].apply(extract_noun_phrases)

# %%
def visualize_noun_phrases(text):
    """Create a temporary dataframe to extract and visualize noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    df = pd.DataFrame([text]) 
    df.columns = ['text']
    add_noun_phrases(df)
    column = 'noun_phrases'
    render_entities(0, df, options=options, column=column)

# %%
visualize_noun_phrases(text)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[15+ years within
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the recruiting industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  combined with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  for
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my client groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my goal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is to ensure that
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the perfect marriage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is made between
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the candidate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and that
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a long term relationship
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is forged with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the perfect match
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the consummate recruiter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# ,
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  live, eat and breathe
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my work
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and am always looking for
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new ways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to better
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my skills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am always learning and love to share
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     what
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  have learned with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my colleagues
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# , or
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anyone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  willing to take
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to listen.
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am happy to be
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a resource
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</sp

# %%
add_noun_phrases(df)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents  \
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
#                                                 nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                           named_nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                          noun_phrases
# 0   [(the recruiting industry, 18, 41, NP), (ten y...
# 1   [(science, 13, 20, NP), ((b.s) degree, 21, 33,...
# 2   [(i, 1, 2, NP), (a current online student, 5, ...
# 3   [(more than 6 years, 54, 71, NP), (experience,...
# 4   [(i, 1, 2, NP), (a highly motivated civil engi...
# ..                                                ...
# 95  [([features, 0, 9, NP), (thor, 11, 15, NP), (r...
# 96  [([passionate visioner and doer. expert, 0, 37...
# 97  [(i, 1, 2, NP), (a self-motivated sales, 6, 28...
# 98  [([www.lisawilkins.com specialties, 0, 32, NP)...
# 99  [(10 years experience, 55, 74, NP), (fast pace...
#
# [100 rows x 5 columns]

# %%
column = 'noun_phrases'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[15+ years within
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the recruiting industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  combined with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  for
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my client groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my goal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is to ensure that
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the perfect marriage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is made between
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the candidate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and that
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a long term relationship
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is forged with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the perfect match
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the consummate recruiter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# ,
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  live, eat and breathe
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my work
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  and am always looking for
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new ways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to better
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my skills
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am always learning and love to share
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     what
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  have learned with
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my colleagues
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# , or
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anyone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  willing to take
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  to listen.
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  am happy to be
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a resource
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NP</sp

# %% [markdown]
# ## Extract compound noun phrases

# %%
def extract_compounds(text):
    """Extract compound noun phrases with beginning and end idxs. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    comp_idx = 0
    compound = []
    compound_nps = []
    tok_idx = 0
    for idx, tok in enumerate(nlp(text)):
        if tok.dep_ == 'compound':

            # capture hyphenated compounds
            children = ''.join([c.text for c in tok.children])
            if '-' in children:
                compound.append(''.join([children, tok.text]))
            else:
                compound.append(tok.text)

            # remember starting index of first child in compound or word
            try:
                tok_idx = [c for c in tok.children][0].idx
            except IndexError:
                if len(compound) == 1:
                    tok_idx = tok.idx
            comp_idx = tok.i

        # append the last word in a compound phrase
        if tok.i - comp_idx == 1:
            compound.append(tok.text)
            if len(compound) > 1: 
                compound = ' '.join(compound)
                compound_nps.append((compound, tok_idx, tok_idx+len(compound), 'COMPOUND'))

            # reset parameters
            tok_idx = 0 
            compound = []

    return compound_nps

def add_compounds(df):
    """Create new column in data frame with compound noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['compounds'] = df['text'].apply(extract_compounds)

# %%
add_compounds(df)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents  \
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
#                                                 nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                           named_nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                          noun_phrases  \
# 0   [(the recruiting industry, 18, 41, NP), (ten y...
# 1   [(science, 13, 20, NP), ((b.s) degree, 21, 33,...
# 2   [(i, 1, 2, NP), (a current online student, 5, ...
# 3   [(more than 6 years, 54, 71, NP), (experience,...
# 4   [(i, 1, 2, NP), (a highly motivated civil engi...
# ..                                                ...
# 95  [([features, 0, 9, NP), (thor, 11, 15, NP), (r...
# 96  [([passionate visioner and doer. expert, 0, 37...
# 97  [(i, 1, 2, NP), (a self-motivated sales, 6, 28...
# 98  [([www.lisawilkins.com specialties, 0, 32, NP)...
# 99  [(10 years experience, 55, 74, NP), (fast pace...
#
#                                             compounds
# 0   [(recruiting industry, 22, 41, COMPOUND), (qua...
# 1   [(telecommunications networks, 39, 66, COMPOUN...
# 2   [(fashion merchandising, 34, 55, COMPOUND), (n...
# 3   [(device marketing, 90, 106, COMPOUND), (produ...
# 4   [(construction industry, 83, 104, COMPOUND), (...
# ..                                                ...
# 95  [(ragnarok spiderman, 17, 35, COMPOUND), (inde...
# 96  [(project development, 53, 72, COMPOUND), (pac...
# 97  [(communication skills, 69, 89, COMPOUND), (mg...
# 98  [(ux design, 34, 43, COMPOUND), (business requ...
# 99  [(healthcare professional, 1, 24, COMPOUND), (...
#
# [100 rows x 6 columns]

# %%
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[15+ years within the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  combined with ten years in management contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  for my
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     client groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# . my goal is to ensure that the perfect marriage is made between the candidate and the team and that a
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     long term relatio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# nship is forged with the perfect match. i am the consummate recruiter, i live, eat and breathe my work and am always looking for new ways to better my skills. i am always learning and love to share what i have learned with my colleagues, or anyone willing to take the time to listen. i am happy to be a resource and look forward to meeting new people. i am here to network and am a member of lion and am open to invites. specialties: recruiter,
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sourcing guru
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# , mentor, innovative &amp; creative. strong
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     networking capabilities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# , cost effective
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sourcing techniques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  and methodologies. specializing in finding passive candidates within the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     it sector
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# . national and international
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting abilities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# ., 13 years within the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  combined with ten years in management contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quality candidates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  for my
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     client groups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# . my goal is to ensure that the perfect marriage is made between the candidate and the team and that a
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     long term relatio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# nship is forged with the perfect match. i am the consummate recruiter, i live, eat and breathe my work and am always looking for new ways to better my skills. i am always learning and love to share what i have learned with my colleagues, or anyone willing to take the time to listen. i am happy to be a resource and look forward to meeting new people. i am here to network and am a member of lion and am open to invites.
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#
#
# specialties:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  recruiter, sourcing guru, mentor, innovative &amp; creative. strong
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     networking capabilities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# , cost effective
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sourcing techniques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  and methodologies. specializing in finding passive candidates within the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     it sector
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# . national and international
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting abilities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
# ., 11 years within the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recruiting industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  combined with ten years in management contribute to a well-rounded recruiting professional dedicated to finding
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25

# %%
def extract_comp_nouns(row_series, cols=[]):
    """Combine compound noun phrases and entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    return {noun_tuple[0] for col in cols for noun_tuple in row_series[col]}

def add_comp_nouns(df, cols=[]):
    """Create new column in data frame with merged entities.
    
    Keyword arguments:
    df -- a dataframe object
    cols -- a list of column names that need to be merged
    
    """
    df['comp_nouns'] = df.apply(extract_comp_nouns, axis=1, cols=cols)
cols = ['nouns', 'compounds']
add_comp_nouns(df, cols=cols)
display(df)
# Out:
#                                                  text  \
# 0   [15+ years within the recruiting industry comb...
# 1   [bachelor of science (b.s) degree in " telecom...
# 2   [i'm a current online student for fashion merc...
# 3   [high-performing,strategic-thinking profession...
# 4   [i am a highly motivated civil engineer with o...
# ..                                                ...
# 95  [features: thor: ragnarok spiderman: homecomin...
# 96  [passionate visioner and doer. expert in susta...
# 97  [i am a self-motivated sales & marketing profe...
# 98  [www.lisawilkins.com specialties: visual/ui/ux...
# 99  [driven and compassionate healthcare professio...
#
#                                            named_ents  \
# 0   [(15+ years, 1, 10, DATE), (ten years, 56, 65,...
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CA...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, ...
# 3   [(more than 6 years', 54, 72, DATE), (9 years'...
# 4   [(eight years, 50, 61, DATE), (hong kong, 563,...
# ..                                                ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen yea...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 119...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, O...
#
#                                                 nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                           named_nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NO...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOU...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NO...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, N...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOU...
# ..                                                ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN),...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, N...
#
#                                          noun_phrases  \
# 0   [(the recruiting industry, 18, 41, NP), (ten y...
# 1   [(science, 13, 20, NP), ((b.s) degree, 21, 33,...
# 2   [(i, 1, 2, NP), (a current online student, 5, ...
# 3   [(more than 6 years, 54, 71, NP), (experience,...
# 4   [(i, 1, 2, NP), (a highly motivated civil engi...
# ..                                                ...
# 95  [([features, 0, 9, NP), (thor, 11, 15, NP), (r...
# 96  [([passionate visioner and doer. expert, 0, 37...
# 97  [(i, 1, 2, NP), (a self-motivated sales, 6, 28...
# 98  [([www.lisawilkins.com specialties, 0, 32, NP)...
# 99  [(10 years experience, 55, 74, NP), (fast pace...
#
#                                             compounds  \
# 0   [(recruiting industry, 22, 41, COMPOUND), (qua...
# 1   [(telecommunications networks, 39, 66, COMPOUN...
# 2   [(fashion merchandising, 34, 55, COMPOUND), (n...
# 3   [(device marketing, 90, 106, COMPOUND), (produ...
# 4   [(construction industry, 83, 104, COMPOUND), (...
# ..                                                ...
# 95  [(ragnarok spiderman, 17, 35, COMPOUND), (inde...
# 96  [(project development, 53, 72, COMPOUND), (pac...
# 97  [(communication skills, 69, 89, COMPOUND), (mg...
# 98  [(ux design, 34, 43, COMPOUND), (business requ...
# 99  [(healthcare professional, 1, 24, COMPOUND), (...
#
#                                            comp_nouns
# 0   {client groups, groups, member, relationship, ...
# 1   {tudor, switching, bgp, july, ospf, dwdm, tech...
# 2   {nordstrom, nordstrom(nordstrom, merchandising...
# 3   {track, marketing, relationship, life, product...
# 4   {excavation, project teams, fit, construction ...
# ..                                                ...
# 95  {day, turtles, harry, carribean, compass gener...
# 96  {career progression, establishment, project, c...
# 97  {rotor, life, llc, clients, mastery, property,...
# 98  {solutions, tv systems, answer, details, busin...
# 99  {coaching, health, decision maker, years exper...
#
# [100 rows x 7 columns]

# %%
def drop_duplicate_np_splits(ents):
    """Drop any entities that are already captured by noun phrases. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    drop_ents = set()
    for ent in ents:
        if len(ent.split(' ')) > 1:
            for e in ent.split(' '):
                if e in ents:
                    drop_ents.add(e)
    return ents - drop_ents

def drop_single_char_nps(ents):
    """Within an entity, drop single characters. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    return {' '.join([e for e in ent.split(' ') if not len(e) == 1]) for ent in ents}

def drop_double_char(ents):
    """Drop any entities that are less than three characters. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    drop_ents = {ent for ent in ents if len(ent) < 3}
    return ents - drop_ents

def keep_alpha(ents):
    """Keep only entities with alphabetical unicode characters, hyphens, and spaces. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    keep_char = set('-abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ')
    drop_ents = {ent for ent in ents if not set(ent).issubset(keep_char)}
    return ents - drop_ents

# %%
type(df["nouns"][0][0][0])
# Out:
# str

# %%
df["nouns"][0][0][0]
# Out:
# 'years'

# %%
# Take all entries from all columns and put in a single dictionary as entities,

# %% [markdown]
# # Trying Knowledge Graph Approach

# %% [markdown]
# - https://www.kaggle.com/pavansanagapati/knowledge-graph-nlp-tutorial-bert-spacy-nltk

# %%
import re
import pandas as pd
# import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_lg')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
# import wikipedia sentences
candidate_sentences = pd.read_csv("Train_Data/Accuracy_Data/Dataset_to_run_on_all/tagged_simanchala_100.csv")
candidate_sentences.shape
# Out:
# (100, 11)

# %%
candidate_sentences['summaries'].sample(5)
# Out:
# 69    [i have recently read a number of books that reference the growth mindset which is a concept that resonates with me. i've applied a growth mindset in my career and it drives me to find new things ...
# 76    [een mooi merk en een sterk team met ruim 17 jaar marketing & communicatie-ervaring zit ik nu op plek waarbij twee van mijn inspiratiebronnen bij elkaar komen: een mooi, sterk merk en een team van...
# 87    [dyson transform every category they enter with radical and iconic reinventions that work, perform and look very different. that makes dyson far from ordinary and i love the unique culture. not al...
# 19    [i'm co-owner/coo of alesmith brewing company which has been operating since 1995. we are also business partners with the soon to be mikkeller san diego brewing company which is due to open early ...
# 20    [having 10 years of experience in digital, analog mixed and rf board designing - knowledge of product designing from scratch to end - expertise in iot product design including rf platform like ble...
# Name: summaries, dtype: object

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["summaries"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 100/100 [00:16<00:00,  6.02it/s]

# %%
entity_pairs[10:20]
# Out:
# [['technology cloud it', 'information facebook'],
#  ['managing process yasemin', 'northwest relocation council'],
#  ['larger loan i', 'residential branch bankunited'],
#  ['specialist  vmware', 'solutioning investment ibm'],
#  ['active brand leader', 'small advocacy influitive'],
#  ['i', 'nonstop product support amazon'],
#  ['principal development strategist i', 'grumman engineer corporation'],
#  ['freelance  i', 'startup italiana things'],
#  ['corporate account ability', 'recruitment vdart inc'],
#  ['cover we', 'human alesmith brewing company']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", [pattern]) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['summaries'])]
# Out:
# 100%|██████████| 100/100 [00:13<00:00,  7.20it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# am                    4
# is                    3
# specialist at         2
# manager at            2
# specialties           2
#                      ..
# covered               1
# experience of lead    1
# receive positive      1
# experienced           1
# research              1
# Length: 50, dtype: int64

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
kg_df
# Out:
#                            source                         target  \
# 0           senior technology any      purple squirrel microsoft
# 1                    glbp \n mpls               8 network asavie
# 2                               i  founder fashion icandydesigns
# 3    proven distributor expertise         medical product system
# 4                       unique  i         capable site multiplex
# ..                            ...                            ...
# 95                final cloth cut       senior engine design inc
# 96             strategic business            plastic supply bank
# 97  professional helicopter pilot                 total qc miami
# 98        entire development time                  well nbc news
# 99               patient advocate      clinical crossover health
#
#                 edge
# 0                are
# 1         members in
# 2            sell on
# 3   receive positive
# 4                 am
# ..               ...
# 95             td at
# 96          location
# 97         broker at
# 98       designer at
# 99  improved patient
#
# [100 rows x 3 columns]

# %%
# Target is the Entity

# %%
len(kg_df["target"].to_list())
# Out:
# 100

# %%
# df names : kg_df and df

# %%
df
# Out:
#                                                                                                                                                                                                        text  \
# 0   [15+ years within the recruiting industry combined with ten years in management contribute to a well-rounded recruiting professional dedicated to finding quality candidates for my client groups. m...
# 1   [bachelor of science (b.s) degree in " telecommunications networks and software " program at politehnica university - electronics ,telecommunications and information technology faculty master of s...
# 2   [i'm a current online student for fashion merchandising and management. i started my own business 4 years ago, called icandydesigns. a company where i sell my own handcrafted jewelry and women's c...
# 3   [high-performing,strategic-thinking professional with more than 6 years' of experience in medical device marketing and product management. an engineer by qualification, a marketing profession by v...
# 4   [i am a highly motivated civil engineer with over eight years of experience in the construction industry. throughout my career i have been involved in many aspects of civil works and construction,...
# ..                                                                                                                                                                                                      ...
# 95  [features: thor: ragnarok spiderman: homecoming logan fantastic beasts and where to find them independence day resurgence alice through the looking glass chappie teenage mutant ninja turtles pompe...
# 96  [passionate visioner and doer. expert in sustainable project development, plastic packaging manufacturing, polymer products marketing and procurement "...to grow professionally by securing a chall...
# 97  [i am a self-motivated sales & marketing professional with excellent communication skills. in addition, i possess strong web based marketing and database mgmt experience. as a owner & operator at ...
# 98  [www.lisawilkins.com specialties: visual/ui/ux design and research for online media, mobile & ott. business requirements in hand, my first and foremost goal is to create an experience where my wor...
# 99  [driven and compassionate healthcare professional with 10 years experience in fast paced departments in hospital and clinical settings, including primary care and medical specialty departments acr...
#
#                                                                                                                                                                                                  named_ents  \
# 0                           [(15+ years, 1, 10, DATE), (ten years, 56, 65, DATE), (13 years, 1005, 1013, DATE), (ten years, 1059, 1068, DATE), (11 years, 2009, 2017, DATE), (ten years, 2063, 2072, DATE)]
# 1   [(640, 406, 409, CARDINAL), (642, 449, 452, CARDINAL), (642, 525, 528, CARDINAL), (642, 610, 613, CARDINAL), (l2/l3, 750, 755, ORG), (2011, 1835, 1839, DATE), (july 2013, 1994, 2003, DATE), (workd...
# 2   [(4 years ago, 98, 109, DATE), (atlanta, 232, 239, GPE), (2015 4th quarter, 381, 397, DATE), (april 2016-may 2016, 508, 527, DATE), (over 5 years, 550, 562, DATE), (3 yrs, 574, 579, DATE), (5 year...
# 3                                                                                                          [(more than 6 years', 54, 72, DATE), (9 years', 1011, 1019, DATE), (8 years', 1958, 1966, DATE)]
# 4   [(eight years, 50, 61, DATE), (hong kong, 563, 572, GPE), (ten years, 1131, 1140, DATE), (hong kong, 1349, 1358, GPE), (nine years, 2134, 2144, DATE), (hong kong, 2550, 2559, GPE), (eight years, 3...
# ..                                                                                                                                                                                                      ...
# 95  [(alice, 122, 127, PERSON), (john carter, 294, 305, PERSON), (3delight, 504, 512, CARDINAL), (alice, 960, 965, PERSON), (john carter, 1132, 1143, PERSON), (3delight, 1342, 1350, CARDINAL), (alice,...
# 96  [(fifteen years, 363, 376, DATE), (fifteen years, 1375, 1388, DATE), (twelve years, 2382, 2394, DATE), (15 years, 3176, 3184, DATE), (los angeles, 3358, 3369, GPE), (california, 3371, 3381, GPE), ...
# 97  [(miami, 267, 272, GPE), (miami, 331, 336, GPE), (miami, 962, 967, GPE), (miami, 1026, 1031, GPE), (miami, 1623, 1628, GPE), (miami, 1687, 1692, GPE), (second, 2758, 2764, ORDINAL), (miami, 2881, ...
# 98  [(first, 133, 138, ORDINAL), (first, 1191, 1196, ORDINAL), (first, 1973, 1978, ORDINAL), (https://medium.com/@rhysys/no-dickheads-a-guide-to-building-happy-healthy-and-creative-teams-7e9b049fc57d\...
# 99  [(10 years, 55, 63, DATE), (first, 475, 480, ORDINAL), (first, 789, 794, ORDINAL), (8 years, 913, 920, DATE), (first, 1332, 1337, ORDINAL), (first, 1646, 1651, ORDINAL), (9 years, 1770, 1777, DATE...
#
#                                                                                                                                                                                                       nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NOUN), (industry, 33, 41, NOUN), (years, 60, 65, NOUN), (management, 69, 79, NOUN), (quality, 154, 161, NOUN), (candidates, 162, 172, NOUN), (client, 18...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOUN), (b.s, 22, 25, NOUN), (degree, 27, 33, NOUN), (telecommunications, 39, 57, NOUN), (networks, 58, 66, NOUN), (software, 71, 79, NOUN), (program, 82,...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NOUN), (merchandising, 42, 55, NOUN), (management, 60, 70, NOUN), (business, 89, 97, NOUN), (years, 100, 105, NOUN), (icandydesigns, 118, 131, NOUN), (c...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, NOUN), (device, 98, 104, NOUN), (marketing, 105, 114, NOUN), (product, 119, 126, NOUN), (management, 127, 137, NOUN), (engineer, 142, 150, NOUN), (qual...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOUN), (experience, 65, 75, NOUN), (construction, 83, 95, NOUN), (industry, 96, 104, NOUN), (career, 120, 126, NOUN), (aspects, 156, 163, NOUN), (works, ...
# ..                                                                                                                                                                                                      ...
# 95  [(features, 1, 9, NOUN), (thor, 11, 15, NOUN), (ragnarok, 17, 25, NOUN), (spiderman, 26, 35, NOUN), (homecoming, 37, 47, NOUN), (beasts, 64, 70, NOUN), (independence, 94, 106, NOUN), (day, 107, 11...
# 96  [(visioner, 12, 20, NOUN), (doer, 25, 29, NOUN), (expert, 31, 37, NOUN), (project, 53, 60, NOUN), (development, 61, 72, NOUN), (plastic, 74, 81, NOUN), (packaging, 82, 91, NOUN), (manufacturing, 9...
# 97  [(self, 8, 12, NOUN), (sales, 23, 28, NOUN), (marketing, 31, 40, NOUN), (communication, 69, 82, NOUN), (skills, 83, 89, NOUN), (addition, 94, 102, NOUN), (web, 121, 124, NOUN), (marketing, 131, 14...
# 98  [(specialties, 21, 32, NOUN), (visual, 34, 40, NOUN), (ui, 41, 43, NOUN), (ux, 44, 46, NOUN), (design, 47, 53, NOUN), (research, 58, 66, NOUN), (media, 78, 83, NOUN), (mobile, 85, 91, NOUN), (ott,...
# 99  [(healthcare, 26, 36, NOUN), (years, 58, 63, NOUN), (experience, 64, 74, NOUN), (departments, 89, 100, NOUN), (hospital, 104, 112, NOUN), (settings, 126, 134, NOUN), (care, 154, 158, NOUN), (speci...
#
#                                                                                                                                                                                                 named_nouns  \
# 0   [(years, 5, 10, NOUN), (recruiting, 22, 32, NOUN), (industry, 33, 41, NOUN), (years, 60, 65, NOUN), (management, 69, 79, NOUN), (quality, 154, 161, NOUN), (candidates, 162, 172, NOUN), (client, 18...
# 1   [(bachelor, 1, 9, NOUN), (science, 13, 20, NOUN), (b.s, 22, 25, NOUN), (degree, 27, 33, NOUN), (telecommunications, 39, 57, NOUN), (networks, 58, 66, NOUN), (software, 71, 79, NOUN), (program, 82,...
# 2   [(student, 22, 29, NOUN), (fashion, 34, 41, NOUN), (merchandising, 42, 55, NOUN), (management, 60, 70, NOUN), (business, 89, 97, NOUN), (years, 100, 105, NOUN), (icandydesigns, 118, 131, NOUN), (c...
# 3   [(years, 66, 71, NOUN), (experience, 76, 86, NOUN), (device, 98, 104, NOUN), (marketing, 105, 114, NOUN), (product, 119, 126, NOUN), (management, 127, 137, NOUN), (engineer, 142, 150, NOUN), (qual...
# 4   [(engineer, 31, 39, NOUN), (years, 56, 61, NOUN), (experience, 65, 75, NOUN), (construction, 83, 95, NOUN), (industry, 96, 104, NOUN), (career, 120, 126, NOUN), (aspects, 156, 163, NOUN), (works, ...
# ..                                                                                                                                                                                                      ...
# 4   {excavation, project teams, fit, construction team, contractor, project, years experience, section engineer, leadership, uae, project management, quality, focus, uk, section, infrastructure works,...
# ..                                                                                                                                                                                                      ...
# 95  {day, turtles, harry, carribean, compass generation, stanger, inc, prince, water, monsters, carter, john carter, photoshop, stanger tides harry potter, zbrush, byzantium, blood prince, scripting, ...
# 96  {career progression, establishment, project, california, fact, polymer products marketing, los angeles, application, forecasting, location, bank, inc, growth, george, doer, packaging, angeles, alp...
# 97  {rotor, life, llc, clients, mastery, property, methods, marketing skills, tql miami, rotor wing pilot, communication, peak management llc, construction, man, crm, capacity, manager, qc, rapport, l...
# 98  {solutions, tv systems, answer, details, business requirements, insecurity, end -, devs, time, prototypes, css, teams, devices, wireframes, front-end development, ux designer, nbc news, https://me...
# 99  {coaching, health, decision maker, years experience, staff, palo, care center manager, solver, outcomes, quality, activities, focus, implementation, specialist, time management skills, experience,...
#
# [100 rows x 7 columns]

# %%
def entity_list(column_name_list):
    entity_list = []
    for i in range(0, len(column_name_list)):
        entity_list.append(column_name_list[i][0])
        
    return entity_list

# %%
df['named_ents'] = df.apply(lambda x: entity_list(x["named_ents"]), axis = 1)

# %%
df['nouns'] = df.apply(lambda x: entity_list(x["nouns"]), axis = 1)

# %%
df['named_nouns'] = df.apply(lambda x: entity_list(x["named_nouns"]), axis = 1)

# %%
df['noun_phrases'] = df.apply(lambda x: entity_list(x["noun_phrases"]), axis = 1)

# %%
df['compounds'] = df.apply(lambda x: entity_list(x["compounds"]), axis = 1)

# %%
type(df['comp_nouns'][0])
# Out:
# set

# %%
def combine_entities(list_1,list_2,list_3,list_4,list_5,list_6):
    list_6 = list(list_6)
    final_list = list_1+list_2+list_3+list_4+list_5+list_6
    
    combined_list_unique = list(set(final_list))
    
    return combined_list_unique

# %%
df['combined_list_unique'] = df.apply(lambda x: combine_entities(x["named_ents"], x["nouns"], x["named_nouns"], x["noun_phrases"], x["compounds"], x["comp_nouns"]), axis = 1)

# %%
len(df['combined_list_unique'][0])
# Out:
# 104

# %%
df
# Out:
#                                                                                                                                                                                                        text  \
# 0   [15+ years within the recruiting industry combined with ten years in management contribute to a well-rounded recruiting professional dedicated to finding quality candidates for my client groups. m...
# 1   [bachelor of science (b.s) degree in " telecommunications networks and software " program at politehnica university - electronics ,telecommunications and information technology faculty master of s...
# 2   [i'm a current online student for fashion merchandising and management. i started my own business 4 years ago, called icandydesigns. a company where i sell my own handcrafted jewelry and women's c...
# 3   [high-performing,strategic-thinking professional with more than 6 years' of experience in medical device marketing and product management. an engineer by qualification, a marketing profession by v...
# 4   [i am a highly motivated civil engineer with over eight years of experience in the construction industry. throughout my career i have been involved in many aspects of civil works and construction,...
# ..                                                                                                                                                                                                      ...
# 95  [features: thor: ragnarok spiderman: homecoming logan fantastic beasts and where to find them independence day resurgence alice through the looking glass chappie teenage mutant ninja turtles pompe...
# 96  [passionate visioner and doer. expert in sustainable project development, plastic packaging manufacturing, polymer products marketing and procurement "...to grow professionally by securing a chall...
# 97  [i am a self-motivated sales & marketing professional with excellent communication skills. in addition, i possess strong web based marketing and database mgmt experience. as a owner & operator at ...
# 98  [www.lisawilkins.com specialties: visual/ui/ux design and research for online media, mobile & ott. business requirements in hand, my first and foremost goal is to create an experience where my wor...
# 99  [driven and compassionate healthcare professional with 10 years experience in fast paced departments in hospital and clinical settings, including primary care and medical specialty departments acr...
#
#                                                                                                                                                                                                  named_ents  \
# 0                                                                                                                                          [15+ years, ten years, 13 years, ten years, 11 years, ten years]
# 1                                                                                                                                                  [640, 642, 642, 642, l2/l3, 2011, july 2013, workday, 8]
# 2   [4 years ago, atlanta, 2015 4th quarter, april 2016-may 2016, over 5 years, 3 yrs, 5 years ago, atlanta, 2015 4th quarter, 6 years, 3 yrs, 4 years ago, atlanta, over 5 years, 3 yrs, turner&#39;s, ...
# 3                                                                                                                                                                  [more than 6 years', 9 years', 8 years']
# 4                                                                [eight years, hong kong, ten years, hong kong, nine years, hong kong, eight years, hong kong, seven years, hong kong, 6+ years, hong kong]
# ..                                                                                                                                                                                                      ...
# 95                                                                                                               [alice, john carter, 3delight, alice, john carter, 3delight, alice, john carter, 3delight]
# 96                                                                                  [fifteen years, fifteen years, twelve years, 15 years, los angeles, california, 16 years, 13 years, 12 years, 15 years]
# 97                                                                                                                                         [miami, miami, miami, miami, miami, miami, second, miami, miami]
# 98                                                                [first, first, first, https://medium.com/@rhysys/no-dickheads-a-guide-to-building-happy-healthy-and-creative-teams-7e9b049fc57d\n\n, nbc]
# 99                                                                                                           [10 years, first, first, 8 years, first, first, 9 years, first, first, 12 years, first, first]
#
#                                                                                                                                                                                                       nouns  \
# 0   [years, recruiting, industry, years, management, quality, candidates, client, groups, goal, marriage, candidate, team, term, relationship, match, recruiter, work, ways, skills, colleagues, time, r...
# 1   [bachelor, science, b.s, degree, telecommunications, networks, software, program, politehnica, university, electronics, telecommunications, information, technology, faculty, master, science, m.s, ...
# 2   [student, fashion, merchandising, management, business, years, icandydesigns, company, jewelry, women, clothing, boutique, atlanta, events, website, events, company, nordstrom, rack, quarter, star...
# 3   [years, experience, device, marketing, product, management, engineer, qualification, marketing, profession, virtue, position, capacity, projects, timelines, brand, identity, values, team, leader, ...
# 4   [engineer, years, experience, construction, industry, career, aspects, works, construction, focus, excavation, concrete, piling, steelworks, works, lifting, logistics, career, person, operations, ...
# ..                                                                                                                                                                                                      ...
# 95  [features, thor, ragnarok, spiderman, homecoming, beasts, independence, day, resurgence, alice, glass, chappie, turtles, instruments, percy, jackson, sea, monsters, byzantium, expectations, john, ...
# 96  [visioner, doer, expert, project, development, plastic, packaging, manufacturing, polymer, products, marketing, procurement, position, organization, business, knowledge, experience, skills, growth...
# 97  [self, sales, marketing, communication, skills, addition, web, marketing, database, mgmt, experience, owner, operator, quality, miami, objective, focus, miami, cleaning, industry, service, miami, ...
# 98  [specialties, visual, ui, ux, design, research, media, mobile, ott, business, requirements, hand, goal, experience, work, end, user, solutions, wireframes, prototypes, user, tests, iterations, ske...
# 99  [healthcare, years, experience, departments, hospital, settings, care, specialty, departments, palo, alto, foundation, experience, coaching, staff, planning, organizing, activities, goals, mission...
#
#                                                                                                                                                                                                 named_nouns  \
# 0   [years, recruiting, industry, years, management, quality, candidates, client, groups, goal, marriage, candidate, team, term, relationship, match, recruiter, work, ways, skills, colleagues, time, r...
# 1   [bachelor, science, b.s, degree, telecommunications, networks, software, program, politehnica, university, electronics, telecommunications, information, technology, faculty, master, science, m.s, ...
# 2   [student, fashion, merchandising, management, business, years, icandydesigns, company, jewelry, women, clothing, boutique, atlanta, events, website, events, company, nordstrom, rack, quarter, star...
# 3   [years, experience, device, marketing, product, management, engineer, qualification, marketing, profession, virtue, position, capacity, projects, timelines, brand, identity, values, team, leader, ...
# 4   [engineer, years, experience, construction, industry, career, aspects, works, construction, focus, excavation, concrete, piling, steelworks, works, lifting, logistics, career, person, operations, ...
# ..                                                                                                                                                                                                      ...
# 95  [features, thor, ragnarok, spiderman, homecoming, beasts, independence, day, resurgence, alice, glass, chappie, turtles, instruments, percy, jackson, sea, monsters, byzantium, expectations, john c...
# 96  [visioner, doer, expert, project, development, plastic, packaging, manufacturing, polymer, products, marketing, procurement, position, organization, business, knowledge, experience, skills, growth...
# 97  [self, sales, marketing, communication, skills, addition, web, marketing, database, mgmt, experience, owner, operator, quality, miami, objective, focus, miami, cleaning, industry, service, miami, ...
# 98  [specialties, visual, ui, ux, design, research, media, mobile, ott, business, requirements, hand, goal, experience, work, end, user, solutions, wireframes, prototypes, user, tests, iterations, ske...
# 99  [healthcare, years, experience, departments, hospital, settings, care, specialty, departments, palo, alto, foundation, experience, coaching, staff, planning, organizing, activities, goals, mission...
#
#                                                                                                                                                                                                noun_phrases  \
# 0   [the recruiting industry, ten years, management, quality candidates, my client groups, my goal, the perfect marriage, the candidate, the team, a long term relationship, the perfect match, i, the c...
# 1   [science, (b.s) degree, telecommunications networks, software " program, politehnica, university - electronics ,telecommunications and information technology faculty master, science, management, n...
# 2   [i, a current online student, fashion merchandising, management, i, my own business, icandydesigns, a company, i, my own handcrafted jewelry, women's clothing, i, a boutique, atlanta, events, i, m...
# 3   [more than 6 years, experience, medical device marketing, product management, an engineer, qualification, a marketing profession, virtue, current position, strong capacity, multiple projects, stri...
# 4   [i, a highly motivated civil engineer, over eight years, experience, the construction industry, my career, i, many aspects, civil works, construction, a main focus, excavation, reinforced concrete...
# ..                                                                                                                                                                                                      ...
# 95  [[features, thor, ragnarok spiderman, homecoming logan fantastic beasts, them, the looking glass chappie teenage mutant ninja turtles, the mortal instruments, percy jackson, sea, monsters, byzanti...
# 96  [[passionate visioner and doer. expert, sustainable project development, plastic packaging manufacturing, polymer products marketing, procurement, a challenging leading position, a dynamic organiz...
# 97  [i, a self-motivated sales, marketing, excellent communication skills, addition, i, strong web based marketing and database mgmt experience, a owner, operator, quality clean miami, my objective, f...
# 98  [[www.lisawilkins.com specialties, visual/ui/ux design, research, online media, mobile, ott, hand, my first and foremost goal, an experience, my work, the end-user, my solutions, i, wireframes, pr...
# 99  [10 years experience, fast paced departments, hospital and clinical settings, primary care, medical specialty departments, palo alto medical foundation, extensive experience, clinical staff, plann...
#
#                                                                                                                                                                                                   compounds  \
# 0   [recruiting industry, quality candidates, client groups, term relationship, sourcing guru, networking capabilities, sourcing techniques, it sector, recruiting abilities, recruiting industry, quali...
# 1   [telecommunications networks, university -, faculty master, university -, faculty routing, cisco ccna, cisco ccnp, 642 -, cisco ccnp switch, cisco ccnp, 642 -, l3 protocols, -data link protocols, ...
# 2   [fashion merchandising, nordstrom rack, store manager, nordstrom leaders, event coordinating, customer service, time management, fashion blogging, marketing skills, fashion merchandising, store ma...
# 3   [device marketing, product management, marketing profession, brand identity, track record, communication skills, device marketing, product management, life -, product training, application special...
# 4   [construction industry, certificate iv, project management, hong kong, project teams, leadership roles, quality results, project teams, project team, construction industry, infrastructure works, f...
# ..                                                                                                                                                                                                      ...
# 95  [ragnarok spiderman, independence day, resurgence alice, percy jackson, recall byzantium, john carter, mars pirates, stanger tides harry potter, blood prince bedtime stories, compass generation, v...
# 96  [project development, packaging manufacturing, polymer products marketing, business knowledge, years experience, packaging industry, business processes, career progression, contract administration...
# 97  [communication skills, mgmt experience, cleaning industry, qc miami, cleaning job, business man, sell products, network ties, investment zoom, communication skills, cleaning industry, qc miami, cl...
# 98  [ux design, business requirements, end -, user tests, development process, information hoarders, tv systems, business requirements, end -, user tests, development process, \n\n specialties, ux des...
# 99  [healthcare professional, years experience, specialty departments, problem -, time management skills, disease prevention, service recovery, quality healthcare, decision maker, patient advocate, pa...
#
#                                                                                                                                                                                                  comp_nouns  \
# 0   {client groups, groups, member, relationship, abilities, capabilities, technology, quality, match, ways, collector, squirrel stalker, skills, specialties, recruiting industry, recruiting abilities...
# 1   {tudor, switching, bgp, july, ospf, dwdm, technology, platforms, repositories, faculty \n \n master, eigrp, switch, faculty master, cisco ccna, m.s, engineer-internet services, mpls, level, networ...
# 2   {nordstrom, nordstrom(nordstrom, merchandising, events, boutique, interest, nordstrom leaders, hands, time, student, marketing skills, a., fashion blogging, leaders, manager, snhu, fashion retail,...
# 3   {track, marketing, relationship, life, product specalist, life -, collateral, sales, co, -, sr, marketing profession, system, specialist, marketing collateral, experience, skills, application, tim...
# 4   {excavation, project teams, fit, construction team, contractor, project, years experience, section engineer, leadership, uae, project management, quality, focus, uk, section, infrastructure works,...
# ..                                                                                                                                                                                                      ...
# 95  {day, turtles, harry, carribean, compass generation, stanger, inc, prince, water, monsters, carter, john carter, photoshop, stanger tides harry potter, zbrush, byzantium, blood prince, scripting, ...
# 96  {career progression, establishment, project, california, fact, polymer products marketing, los angeles, application, forecasting, location, bank, inc, growth, george, doer, packaging, angeles, alp...
# 97  {rotor, life, llc, clients, mastery, property, methods, marketing skills, tql miami, rotor wing pilot, communication, peak management llc, construction, man, crm, capacity, manager, qc, rapport, l...
# 98  {solutions, tv systems, answer, details, business requirements, insecurity, end -, devs, time, prototypes, css, teams, devices, wireframes, front-end development, ux designer, nbc news, https://me...
# 99  {coaching, health, decision maker, years experience, staff, palo, care center manager, solver, outcomes, quality, activities, focus, implementation, specialist, time management skills, experience,...
#
#                                                                                                                                                                                        combined_list_unique
# 0   [technology, match, collector, senior technical recruiter, techniques, time, mentor, 13 years, squirrel, purple squirrel collector, all statements, networking capabilities, a member, the consummat...
# 1   [tudor, switching, bgp, july, ospf, dwdm, (b.s) degree, technology, platforms, repositories, (b.s, faculty \n \n master, \n- mpls fundamentals, eigrp, switch, senior network analyst, faculty maste...
# 2   [nordstrom, 4 years ago, my own events, nordstrom(nordstrom, merchandising, events, boutique, interest, my store manager, nordstrom leaders, hands, time, nordstrom(nordstrom rack, a great eye, stu...
# 3   [life, co, 9 years, -, marketing profession, marketing collateral, application, brand, interest, demonstration, product launch, track record, workers, strong capacity, 9 years', virtue, expertise,...
# 4   [project teams, fit, both the client, contractor, project, project management, laing, nine years, kong, construction industry, course, deadlines, time, certificate, teams, a construction team, hon...
# ..                                                                                                                                                                                                      ...
# 95  [day, turtles, harry, byzantium great expectations, carribean, compass generation, stanger, inc, prince, the half blood prince\nbedtime stories, the carribean, water, monsters, stanger tides, fant...
# 96  [career progression, establishment, project, california, fact, polymer products marketing, los angeles, my business knowledge, fifteen years experience, fact-based, process-oriented approaches, ap...
# 97  [we, market/ sell products, rotor, life, a property manager, llc, clients, mastery, strong web and crm experience, property, methods, any cleaning job, marketing skills, tql miami, rotor wing pilo...
# 98  [solutions, tv systems, we, answer, the team members, details, business requirements, insecurity, end -, devs, visual/ui/ux design, principle/invision/pixate, time, prototypes, the entire developm...
# 99  [primary care, intense focus, 9 years, licensed vocational nurse, strong decision maker, time, 12 years, patience, advocate, clinic, 10 years experience, departments, implementation specialist, nu...
#
# [100 rows x 8 columns]

# %%
entity_df = pd.concat([df,kg_df["target"]], axis =1)

# %%
entity_df.columns
# Out:
# Index(['text', 'named_ents', 'nouns', 'named_nouns', 'noun_phrases',
#        'compounds', 'comp_nouns', 'combined_list_unique', 'target'],
#       dtype='object')

# %%
entity_df.drop(columns = ['text', 'named_ents', 'nouns', 'named_nouns', 'noun_phrases',
       'compounds', 'comp_nouns'], inplace = True)

# %%
entity_df["combined_list_unique"][0]
# Out:
# ['technology',
#  'match',
#  'collector',
#  'senior technical recruiter',
#  'techniques',
#  'time',
#  'mentor',
#  '13 years',
#  'squirrel',
#  'purple squirrel collector',
#  'all statements',
#  'networking capabilities',
#  'a member',
#  'the consummate recruiter',
#  'people',
#  'sector',
#  'unicorn wrangler',
#  'it sector',
#  'term relationship',
#  'effective sourcing techniques',
#  'microsoft',
#  '\n\n specialties',
#  'the perfect marriage',
#  'strong networking capabilities',
#  'new people',
#  'goal',
#  'my client groups',
#  'groups',
#  'relationship',
#  'abilities',
#  'capabilities',
#  'passive candidates',
#  'my goal',
#  'my skills',
#  'the perfect match',
#  '15+ years',
#  'skills',
#  'specialties',
#  'purple squirrel hunter',
#  'recruiting industry',
#  'the candidate',
#  'unity',
#  'candidate',
#  'term',
#  'snap',
#  'hewlett packard enterprise',
#  'squirrel hunter',
#  'sourcing guru',
#  'methodologies',
#  'recruiting',
#  'work',
#  'ten years',
#  'technologies',
#  'recruiter',
#  'seattle',
#  'networking',
#  'client',
#  'guru',
#  'team',
#  'the recruiting industry',
#  'member',
#  'quality',
#  'what',
#  'my work',
#  'squirrel stalker',
#  'squirrel collector',
#  'purple squirrel stalker',
#  'stalker',
#  'tune',
#  'years',
#  'candidates',
#  'a long term relationship',
#  'quality candidates',
#  'statements',
#  'management',
#  'industry',
#  'colleagues',
#  'technology recruiter',
#  'senior technology recruiter',
#  '\n\nspecialties',
#  'a resource',
#  'unicorn',
#  'enterprise',
#  'unity technologies',
#  'client groups',
#  'my colleagues',
#  'new ways',
#  'ways',
#  'the time',
#  'the team',
#  'national and international recruiting abilities',
#  '11 years',
#  'recruiting abilities',
#  'anyone',
#  'the it sector',
#  'resource',
#  'hewlett',
#  'sourcing techniques',
#  'hunter',
#  'i',
#  'packard',
#  'marriage',
#  'lion',
#  'wrangler']

# %%
type(entity_df["target"][0])
# Out:
# str

# %%
def append_entities(l1, l2):
    print(type(l1))
    print(l1)
    l1.append(l2)
    return l1

# %%
entity_df['combined_list_unique'] = entity_df.apply(lambda x: append_entities(x["combined_list_unique"],x["target"]), axis = 1)
# Out:
# <class 'list'>
# ['technology', 'match', 'collector', 'senior technical recruiter', 'techniques', 'time', 'mentor', '13 years', 'squirrel', 'purple squirrel collector', 'all statements', 'networking capabilities', 'a member', 'the consummate recruiter', 'people', 'sector', 'unicorn wrangler', 'it sector', 'term relationship', 'effective sourcing techniques', 'microsoft', '\n\n specialties', 'the perfect marriage', 'strong networking capabilities', 'new people', 'goal', 'my client groups', 'groups', 'relationship', 'abilities', 'capabilities', 'passive candidates', 'my goal', 'my skills', 'the perfect match', '15+ years', 'skills', 'specialties', 'purple squirrel hunter', 'recruiting industry', 'the candidate', 'unity', 'candidate', 'term', 'snap', 'hewlett packard enterprise', 'squirrel hunter', 'sourcing guru', 'methodologies', 'recruiting', 'work', 'ten years', 'technologies', 'recruiter', 'seattle', 'networking', 'client', 'guru', 'team', 'the recruiting industry', 'member', 'quality', 'what', 'my work', 'squirrel stalker', 'squirrel collector', 'purple squirrel stalker', 'stalker', 'tune', 'years', 'candidates', 'a long term relationship', 'quality candidates', 'statements', 'management', 'industry', 'colleagues', 'technology recruiter', 'senior technology recruiter', '\n\nspecialties', 'a resource', 'unicorn', 'enterprise', 'unity technologies', 'client groups', 'my colleagues', 'new ways', 'ways', 'the time', 'the team', 'national and international recruiting abilities', '11 years', 'recruiting abilities', 'anyone', 'the it sector', 'resource', 'hewlett', 'sourcing techniques', 'hunter', 'i', 'packard', 'marriage', 'lion', 'wrangler']
# <class 'list'>
# ['tudor', 'switching', 'bgp', 'july', 'ospf', 'dwdm', '(b.s) degree', 'technology', 'platforms', 'repositories', '(b.s', 'faculty \n \n master', '\n- mpls fundamentals', 'eigrp', 'switch', 'senior network analyst', 'faculty master', 'cisco ccna', '2011', 'm.s', 'ccnp routing', 'engineer-internet services', 'mpls', 'cisco ip networks', 'level', 'network specialist', 'high availability', 'l2', 'faculty routing', 'internet', 'glbp - mpls fundamentals', 'b.s', '\n- cisco', 'nexus', '642 -', 'likes', 'stp', 'tshoot', 'network engineer', 'office', 'glbp-mpls fundamentals', 'bash', 'link', 'network analyst', 'telecommunications', 'microsoft', 'cisco ccnp switch', 'scripts', 'alcatel sr', 'faculty', 'university -', '" - politehnica university - electronics ,telecommunications and information technology faculty bachelor', 'word', '( 642-832 certification', 'route', 'network automation', 'fundamentals', 'skills', 'specialties', 'telecommunications software', 'master', 'electronics, telecommunications and information technology faculty\n \nmaster', 'ppp', 'quot', 'visio\n\nspecialties', 'network development engineer - internet services', '-cisco ccna', 'jinja', 'hsrp / vrrp', 'the likes', 'the same faculty', '\n-cisco ccnp route diploma', 'hop', 'deployment', 'data', 'services', 'software', 'degree', 'university', '640', 'university - electronics ,telecommunications and information technology faculty routing', 'continent 8 technologies', 'linkedin', 'development', 'linkedin members', 'visio', 'technologies', '\n-mpls fundamentals', 'power point', '\n\n\n-routing protocols', 'information', 'network automation and deployment tools', '\n -', 'redundancy', '-sdh/dwdm - basic level', 'bachelor', '\n- first hop redundancy protocols', 'asavie', 'git', 'telecommunications networks', 'network development engineer -', '8', 'mstp', 'sr', 'cisco ccnp', 'members', 'ireland', 'cisco ccnp tshoot', 'routing', 'workday', 'networks', 'maintenance', '-data link protocols', '" - politehnica university - electronics ,telecommunications and information technology faculty experience', 'power', 'networks and services management', 'ccna', 'engineer', 'alcatel', 'planning', 'large scale networks', 'management', 'diploma', 'politehnica', '\n- unix/linux - basic\n- good knowledge', 'troubleshooting', 'tools', 'suite', 'ldp', 'unix', 'graduate', 'bachelor degree', 'cisco ip routing ) cisco ccnp switch ( 642-813 certification', 'point', 'science', 'hop redundancy protocols', 'scale networks', 'cdp', 'electronics', '- data link protocols', 'glbp -', 'l3', 'analyst', 'versioned repositories', 'continent', 'ccnp', 'route diploma', '( 642-902 certification', 'operation', 'automation', 'university - electronics ,telecommunications and information technology faculty master', 'cisco', 'vrrp', 'availability', 'specialist', 'stp, rstp,mstp', 'experience', 'microsoft office suite', '-cisco routing', 'routing protocols', 'jinja templates', '-cisco', 'bash/python scripts', 'first hop redundancy protocols', 'faculty experience', 'templates', 'l3 protocols', 'alcatel sr platforms - unix/linux', 'l2/l3', 'ldp experience', '\n\n\n- routing protocols', 'july 2013', 'software " program', '( 640-802 certification', '642', 'bucharest', 'science (b.s) degree', 'program', '\n-data link protocols', 'protocols', '\n\n\n -', 'scale', 'hsrp', 'amazon', 'alcatel sr platforms', 'network', 'python scripts', 'faculty bachelor', 'ip', 'juniper', 'major l2/l3 protocols', 'linux', 'certification', 'knowledge', 'python']
# <class 'list'>
# ['project teams', 'fit', 'both the client', 'contractor', 'project', 'project management', 'laing', 'nine years', 'kong', 'construction industry', 'course', 'deadlines', 'time', 'certificate', 'teams', 'a construction team', 'hong kong', 'my team', 'person', 'construction', 'myself', '6+ years experience', 'manager', 'many aspects', 'civil works', 'operations', 'project team', 'my career', 'insight', 'construction team', 'years experience', 'uk', "laing o'rourke", 'over seven years', 'reinforced concrete', 'me', 'perspectives', 'aipm', 'roles', '6+ years', 'works', 'a multi-skilled and adaptable individual', 'australia', 'certificate iv', 'multiplex', 'a main focus', 'steelworks', 'ten years', 'aspects', 'environments', 'both perspectives', 'client', 'concrete', 'united kingdom', 'fit -', 'team', 'budget', 'quality', 'section', '(aipm', "o'rourke", 'a number', 'engineer', 'individual', 'years', 'leea', 'site manager', 'infrastructure', 'eight years', 'management', 'multi-cultural and diverse project teams', 'industry', 'a highly motivated civil engineer', 'temporary and enabling works', 'over eight years', 'over nine years', 'currently the uae', 'it', 'excavation', 'section engineer', 'leadership', 'uae', 'focus', 'infrastructure works', 'experience', 'brookfield', 'civil infrastructure works', 'piling', 'leadership roles', 'kingdom', 'out', 'a project', 'lifting', 'hong', 'the appointed person', 'number', 'career', 'seven years', 'brookfield multiplex', 'i', 'results', 'quality results', 'a project team', 'site', 'fit-out', 'the construction industry', 'a unique insight', 'logistics', 'a highly motivated individual', 'over ten years']
# <class 'list'>
# ['we', 'future', 'machine development', 'mazak 5 axis', 'catia nc programming', 'fidia', 'offline catia nc programming', 'zimmerman 5 axis', 'bracket', 'vb base post', 'cargo', 'time', 'axis', 'aerospace component', 'a experience', 'stringer', 'macro programming automation', 'catia', 'optipath', 'purpose', 'doors', '7.1', 'scripting', 'titanium machining', 'aerospace industry', 'vba', 'hmc', 'vendors', 'turn', 'design', 'goal', 'aviation', 'gear', 'reduction', 'domain', 'tolerance detailed parts', 'v5 v612', 'md', 'component', 'our manufacturing goal', 'axis gantry', 'macro automation', 'aerospace nc programming consulting services', 'aerospace domain -', 'shop', 'nc programming consultant', '5-axis -cincinnati', 'big structural aerospace part', 'custom vb', 'nc_programming', 'zimmerman', 'engineering', 'complex surface designer', 'our services', 'processor', 'tail', 'nc programming services', 'hass', 'mazak 5 axis milling', 'data', 'vbaautomotive designer', 'services', 'base', 'aerospace structural parts', 'post', 'ims , vb base post - vericut machine development', 'wings aircraft seat bracket', 'shop-data generation', '5 axis gantry', 'landing', 'programming automation', 'aerospace parti', '10.0', 'rocket', 'mill', 'components', 'development', 'technologies', 'fixture', 'blueprint', '%', 'sme-automation base shop -', 'vf4', 'owner', 'tooling design', 'generation', 'mazak', 'boeing', 'machining', 'wings', 'custom vb scripting', 'products', 'fixture design', 'stringer upper wings aircraft seat bracket', 'cnc milling production assembly plastic injection mold manufacturing plastic parts production', 'parti', 'aerospace', 'designer', 'milling production assembly plastic injection mold manufacturing', 'helicopter', 'topsolid consulting services', '4', 'injection', 'parts', 'javelin engineering', 'expectations', 'customer expectations', 'composite tooling design', 'aerospace domain - post processor development', 'mastercam', 'manufacturing goal', 'utility', '4 axis hmc programming', 'mold', 'core', 'javelin technologies', 'part', 'years', 'vbaautomotive', 'manufacturing', 'titanium', 'milling', 'millturn', 'programming language', 'language', '5 years', 'esprit , topsolid consulting services - providing offline catia nc programming', 'industry', 'consulting', 'landing gear assembly components bracket', 'web', 'northhrop', 'contract', 'ims', 'gantry', 'customer', 'v612 axis mill-turn programmingsuccessfully programmed landing gear assembly', 'production assembly plastic injection mold manufacturing titanium machining', 'vba - complex aerospace blueprint conversation - aerospace structural parts', 'engineering services', 'new machine development', 'tail stringer', 'vb', 'cnc', 'area', 'hmc post', 'prices', 'production', 'support', 'custom', '% cycle time reduction', 'programming', 'consistent and predictable products', 'axis hmc programming', 'worldwide sme - automation base shop-data generation', '20 %', 'automation', 'plastic parts production', 'successfully developed wfl millturn', 'tooling', 'axis mill', 'contract nc programming', 'consultant', 'millpost', 'nx', 'experience', 'surface', 'aerospace part', 'landing gear assembly', 'vba -', 'aircraft', 'core area', '4 axis hmc post', 'md helicopter', 'spar web', '4 years', 'assembly', 'domain-post processor development', 'vba - 20 % cycle time reduction - complex aerospace blueprint conversation - aerospace structural parts', 'very big structural aerospace parti', 'spacex', 'aerospace blueprint conversation -', 'assemblies', 'production assembly plastic injection mold', 'cycle', 'surface designer', 'seat', 'wfl millturn', '5-axis -cincinnati gantry millpost processor development', 'spar', 'conversation', 'gantry millpost processor development', 'assembly components', 'catia & nx', 'plastic', 'javelin', 'tolerance', 'machine', 'competitive prices', 'gear assembly', 'lockheedmartin', 'nc', 'wfl', 'axis milling', 'cnc milling', '5']
# <class 'list'>
# ['way', 'large businesses', 'we', 'weekly', 'an easier option', 'life', 'questions', 'persistence', 'their individual clients', 'north', 'how positive thinking', 'experiences', 'clients', 'an additional service', 'clientele', 'indirect sales channels', 'corporate clientele', 'customer services', 'time', 'level', 'business development manager', 'speaker', 'managers', 'patience', 'teams', 'their portfolio', 'their utilities', 'channel-', 'over 10 years', 'partners', 'my experience', 'partner channel', 'marketing strategies', 'weds', 'large corporate clientele', 'customers', 'sector', 'b2b businesses', 'thinking', 'businesses', 'manager', 'journey', 'tim.strange22@outlook.com', 'my way', 'business processes', 'offering', 'the relationships', 'utility cost', 'option', 'all levels', 'reduction', 'utility management plan', 'utilities', 'leading teams', 'utility alliance', 'you', 'a weekly show', 'sales', 'my journey', 'their business utilities', 'all aspects', 'the sme and corporate sector', 'me', 'their customers', 'over 12 years', 'decision', 'training', 'business', 'large business associations', 'procurement', 'services', 'development', 'consumption', 'sme businesses', 'www.novaradio.co.uk', 'the partner channel-', 'utility management', 'their utility cost', 'your businesses', 'aspects', 'energy sector', 'a partner', 'channel', 'team', 'north america', 'our service offering', 'america', 'well over 10 years', 'marketing', 'associations', 'membership', 'procurement and consumption reduction strategies', 'partners clients', 'our partners', 'partner channel manager-', 'levels', 'relationships', 'utility management sector', 'plan', 'utility', 'energy', 'years', 'partnerships', 'the partner channel', 'the utility sector', 'director level', 'addiction', 'management', 'partner channel-', 'europe', 'manager-', 'head', 'the utility management sector', 'business management', 'customer', 'hustle', 'an energy procurement strategy', 'tim talks', 'partnership managers', 'processes', 'building', 'strategies', 'utility sector', 'door', 'their clientele', 'building partner relationships', 'it', 'membership benefits', 'host', 'your business', 'benefits', 'show', 'money', 'both residential and commerc
# ['project', 'project management', 'technology', '-', 'saas', 'iesa', 'dev', 'facebook', 'strategic network architecture', '\n - vulnerability assessments', 'ms office suite', 'paas', 'confluence', 'audit project', 'compliance manager', 'technical skills ms office suite', 'oracle', 'track record', 'itil', 'compliance', 'teams', 'information security', 'expertise', 'cloud services', 'cis', 'technology compliance manager', 'office', 'okta', '-technology governance', 'over 6 years', 'manager', '1', 'track record building', 'business processes', 'security and compliance initiatives', 'systrust', 'operations', 'process', 'iaas', '\n\nexpertise', 'leading teams', 'architecture', 'a proven track record driving security and compliance initiatives', 'leading projects', 'database', 'assessment', 'omnigraffle', 'technical skills', 'skills', 'complex globally distributed environments', 'the following: - information security and technology compliance', 'engineering', 'network architecture', 'improvement', 'cloud', 'large scale information security initiatives', '. -', 'business', 'process engineering', '-vulnerability assessments', 'services', 'disa -', 'high performing information security and technology compliance manager', 'trust', 'information security risk', 'privacy', 'development', '(soc', 'paas environments', 'os', 'technical business processes', 'leading technology and cloud services companies', 'vulnerability', 'information', 'environments', 'a proven track record building', 'nexpose', '.', 'confidentiality', 'track record driving', '- proven track record', 'compliance frameworks', '[high performing technology compliance manager', 'appdynamics', '\n -securityinformation security', 'jira', 'assessments', 'projects', '\n -technology governance', 'governance', 'erp', 'years', 'saas/paas environments', 'the following', 'ssae', 'salesforce', 'personnel', '. - vulnerability assessments', 'management', ' compliance frameworks', 'suite', 'casper suite', 'sql', 'record', 'ms', 'fedramp', '3', 'processes', 'building', 'following', 'oracle database', 'controls', 'it', '2', 'track record leading', 'frameworks', '800-53', 'experience leading teams', 'systrust, cis, disa-stig', '\n  -', 'track', 'audit', 'the assessment', 'a proven track record leading teams', 'risk management', 'information security and technology compliance manager', 'implementation', 'availability', 'personnel management', 'experience', '16', '- proficiency', 'process improvement', 'atlassian jira', '.-vulnerability assessments', 'casper', 'risk', 'companies', '6 years', '\n - proficiency', '\n - technology governance', 'excel macro dev', 'security', 'principals', 'technology risk', 'scale information security initiatives', 'proficiency', 'trust principals', 'program', '3402', 'program management', 'initiatives', 'technical operations', 'scale', '- technology governance', 'soc', 'network', 'skills ms office suite', 'driving', 'cloud architecture', 'nist']
# <class 'list'>
# ['procedures', 'program design', 'european and international businesses', 'project', 'perm placement agencies', 'checks', 'm', 'vendor management', 'agency', 'programs', 'interest', 'hr', 'agency recruiting', 'diversity recruiting', 'programs(~$1', 'expertise', 'background checks', 'background check', 'people', 'selection', 'yasemin', 'customers', 'exception management', 'my 6+ years', 'conflict', 'office', 'mobility process development', 'foreign languages', 'the last several months', 'businesses', 'manager', 'reporting', 'mobility', 'design', 'operations', 'bacground', 'process', 'relocation program manager', 'northwest', 'retail banking - back office', 'council', 'sales', 'medical device - electrical engineering', 'sr . hr program manager', 'project implementation', 'medical device - mechanical engineering', 't', 'engineering', 'the organization', 'agency hiring', 'ability', 'improvement', 'membership chair', 'languages', 'business', 'inclusion', '6+ years', 'background', 'communications', 'social media', 'process steps', 'supplier management', 'organization', 'an extensive bacground', 'account management', 'development', 'recruiting', 'chair', 'resolution', 'direct hire/perm placement agencies', 'satisfaction', 'environments', '. hr program manager', 'high levels', 'exception', 'client', 'corpdev', 'hr professional', 'mobile', 'conflict resolution', '.', 'business and intercult
keting strategies', 'content', 'customers', 'campaigns', 'print marketing', 'product management', 'xerox canada ltd', 'advertising', 'the most value', 'telecommunications', 'manager', 'storage', 'long lasting relationships', 'collaboration', 'community', 'content development', 'goal', 'process', 'their marketing strategy', 'value', 'relationship', 'my goal', 'problems', 'sales', 'coach', 'canada', 'their business problems', 'they', 'skills', 'specialties', 'online content development', 'me', 'event strategy', 'passion', '-positioning project management social media', 'work ethic', 'customer success manager', 'decision', 'training', 'relentless work ethic', 'business', 'business problems', 'marketing brand development', 'background', 'services', 'advocacy', 'client and account management marketing strategy mentorship/leadership training', 'communications', 'social media', 'leadership training', 'relationship management', 'event', 'development', 'share', 'leader', 'work', 'document management', 'increased brand penetration', 'ethic', 'client', 'advocacy coach', 'product', 'analysis', 'penetration', 'bay st', 'marketing', "xerox's wallet share", 'national meetings', 'profit', 'success', 'bay', 'what', 'brand development', 'relationships', 'my passion', 'client manager', 'projects', 'wallet share', 'decision making', 'internal and external customers', 'experiential marketing', 'ltd', 'targets', 'individual', 'document', 'marketing strategy', 'leading programs', '\n\n\n specialties', 'systems', 'management', 'industry', 'trend', 'a keen interest', 'a highly competitive industry', 'customer', 'face', 'strategies', 'online research', 'xerox', 'manager client development', 'communicator', 'it', 'my knowledge', 'company', 'tick', 'leadership', 'the decision making process', 'ways', 'role', 'a strong background', 'advertising \n\n\nindustries', 'industries', 'st', 'marketer', "my customer's tick", 'company sales targets', 'management marketing strategy mentorship', 're', 'media', 'influitive', 'i', 'a highly pro-active leader', 'research', 'the overall business', 'valuable relationships', 'strategy', 'community/advocacy marketing', 'every marketer', '\n\n\nspecialties', 'business storage', 'excellent communicator', 'marketing communications advertising industries', 'advocacy marketing', 'problem', '-positioning project management integrated marketing communications social media', 'account', 'b', 'professional, senior client manager', 'client management', 'knowledge']
# <class 'list'>
# ['scheme', 'project', 'coordination', 'the year', 'platforms', 'project management', 'vodafone uk', 'international companies', 'experiences', 'work environment', 'environment', 'interest', 'kyrgyzstan', 'hr', 'situations', 'a school', 'a year', 'student', 'people', 'international business management', 'store sales advisor', 'myself', 'teacher', 'prague international college', 'advisor', 'new people', 'college', 'product support analyst', 'a summer camp', 'the different platforms', 'peoplesoft', 'sales', 'uk', 'summer', 'assessment', 'they', 'my future work environment', 'skills', 'market', 'me', 'team skills', 'new situations', 'former student', 'store', 'vodafone', 'business', 'roles', 'uat coordination', 'degree', 'business development', 'development', 'work', 'graduate scheme roles', 'a primary focus', 'product', 'team', 'marketing', 'researcher', 'the jesuit missions', 'a teacher', 'depth', 'hons', 'levels', 'jesuit missions', 'school', 'ba', '(ba hons', 'recruitment', 'year', 'salesforce', 'new skills', 'education', 'management', '2016', 'sports', 'business management', 'resources', 'graduate', 'a product support analyst', 'opportunities', 'ba hons', 'support', 'areas', 'completion', 'analyst', 'camp', 'prague', 'business management student', 'technical support', 'india', 'focus', 'consultant', 'specialist', 'my a levels', 'human resources', 'companies', 'charity', '(hons) international business management student', 'charity work', 'the importance', 'i', 'importance', 'a ba', 'market researcher', 'missions', 'my final year', 'a charity', 'these experiences', 'recruitment consultant', '(international business management', 'everything', 'volunteer', 'an in-depth assessment', 'nonstop education', 'a degree', 'hr specialist', 'amazon', 'prague college', 'summer camp', 'a volunteer', 'sales advisor', 'challenges']
l'opinione", 'industries', 'italiana', 'announo', 'linkiesta', 'perspective', 'media contributor', 'a career perspective', 'career', 'media', 'the belief', 'inspiration', 'i', 'charge', 'a ba', 'a focus', 'different industries', 'columnist', 'mayor municipality', 'international economics', 'strategy', 'reason', 'economics', 'national tv rai2', 'the us', 'my area', 'a columnist', 'journalist', 'living', 'pr strategy', 'cooperation', 'investor', 'sustainability', 'political economy', 'liberty', 'audience', 'belief', 'il giornale, linkiesta', 's.p.a', 'firms']
# <class 'list'>
# ['project', 'account manager', 'various other software professionals', 'application', 'java/j2ee', 'business analysts', 'inc', 'sets', 'infrastructure skills specialties', 'managers', 'developers', '9+ years', ', business objects', 'negotiation skills', '8+ years', 'software professionals', 'manager', 'java', 'software engineers', 'qa', 'top', 'team handling and client interactions', '- vdart technologies', 'technical interviews', 'database', 'technical skills', 'skills', 'specialties', 'training recruiters', 'ability', 'training', 'business', 'interactions', 'software', 'database developers', 'j2ee', 'professionals', 'account management', 'technologies', '8 +', 'client', 'enterprise application integration skills', 'eai other', 'portal developers', 'team', '( recruitment )vdart technologies', 'it talent', 'integration', 'recruitment professional', 'delivery account lead', 'business objects', 'eai', 'vdart inc', 'talent management', 'negotiation', 'recruitment', 'vdart', 'years', 'vdart technologies', 'recruitment & client interactions', 'infrastructure skills', 'infrastructure', 'testing', 'recruiters', 'management', 'analysts', 'other skill sets', ', delivery account lead', 'face', 'engineers', 'corporate recruitment', 'project managers', 'enterprise', 'around 8+ years', 'extensive experience', 'experts', '[summary', 'talent', 'interviews', 'sourcing professionals', '-vdart technologies', 'experience', 'messaging', 'skill sets', ', .net, business objects', '10 +', 'around 9+ years', 'phone', 'biztalk', 'summary', 'sharepoint', 'recruitment management', 'administrators', 'objects', 'handling', '10 + years', 'specialists', 'lead', '.net technologies', 'account', 'skill', 'delivery', 'technical recruitment', 'architects']
# <class 'list'>
# ['an emphasis', 'award', 'we', 'the subject line', 'hr manager', 'co', '-', 'an additional 20 people', '1995', 'interest', 'hr', 'growth', 'time', 'that position', 'brewing award', 'the end of 2016', 'partners', '65', 'impact', 'owner/coo', 'people', 'gm', 'early 2016', 'manager', 'a gm', 'reasons', 'alesmith brewing company', 'resumes', 'your email', 'san diego brewing company', 'you', 'our local and global communities', 'sales', 'new sales reps', 'goals', 'mikkeller san diego brewing company', 'term', 'business partners', 'passion', 'quality craft beer', 'those relationships', 'san diego', 'business', 'your desired salary', 'diego', 'beer', 'craft', 'the end', '65 employees', 'end', 'your long term goals', 'distributor agreements', 'owner', 'your reasons', 'either company', 'a current listing', 'listing', 'our company', 'our openings', 'us', 'an interest', '5-star customer service', 'star', 'mikkeller', 'continued growth', 'employees', 'the email', 'salary', 'quality', 'new distributor agreements', 'relationships', 'openings', 'letter', 'line', 'career opportunities', 'agreements', 'an hr manager / director', 'emphasis', 'file', 'customer', 'brewing', 'resources', 'reps', 'the following info', 'opportunities', 'communities', 'your ideal position', 'a positive impact', 'distributor', 'company', 'website', 'coo', 'your desired position', 'term goals', 'email', 'the time', 'resume', 'san', 'director', 'human resources', 'them', 'a passion', 'sales reps', 'plans', 'alesmith', 'a resume', 'career', 'i', 'beers', 'position', 'info', 'our website', 'an additional 20', 'cheers', 'cover letter', 'brewing company', 'service', '5']
# <class 'list'>
# ...
# ['business/marketing results', 'personalization', 'project', 'pressure', 'syndicated data', 'project management', 'technology', 'vice', '-', 'commercial products', 'marketing results', 'equation', '150', 'angel', 'scalable software design', 'successful client engagements', 'engineering organizations', 'environment', 'commerce', 'motivated, competent and productive engineering organizations', 'hands', 'model', 'growth', 'techniques', 'time', 'level', 'data analysis techniques', 'performance', 'track record', 'teams', 'vp', 'internet', 'expertise', 'developers', 'marketing decision', 'innovation executive | entrepreneur', 'a diverse set', 'analytics', 'commerce and device management areas', 'customers', 'technology leader', 'repeated and/or new business opportunities specialties', 'business leader', 'development expertise building', 'an established advanced analytics leader', 'factor', 'community', 'profound understanding', 'team building/leadership', 'angel investor', 'process improvements', '|', 'design', 'staff management software', 'process', 'partner relationship', 'relationship', 'innovation', 'staff', 'architecture', 'new high-availability mission critical products', 'analytics leader', 'mission', 'effectiveness', 'specialties', 'new high-availability mission critical enterprise', 'engineering', 'price', 'vice president', 'ability', 'landscape', 'cloud', 'marketing mix model', 'engineering teams', 'decision', 'the next level', 'the competitive landscape', 'business', 'data', 'hands-on experience', 'services', 'software', 'a proven track record', 'deep learning', 'organization', 'e', 'leader', 'development', 'large enterprise organizations', 'markets', 'analytics consulting', 'pricing strategies', 'environments', 'learning', 'client', 'new products', 'an offshore development center', 'spend', 'parallel', 'customer/partner relationship', 'analysis', 'team', 'products', '150+ developers', 'business opportunities', 'ecommerce', 'marketing', 'management areas', 'cluster', 'releases', 'client engagements', 'depth', 'multivariate data analysis techniques', '20 years', 'team development', 'strategic markets', 'internet security', 'set', 'factor analysis', 'mobile applications', 'depth expertise', 'enterprise organization', 'modeling', 'years', 'software design', '| entrepreneur', 'custom analytics -', 'mix', 'device', 'planning', 'competitive landscape', 'center', 'management', ', innovative, results-driven technology leader', 'consulting', 'multiple critical commercial releases', 'web', 'record', 'customer', 'repeated and/or new business opportunities', 'price and promotion analysis', 'optimization', '~ staff management software', 'analytics-marketing effectiveness', 'building', 'strategies', 'cluster analysis', 'president', 'opportunities', 'device management', 'business/marketing decision', '10+ years', 'motivated, competent and productive engineering teams', 'iterative critical releases', 'enterprise', 'big data process', 'areas', 'custom', 'a services', 'small teams', 'organizations', 'track', 'engagements', 'organic growth', 'solid knowledge', 'marketing analytics', 'leadership', 'emarketing', 'availability', 'agile development', 'marketing spend optimization', 'custom analytics - marketing effectiveness', 'experience', 'high-pressure, fast-paced, dynamic environments', 'nielsen', 'industries', 'director', 'strategic planning', '10 +', 'business opportunities specialties', 'software architecture', 'data process', 'partner', 'consumer', 'the existing products', 'promotion', 'security', 'statistical modeling', 'results', 'enterprise organizations', '+', 'consumer products', 'consistent track record', 'cost', 'clear understanding', 'understanding', 'structure', 'proven ability', 'improvements', 'big data', 'device management j2ee web applications', 'development center', 'investor', 'large enterprise organization', 'pricing', 'a high-pressure, client-driven environment', 'structure equation modeling', 'generalized linear modeli ...
# <class 'list'>
# ['career progression', 'establishment', 'project', 'california', 'fact', 'polymer products marketing', 'los angeles', 'my business knowledge', 'fifteen years experience', 'fact-based, process-oriented approaches', 'application', 'forecasting', 'location', 'sustainable projects', 'bank', 'inc', '... expert / top manager', 'expert / top manager', 'advanced plastic products', '15 years', 'results-driven, highly motivated manager', 'growth', '12 years', '13 years', 'a dynamic organization', 'george', 'doer', 'packaging', 'angeles', 'alpha', 'myself', 'continued career progression', 'manager', 'well-developed technological, business and product understanding, manufacturing, marketing and distribution, strategic development', '\n\n specialties', 'polymer', 'top', 'business processes', 'operations', ', expert / top manager', 'process', 'over 15 years', 'supply chain', 'plastic bank', 'years experience', 'twelve years', 'business analysis', 'george dadiani&#39;s professional profile', 'verdeco', 'skills', 'goals', 'specialties', 'execution', 'the organization', 'over 12 years', 'the development', 'sustainable procurement', 'the growth', 'repet inc', 'plant', 'business', 'procurement', 'expert', 'organization', 'plastics industry', 'linkedin', 'development', 'omega', 'recycling', 'business development executive', 'executive', 'product', 'analysis', 'approaches', 'project development', '.', 'products', 'marketing', 'organizational objectives', 'success', 'projects', 'maintenance', 'verdeco recycling production plant', 'chain', 'best practices', 'pacific sustainable industries', 'years', 'the pet packaging industry', 'processing', 'george dadiani&#39;s', 'manufacturing', 'packaging industry', 'planning', 'distribution', 'application development', 'food', 'food processing', 'objectives', 'the establishment', 'industry', 'consulting', 'los', 'fifteen years', 'contract', 'sustainable project development', 'processes', 'multiple business processes', 'practices', 'area', '\n\nspecialties', 'repet', 'production', 'support', 'plastics', 'plastics recycling project development', 'a challenging leading position', 'greater los angeles area', '[passionate visioner and doer. expert', 'experience', 'visioner', 'business knowledge', 'administration', 'industries', 'director', 'dadiani&#39;s', 'global supply chain', 'plastic packaging manufacturing', 'los angeles area', 'contract administration', 'career', '\n\nresults-driven, highly motivated manager', 'results', '16 years', 'position', 'understanding', 'twelve years experience', 'plastic', 'containers', 'profile', 'packaging manufacturing', 'progression', 'aggressive goals', 'supply', 'strong analytical skills', 'knowledge']
# <class 'list'>
# ['we', 'market/ sell products', 'rotor', 'life', 'a property manager', 'llc', 'clients', 'mastery', 'strong web and crm experience', 'property', 'methods', 'any cleaning job', 'marketing skills', 'tql miami', 'rotor wing pilot', 'communication', 'strong web based marketing and crm experience', 'peak management llc', 'construction', 'man', 'crm', 'capacity', 'manager', 'qc', 'rapport', 'leasing process', 'design', 'excellent communication skills', 'process', 'mgmt experience', 'sales', 'database', 'skills', 'my objective', 'helicopter pilot', 'sell products', 'excellent verbal and written communication skills', 'cleaning industry', 'peak', 'training', 'the capacity', 'business', 'managing partner', 'leadership training', 'major automotive repair', 'potential
# ['primary care', 'intense focus', '9 years', 'licensed vocational nurse', 'strong decision maker', 'time', '12 years', 'patience', 'advocate', 'clinic', '10 years experience', 'departments', 'implementation specialist', 'nurse', 'recovery', 'foundation', 'healthcare professional', 'employee', 'manager', 'specialty', 'safety', 'hospital', 'patient safety', 'years experience', 'staff', 'palo', 'solver', 'a strong focus', 'activities', 'skills', 'goals', 'hospital and clinical settings', ', positive patient interactions', 'service recovery', 'decision', 'disease prevention', 'patients', 'high quality healthcare', 'compassion', 'employee management', 'interactions', 'crossover health', 'patient advocate', 'clinical staff', 'medical specialty', 'excellent time management skills', 'clinic management', 'care', 'crossover', 'medical specialty departments', 'coaching', 'care center manager', 'outcomes', 'quality', 'organizational goals', '8 years', 'maker', 'alto', 'years', 'patient outcomes', 'planning', 'surgical specialty departments', 'palo alto medical foundation', 'center', 'management', 'prevention', 'healthcare', 'organizing', 'settings', 'fast paced departments', 'disease', 'quality healthcare', 'who', 'clinical implementation specialist', 'extensive experience', 'health', 'decision maker', 'planning and organizing activities', 'focus', 'implementation', '12 years experience', 'specialist', 'time management skills', 'experience', 'specialty departments', '9 years experience', 'patient interactions', 'first', '10 years', 'the importance', 'importance', 'missions', 'patient', 'problem', '8 years experience', 'problem -', 'service']

# %%
entity_df
# Out:
#                                                                                                                                                                                        combined_list_unique  \
# 0   [technology, match, collector, senior technical recruiter, techniques, time, mentor, 13 years, squirrel, purple squirrel collector, all statements, networking capabilities, a member, the consummat...
# 1   [tudor, switching, bgp, july, ospf, dwdm, (b.s) degree, technology, platforms, repositories, (b.s, faculty \n \n master, \n- mpls fundamentals, eigrp, switch, senior network analyst, faculty maste...
# 2   [nordstrom, 4 years ago, my own events, nordstrom(nordstrom, merchandising, events, boutique, interest, my store manager, nordstrom leaders, hands, time, nordstrom(nordstrom rack, a great eye, stu...
# 3   [life, co, 9 years, -, marketing profession, marketing collateral, application, brand, interest, demonstration, product launch, track record, workers, strong capacity, 9 years', virtue, expertise,...
# 4   [project teams, fit, both the client, contractor, project, project management, laing, nine years, kong, construction industry, course, deadlines, time, certificate, teams, a construction team, hon...
# ..                                                                                                                                                                                                      ...
# 95  [day, turtles, harry, byzantium great expectations, carribean, compass generation, stanger, inc, prince, the half blood prince\nbedtime stories, the carribean, water, monsters, stanger tides, fant...
# 96  [career progression, establishment, project, california, fact, polymer products marketing, los angeles, my business knowledge, fifteen years experience, fact-based, process-oriented approaches, ap...
# 97  [we, market/ sell products, rotor, life, a property manager, llc, clients, mastery, strong web and crm experience, property, methods, any cleaning job, marketing skills, tql miami, rotor wing pilo...
# 98  [solutions, tv systems, we, answer, the team members, details, business requirements, insecurity, end -, devs, visual/ui/ux design, principle/invision/pixate, time, prototypes, the entire developm...
# 99  [primary care, intense focus, 9 years, licensed vocational nurse, strong decision maker, time, 12 years, patience, advocate, clinic, 10 years experience, departments, implementation specialist, nu...
#
#                            target
# 0       purple squirrel microsoft
# 1                8 network asavie
# 2   founder fashion icandydesigns
# 3          medical product system
# 4          capable site multiplex
# ..                            ...
# 95       senior engine design inc
# 96            plastic supply bank
# 97                 total qc miami
# 98                  well nbc news
# 99      clinical crossover health
#
# [100 rows x 2 columns]

# %%
entity_df.drop(columns = ["target"], axis =1)
# Out:
#                                                                                                                                                                                        combined_list_unique
# 0   [technology, match, collector, senior technical recruiter, techniques, time, mentor, 13 years, squirrel, purple squirrel collector, all statements, networking capabilities, a member, the consummat...
# 1   [tudor, switching, bgp, july, ospf, dwdm, (b.s) degree, technology, platforms, repositories, (b.s, faculty \n \n master, \n- mpls fundamentals, eigrp, switch, senior network analyst, faculty maste...
# 2   [nordstrom, 4 years ago, my own events, nordstrom(nordstrom, merchandising, events, boutique, interest, my store manager, nordstrom leaders, hands, time, nordstrom(nordstrom rack, a great eye, stu...
# 3   [life, co, 9 years, -, marketing profession, marketing collateral, application, brand, interest, demonstration, product launch, track record, workers, strong capacity, 9 years', virtue, expertise,...
# 4   [project teams, fit, both the client, contractor, project, project management, laing, nine years, kong, construction industry, course, deadlines, time, certificate, teams, a construction team, hon...
# ..                                                                                                                                                                                                      ...
# 95  [day, turtles, harry, byzantium great expectations, carribean, compass generation, stanger, inc, prince, the half blood prince\nbedtime stories, the carribean, water, monsters, stanger tides, fant...
# 96  [career progression, establishment, project, california, fact, polymer products marketing, los angeles, my business knowledge, fifteen years experience, fact-based, process-oriented approaches, ap...
# 97  [we, market/ sell products, rotor, life, a property manager, llc, clients, mastery, strong web and crm experience, property, methods, any cleaning job, marketing skills, tql miami, rotor wing pilo...
# 98  [solutions, tv systems, we, answer, the team members, details, business requirements, insecurity, end -, devs, visual/ui/ux design, principle/invision/pixate, time, prototypes, the entire developm...
# 99  [primary care, intense focus, 9 years, licensed vocational nurse, strong decision maker, time, 12 years, patience, advocate, clinic, 10 years experience, departments, implementation specialist, nu...
#
# [100 rows x 1 columns]

# %%
entity_df["combined_list_unique"][0]
# Out:
# ['technology',
#  'match',
#  'collector',
#  'senior technical recruiter',
#  'techniques',
#  'time',
#  'mentor',
#  '13 years',
#  'squirrel',
#  'purple squirrel collector',
#  'all statements',
#  'networking capabilities',
#  'a member',
#  'the consummate recruiter',
#  'people',
#  'sector',
#  'unicorn wrangler',
#  'it sector',
#  'term relationship',
#  'effective sourcing techniques',
#  'microsoft',
#  '\n\n specialties',
#  'the perfect marriage',
#  'strong networking capabilities',
#  'new people',
#  'goal',
#  'my client groups',
#  'groups',
#  'relationship',
#  'abilities',
#  'capabilities',
#  'passive candidates',
#  'my goal',
#  'my skills',
#  'the perfect match',
#  '15+ years',
#  'skills',
#  'specialties',
#  'purple squirrel hunter',
#  'recruiting industry',
#  'the candidate',
#  'unity',
#  'candidate',
#  'term',
#  'snap',
#  'hewlett packard enterprise',
#  'squirrel hunter',
#  'sourcing guru',
#  'methodologies',
#  'recruiting',
#  'work',
#  'ten years',
#  'technologies',
#  'recruiter',
#  'seattle',
#  'networking',
#  'client',
#  'guru',
#  'team',
#  'the recruiting industry',
#  'member',
#  'quality',
#  'what',
#  'my work',
#  'squirrel stalker',
#  'squirrel collector',
#  'purple squirrel stalker',
#  'stalker',
#  'tune',
#  'years',
#  'candidates',
#  'a long term relationship',
#  'quality candidates',
#  'statements',
#  'management',
#  'industry',
#  'colleagues',
#  'technology recruiter',
#  'senior technology recruiter',
#  '\n\nspecialties',
#  'a resource',
#  'unicorn',
#  'enterprise',
#  'unity technologies',
#  'client groups',
#  'my colleagues',
#  'new ways',
#  'ways',
#  'the time',
#  'the team',
#  'national and international recruiting abilities',
#  '11 years',
#  'recruiting abilities',
#  'anyone',
#  'the it sector',
#  'resource',
#  'hewlett',
#  'sourcing techniques',
#  'hunter',
#  'i',
#  'packard',
#  'marriage',
#  'lion',
#  'wrangler',
#  'purple squirrel microsoft']

# %%
entity_df = pd.concat([summary["id"], entity_df], axis = 1)

# %%
entity_df
# Out:
#                              id  \
# 0   zPnnWGWHb2gSYnd98GKaag_0000
# 1   z5LcE0BcZevf5WmwL8nunQ_0000
# 2   xi8skZhrJpM4GVvKfqmuiQ_0000
# 3   xemFTL4WGIObJBz0VZv0gg_0000
# 4   wGX7QmVHBijxQrH-U3ncbA_0000
# ..                          ...
# 95  04dK5T2y78a27gewYZxfEA_0000
# 96  -sQNuO1antttcEmOWs-o5Q_0000
# 97  -nbbpInS-iD0thomdMs6BQ_0000
# 98  -jsY6ula0lsaOQ5rBHxHLg_0000
# 99  -gje06EDSxsMmw8WF1hKtA_0000
#
#                                                                                                                                                                                        combined_list_unique  \
# 0   [technology, match, collector, senior technical recruiter, techniques, time, mentor, 13 years, squirrel, purple squirrel collector, all statements, networking capabilities, a member, the consummat...
# 1   [tudor, switching, bgp, july, ospf, dwdm, (b.s) degree, technology, platforms, repositories, (b.s, faculty \n \n master, \n- mpls fundamentals, eigrp, switch, senior network analyst, faculty maste...
# 2   [nordstrom, 4 years ago, my own events, nordstrom(nordstrom, merchandising, events, boutique, interest, my store manager, nordstrom leaders, hands, time, nordstrom(nordstrom rack, a great eye, stu...
# 3   [life, co, 9 years, -, marketing profession, marketing collateral, application, brand, interest, demonstration, product launch, track record, workers, strong capacity, 9 years', virtue, expertise,...
# 4   [project teams, fit, both the client, contractor, project, project management, laing, nine years, kong, construction industry, course, deadlines, time, certificate, teams, a construction team, hon...
# ..                                                                                                                                                                                                      ...
# 95  [day, turtles, harry, byzantium great expectations, carribean, compass generation, stanger, inc, prince, the half blood prince\nbedtime stories, the carribean, water, monsters, stanger tides, fant...
# 96  [career progression, establishment, project, california, fact, polymer products marketing, los angeles, my business knowledge, fifteen years experience, fact-based, process-oriented approaches, ap...
# 97  [we, market/ sell products, rotor, life, a property manager, llc, clients, mastery, strong web and crm experience, property, methods, any cleaning job, marketing skills, tql miami, rotor wing pilo...
# 98  [solutions, tv systems, we, answer, the team members, details, business requirements, insecurity, end -, devs, visual/ui/ux design, principle/invision/pixate, time, prototypes, the entire developm...
# 99  [primary care, intense focus, 9 years, licensed vocational nurse, strong decision maker, time, 12 years, patience, advocate, clinic, 10 years experience, departments, implementation specialist, nu...
#
#                            target
# 0       purple squirrel microsoft
# 1                8 network asavie
# 2   founder fashion icandydesigns
# 3          medical product system
# 4          capable site multiplex
# ..                            ...
# 95       senior engine design inc
# 96            plastic supply bank
# 97                 total qc miami
# 98                  well nbc news
# 99      clinical crossover health
#
# [100 rows x 3 columns]

# %%
entity_df.to_csv("entity_other_from_ner.csv", index = False)
